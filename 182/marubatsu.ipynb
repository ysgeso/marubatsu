# %%
from ai import dprint
from marubatsu import Marubatsu
from copy import deepcopy
from functools import wraps
from time import perf_counter
from random import choice

def ai_by_mmscore(eval_func):
    @wraps(eval_func)
    def wrapper(mb_orig, debug=False, *args, rand=True, share_tt=True,
                analyze=False, calc_score=False, **kwargs):       
        if calc_score:
            score, count = eval_func(mb_orig, debug, *args, **kwargs)
            return score
        
        starttime = perf_counter()
        dprint(debug, "Start ai_by_mmscore")
        dprint(debug, mb_orig)
        legal_moves = mb_orig.calc_legal_moves()
        dprint(debug, "legal_moves", legal_moves)
        maxnode = mb_orig.turn == Marubatsu.CIRCLE
        best_score = float("-inf") if maxnode else float("inf")
        best_moves = []
        tt = {} if share_tt else None
        totalcount = 0
        if analyze:
            score_by_move = {}
        for move in legal_moves:
            dprint(debug, "=" * 20)
            dprint(debug, "move", move)
            mb = deepcopy(mb_orig)
            x, y = move
            mb.move(x, y)
            dprint(debug, mb)
            score, count = eval_func(mb, debug, tt=tt, *args, **kwargs)
            totalcount += count
            dprint(debug, "score", score, "best score", best_score)
            if analyze:
                score_by_move[move] = score
            
            if (maxnode and best_score < score) or (not maxnode and best_score > score):
                best_score = score
                best_moves = [move]
                dprint(debug, "UPDATE")
                dprint(debug, "  best score", best_score)
                dprint(debug, "  best moves", best_moves)
            elif best_score == score:
                best_moves.append(move)
                dprint(debug, "APPEND")
                dprint(debug, "  best moves", best_moves)

        dprint(debug, "=" * 20)
        dprint(debug, "Finished")
        dprint(debug, "best score", best_score)
        dprint(debug, "best moves", best_moves)
        bestmove = choice(best_moves) if rand else best_moves[0]
        if analyze:
            return {
                "candidate": best_moves,
                "score_by_move": score_by_move,
                "tt": tt,
                "time": perf_counter() - starttime,
                "bestmove": bestmove,
                "score": best_score,
                "count": totalcount,
            }
        else:
            return bestmove
        
    return wrapper

# %%
@ai_by_mmscore
def ai_abs_dls(mb, debug=False, timelimit_pc=None, maxdepth=1, eval_func=None,
               eval_params={}, use_tt=False, tt=None):           
    count = 0
    def ab_search(mborig, depth, tt, alpha=float("-inf"), beta=float("inf")):
        nonlocal count
        if timelimit_pc is not None and perf_counter() >= timelimit_pc:
            raise RuntimeError("time out")
        
        count += 1
        if mborig.status != Marubatsu.PLAYING or depth == maxdepth:
            return eval_func(mborig, calc_score=True, **eval_params)
        
        if use_tt:
            boardtxt = mborig.board_to_str()
            if boardtxt in tt:
                lower_bound, upper_bound = tt[boardtxt]
                if lower_bound == upper_bound:
                    return lower_bound
                elif upper_bound <= alpha:
                    return upper_bound
                elif beta <= lower_bound:
                    return lower_bound
                else:
                    alpha = max(alpha, lower_bound)
                    beta = min(beta, upper_bound)
            else:
                lower_bound = min_score
                upper_bound = max_score
        
        alphaorig = alpha
        betaorig = beta

        legal_moves = mborig.calc_legal_moves()
        if mborig.turn == Marubatsu.CIRCLE:
            score = float("-inf")
            for x, y in legal_moves:
                mb = deepcopy(mborig)
                mb.move(x, y)
                score = max(score, ab_search(mb, depth + 1, tt, alpha, beta))
                if score >= beta:
                    break
                alpha = max(alpha, score)
        else:
            score = float("inf")
            for x, y in legal_moves:
                mb = deepcopy(mborig)
                mb.move(x, y)
                score = min(score, ab_search(mb, depth + 1, tt, alpha, beta))
                if score <= alpha:
                    break
                beta = min(beta, score)   
            
        from util import calc_same_boardtexts

        if use_tt:
            boardtxtlist = calc_same_boardtexts(mborig)
            if score <= alphaorig:
                upper_bound = score
            elif score < betaorig:
                lower_bound = score
                upper_bound = score
            else:
                lower_bound = score
            for boardtxt in boardtxtlist:
                tt[boardtxt] = (lower_bound, upper_bound)
        return score
                
    min_score = float("-inf")
    max_score = float("inf")
    
    if tt is None:
        tt = {}
    score = ab_search(mb, depth=0, tt=tt, alpha=min_score, beta=max_score)
    dprint(debug, "count =", count)
    return score, count

# %%
from ai import ai14s

mb = Marubatsu()
eval_params = { "minimax": True }
print(ai_abs_dls(mb, maxdepth=9, eval_func=ai14s, eval_params=eval_params))
# Out:
# (2, 2)

# %%
print(ai_abs_dls(mb, maxdepth=9, eval_func=ai14s, eval_params=eval_params, calc_score=True))
# Out:
# 0.0

# %%
from pprint import pprint

pprint(ai_abs_dls(mb, maxdepth=9, eval_func=ai14s, eval_params=eval_params, analyze=True))
# Out:
# {'bestmove': (1, 0),
#  'candidate': [(0, 0),
#                (1, 0),
#                (2, 0),
#                (0, 1),
#                (1, 1),
#                (2, 1),
#                (0, 2),
#                (1, 2),
#                (2, 2)],
#  'count': 30709,
#  'score': 0.0,
#  'score_by_move': {(0, 0): 0.0,
#                    (0, 1): 0.0,
#                    (0, 2): 0.0,
#                    (1, 0): 0.0,
#                    (1, 1): 0.0,
#                    (1, 2): 0.0,
#                    (2, 0): 0.0,
#                    (2, 1): 0.0,
#                    (2, 2): 0.0},
#  'time': 1.5907108001410961,
#  'tt': {}}

# %%
pprint(ai_abs_dls(mb, maxdepth=9, eval_func=ai14s, eval_params=eval_params, 
                  use_tt=True,  analyze=True))
# Out:
# {'bestmove': (1, 1),
#  'candidate': [(0, 0),
#                (1, 0),
#                (2, 0),
#                (0, 1),
#                (1, 1),
#                (2, 1),
#                (0, 2),
#                (1, 2),
#                (2, 2)],
#  'count': 1175,
#  'score': 0.0,
#  'score_by_move': {(0, 0): 0.0,
#                    (0, 1): 0.0,
#                    (0, 2): 0.0,
#                    (1, 0): 0.0,
#                    (1, 1): 0.0,
#                    (1, 2): 0.0,
#                    (2, 0): 0.0,
#                    (2, 1): 0.0,
#                    (2, 2): 0.0},
#  'time': 0.16863269917666912,
#  'tt': {'........o': (0.0, 0.0),
#         '.......o.': (0.0, 0.0),
#         '.......ox': (0.0, 0.0),
#         '.......xo': (300, 300),
#         '......o..': (0.0, 0.0),
#         '......o.x': (300, inf),
#         '......oox': (-300, -300),
#         '......ox.': (300, 300),
#         '......oxo': (0.0, 0.0),
#         '......x.o': (300, inf),
#         '......xo.': (0.0, 0.0),
#         '......xoo': (-300, -300),
#         '.....o...': (0.0, 0.0),
#         '.....o..x': (0.0, 0.0),
#         '.....o.ox': (0.0, 0.0),
#         '.....o.x.': (300, inf),
#         '.....o.xo': (300, 300),
#         '.....oo.x': (-inf, 0.0),
#         '.....oox.': (-inf, 300),
#         '.....ooxx': (300, 300),
#         '.....ox..': (300, inf),
#         '.....ox.o': (300, inf),
#         '.....oxo.': (-inf, 0.0),
#         '.....oxox': (300, 300),
#         '.....oxxo': (300, 300),
#         '.....x..o': (300, 300),
#         '.....x.o.': (300, inf),
#         '.....x.oo': (300, 300),
#         '.....xo..': (300, inf),
#         '.....xo.o': (300, 300),
#         '.....xoo.': (-300, -300),
#         '.....xoox': (-300, -300),
#         '.....xoxo': (300, 300),
#         '.....xxoo': (300, inf),
#         '....o....': (0.0, 0.0),
#         '....o...x': (0.0, 0.0),
#         '....o..ox': (0.0, 0.0),
#         '....o..x.': (0.0, inf),
#         '....o..xo': (0.0, 300),
#         '....o.o.x': (-inf, 0.0),
#         '....o.ox.': (0.0, 300),
#         '....o.oxx': (300, 300),
#         '....o.x..': (0.0, 0.0),
#         '....o.x.o': (-inf, 0.0),
#         '....o.xo.': (0.0, 0.0),
#         '....o.xox': (300, 300),
#         '....o.xxo': (300, 300),
#         '....oo..x': (0.0, 0.0),
#         '....oo.xx': (300, inf),
#         '....oooxx': (300, 300),
#         '....oox..': (-inf, 0.0),
#         '....oox.x': (300, inf),
#         '....ooxox': (300, 300),
#         '....ooxx.': (300, 300),
#         '....ooxxo': (300, 300),
#         '....ox...': (0.0, inf),
#         '....ox..o': (0.0, 300),
#         '....ox.ox': (300, inf),
#         '....ox.xo': (300, inf),
#         '....oxo.x': (300, inf),
#         '....oxoox': (-inf, -300),
#         '....oxox.': (300, inf),
#         '....oxoxo': (300, 300),
#         '....oxx.o': (300, inf),
#         '....oxxo.': (300, inf),
#         '....oxxoo': (300, inf),
#         '....x...o': (0.0, 0.0),
#         '....x..o.': (0.0, inf),
#         '....x..oo': (0.0, 0.0),
#         '....x.o..': (0.0, 0.0),
#         '....x.o.o': (-inf, 0.0),
#         '....x.oo.': (0.0, 0.0),
#         '....x.oox': (0.0, 0.0),
#         '....x.oxo': (0.0, 0.0),
#         '....x.xoo': (0.0, 0.0),
#         '....xo...': (0.0, inf),
#         '....xo..o': (0.0, 0.0),
#         '....xo.ox': (0.0, 0.0),
#         '....xo.xo': (300, inf),
#         '....xoo..': (-inf, 0.0),
#         '....xoo.x': (-inf, 0.0),
#         '....xooox': (-inf, -300),
#         '....xoox.': (-inf, 0.0),
#         '....xooxo': (-300, -300),
#         '....xox.o': (300, inf),
#         '....xoxo.': (-inf, 0.0),
#         '....xoxoo': (-300, -300),
#         '....xx.oo': (300, inf),
#         '....xxo.o': (300, inf),
#         '....xxoo.': (300, inf),
#         '...o.....': (0.0, 0.0),
#         '...o....x': (300, inf),
#         '...o...ox': (-inf, 0.0),
#         '...o...x.': (300, inf),
#         '...o...xo': (-inf, 300),
#         '...o..o.x': (300, inf),
#         '...o..ox.': (300, 300),
#         '...o..oxx': (300, 300),
#         '...o..x..': (0.0, 0.0),
#         '...o..x.o': (-inf, 0.0),
#         '...o..xo.': (0.0, 0.0),
#         '...o..xox': (300, 300),
#         '...o..xxo': (300, 300),
#         '...o.o..x': (-inf, -300),
#         '...o.o.xx': (300, inf),
#         '...o.ooxx': (-inf, 300),
#         '...o.ox..': (-inf, -300),
#         '...o.oxox': (-inf, -300),
#         '...o.oxx.': (300, inf),
#         '...o.oxxo': (-inf, 300),
#         '...o.x...': (0.0, inf),
#         '...o.x..o': (-inf, 300),
#         '...o.x.ox': (300, inf),
#         '...o.xo..': (0.0, inf),
#         '...o.xo.x': (300, inf),
#         '...o.xoox': (-300, -300),
#         '...o.xox.': (300, inf),
#         '...o.xoxo': (-inf, 0.0),
#         '...o.xxo.': (0.0, inf),
#         '...o.xxoo': (0.0, inf),
#         '...oo...x': (-inf, 0.0),
#         '...oo..xx': (300, 300),
#         '...oo.oxx': (300, 300),
#         '...oo.x..': (0.0, 0.0),
#         '...oo.x.x': (300, inf),
#         '...oo.xox': (300, 300),
#         '...oo.xx.': (300, inf),
#         '...oo.xxo': (300, 300),
#         '...oox..x': (-inf, 0.0),
#         '...oox.ox': (-inf, -300),
#         '...ooxo.x': (-inf, -300),
#         '...ooxox.': (300, inf),
#         '...ooxoxx': (300, 300),
#         '...ooxx..': (0.0, 0.0),
#         '...ooxx.o': (-inf, 0.0),
#         '...ooxxo.': (0.0, 0.0),
#         '...ooxxox': (300, 300),
#         '...ooxxxo': (300, 300),
#         '...ox....': (0.0, inf),
#         '...ox...o': (-inf, 0.0),
#         '...ox..ox': (-inf, 0.0),
#         '...ox..xo': (-inf, 0.0),
#         '...ox.o..': (0.0, 0.0),
#         '...ox.o.x': (300, inf),
#         '...ox.oox': (-300, -300),
#         '...ox.ox.': (300, inf),
#         '...ox.oxo': (-300, -300),
#         '...ox.x.o': (-inf, 0.0),
#         '...ox.xo.': (0.0, 0.0),
#         '...ox.xoo': (-inf, -300),
#         '...oxo..x': (-inf, -300),
#         '...oxo.ox': (-inf, -300),
#         '...oxo.xo': (-inf, -300),
#         '...oxoo.x': (-inf, -300),
#         '...oxoox.': (-inf, -300),
#         '...oxooxx': (300, 300),
#         '...oxox..': (-inf, -300),
#         '...oxox.o': (-inf, -300),
#         '...oxoxo.': (-inf, -300),
#         '...oxoxox': (-inf, -300),
#         '...oxoxxo': (300, 300),
#         '...oxxo..': (300, inf),
#         '...oxxoox': (300, inf),
#         '...oxxoxo': (300, 300),
#         '...oxxxoo': (0.0, 0.0),
#         '...x....o': (300, inf),
#         '...x...o.': (300, inf),
#         '...x...oo': (-300, -300),
#         '...x..o..': (300, 300),
#         '...x..o.o': (300, 300),
#         '...x..oo.': (300, 300),
#         '...x..oox': (300, inf),
#         '...x..oxo': (300, 300),
#         '...x..xoo': (-300, -300),
#         '...x.o...': (0.0, inf),
#         '...x.o..o': (0.0, inf),
#         '...x.o.ox': (0.0, inf),
#         '...x.o.xo': (300, inf),
#         '...x.oo..': (-inf, 300),
#         '...x.ooox': (0.0, inf),
#         '...x.ooxo': (-inf, 0.0),
#         '...x.ox.o': (300, inf),
#         '...x.oxo.': (300, inf),
#         '...x.oxoo': (-300, -300),
#         '...x.x.oo': (300, inf),
#         '...x.xo.o': (300, inf),
#         '...x.xoo.': (300, inf),
#         '...xo....': (0.0, inf),
#         '...xo..ox': (300, inf),
#         '...xo..xo': (300, inf),
#         '...xo.o..': (0.0, 300),
#         '...xo.o.x': (300, inf),
#         '...xo.oox': (300, inf),
#         '...xo.ox.': (300, inf),
#         '...xo.oxo': (300, 300),
#         '...xo.x.o': (300, inf),
#         '...xo.xo.': (300, inf),
#         '...xo.xoo': (-inf, -300),
#         '...xoo..x': (0.0, 0.0),
#         '...xoo.ox': (0.0, 0.0),
#         '...xoo.xo': (300, inf),
#         '...xooo.x': (-inf, 0.0),
#         '...xoooxx': (300, 300),
#         '...xoox..': (-inf, 0.0),
#         '...xoox.o': (-inf, -300),
#         '...xooxo.': (-inf, -300),
#         '...xooxox': (300, 300),
#         '...xooxxo': (300, 300),
#         '...xox..o': (300, inf),
#         '...xox.oo': (300, inf),
#         '...xoxo..': (300, inf),
#         '...xoxoo.': (300, inf),
#         '...xoxoox': (300, inf),
#         '...xoxoxo': (300, 300),
#         '...xoxxoo': (300, inf),
#         '...xx..oo': (300, inf),
#         '...xx.o.o': (300, inf),
#         '...xx.oo.': (300, inf),
#         '...xxo..o': (300, inf),
#         '...xxooox': (0.0, 0.0),
#         '...xxooxo': (300, 300),
#         '...xxoxoo': (300, inf),
#         '..o......': (0.0, 0.0),
#         '..o.....x': (300, inf),
#         '..o....ox': (-inf, 0.0),
#         '..o....x.': (300, inf),
#         '..o....xo': (300, 300),
#         '..o...ox.': (-inf, 300),
#         '..o...oxx': (-inf, 300),
#         '..o...x..': (0.0, inf),
#         '..o...x.o': (0.0, inf),
#         '..o...xo.': (-inf, 0.0),
#         '..o...xox': (300, 300),
#         '..o...xxo': (300, 300),
#         '..o..o..x': (-300, -300),
#         '..o..o.x.': (-300, -300),
#         '..o..o.xx': (-300, -300),
#         '..o..ooxx': (-inf, -300),
#         '..o..ox..': (-300, -300),
#         '..o..ox.x': (-300, -300),
#         '..o..oxox': (-inf, -300),
#         '..o..oxx.': (300, inf),
#         '..o..x...': (300, 300),
#         '..o..x..o': (0.0, 0.0),
#         '..o..x.o.': (-inf, 300),
#         '..o..x.ox': (300, 300),
#         '..o..x.xo': (300, 300),
#         '..o..xo..': (-inf, 300),
#         '..o..xo.x': (-inf, 300),
#         '..o..xoox': (-inf, -300),
#         '..o..xoxo': (-inf, -300),
#         '..o..xx.o': (0.0, inf),
#         '..o..xxoo': (-300, -300),
#         '..o.o...x': (-inf, 0.0),
#         '..o.o..xx': (300, inf),
#         '..o.o.x..': (-inf, 0.0),
#         '..o.o.x.x': (-inf, 0.0),
#         '..o.o.xox': (-inf, 0.0),
#         '..o.o.xx.': (300, 300),
#         '..o.o.xxo': (300, 300),
#         '..o.oo.xx': (-inf, -300),
#         '..o.oox.x': (-inf, -300),
#         '..o.ooxx.': (-inf, -300),
#         '..o.ox...': (0.0, 300),
#         '..o.ox..x': (300, 300),
#         '..o.ox.ox': (300, 300),
#         '..o.ox.x.': (300, inf),
#         '..o.ox.xo': (300, 300),
#         '..o.oxx..': (0.0, inf),
#         '..o.oxx.o': (0.0, inf),
#         '..o.oxxox': (300, 300),
#         '..o.oxxxo': (300, 300),
#         '..o.x....': (0.0, 0.0),
#         '..o.x...o': (-inf, 0.0),
#         '..o.x..o.': (-inf, 0.0),
#         '..o.x..ox': (-inf, 0.0),
#         '..o.x..xo': (300, inf),
#         '..o.x.o..': (-inf, 0.0),
#         '..o.x.oox': (-inf, 0.0),
#         '..o.x.ox.': (-inf, 0.0),
#         '..o.x.oxo': (-inf, -300),
#         '..o.x.x.o': (300, inf),
#         '..o.x.xo.': (-inf, 0.0),
#         '..o.x.xoo': (0.0, 0.0),
#         '..o.xo...': (0.0, 0.0),
#         '..o.xo..x': (0.0, 0.0),
#         '..o.xo.ox': (-inf, -300),
#         '..o.xo.x.': (300, inf),
#         '..o.xoo.x': (-inf, 0.0),
#         '..o.xoox.': (-inf, -300),
#         '..o.xooxx': (-inf, -300),
#         '..o.xox..': (300, inf),
#         '..o.xoxo.': (-inf, 0.0),
#         '..o.xoxox': (0.0, 0.0),
#         '..o.xx..o': (0.0, 0.0),
#         '..o.xx.o.': (-inf, 0.0),
#         '..o.xx.oo': (-300, -300),
#         '..o.xxo..': (-inf, 0.0),
#         '..o.xxo.o': (-inf, -300),
#         '..o.xxoo.': (-inf, -300),
#         '..o.xxoox': (-inf, -300),
#         '..o.xxoxo': (-inf, -300),
#         '..o.xxxoo': (0.0, 0.0),
#         '..oo..oxx': (-inf, 300),
#         '..oo..x..': (-inf, 0.0),
#         '..oo..xox': (-inf, 0.0),
#         '..oo..xx.': (300, inf),
#         '..oo..xxo': (300, 300),
#         '..oo.o.xx': (-inf, -300),
#         '..oo.ox.x': (-inf, -300),
#         '..oo.x...': (-inf, 300),
#         '..oo.x..x': (-inf, 300),
#         '..oo.x.ox': (300, 300),
#         '..oo.x.xo': (-inf, 300),
#         '..oo.xo.x': (-inf, 300),
#         '..oo.xxox': (300, inf),
#         '..oo.xxxo': (300, 300),
#         '..ooo..xx': (-inf, -300),
#         '..ooo.x.x': (-inf, 0.0),
#         '..ooo.xx.': (-inf, -300),
#         '..ooox..x': (-inf, 0.0),
#         '..ooox.xx': (300, inf),
#         '..oooxx..': (-inf, 0.0),
#         '..oooxx.x': (-inf, 0.0),
#         '..oooxxox': (-inf, 0.0),
#         '..oooxxxo': (-inf, 0.0),
#         '..oox....': (-inf, 0.0),
#         '..oox..ox': (-inf, 0.0),
#         '..oox..xo': (-inf, 0.0),
#         '..oox.ox.': (-inf, 0.0),
#         '..oox.oxx': (300, 300),
#         '..oox.x..': (-inf, 0.0),
#         '..oox.x.o': (-inf, 0.0),
#         '..oox.xo.': (0.0, 0.0),
#         '..oox.xox': (0.0, 0.0),
#         '..oox.xxo': (300, inf),
#         '..ooxo..x': (-inf, -300),
#         '..ooxo.xx': (-inf, -300),
#         '..ooxooxx': (-inf, -300),
#         '..ooxox..': (-inf, -300),
#         '..ooxox.x': (-inf, -300),
#         '..ooxoxox': (-inf, -300),
#         '..ooxoxx.': (300, inf),
#         '..ooxx..o': (0.0, 0.0),
#         '..ooxx.o.': (-inf, 0.0),
#         '..ooxx.ox': (300, inf),
#         '..ooxx.xo': (0.0, 0.0),
#         '..ooxxo..': (-inf, 0.0),
#         '..ooxxo.x': (300, inf),
#         '..ooxxoox': (-inf, -300),
#         '..ooxxox.': (300, inf),
#         '..ooxxoxo': (-inf, -300),
#         '..ooxxx.o': (0.0, 0.0),
#         '..ooxxxo.': (0.0, inf),
#         '..ooxxxoo': (0.0, 0.0),
#         '..ox.....': (300, inf),
#         '..ox...xo': (300, inf),
#         '..ox..o..': (-inf, 300),
#         '..ox..oxo': (-inf, 300),
#         '..ox..x.o': (300, inf),
#         '..ox..xo.': (300, inf),
#         '..ox..xoo': (-inf, -300),
#         '..ox.o...': (0.0, inf),
#         '..ox.o..x': (0.0, inf),
#         '..ox.o.ox': (-inf, -300),
#         '..ox.o.x.': (300, inf),
#         '..ox.ooxx': (-inf, 300),
#         '..ox.ox..': (300, inf),
#         '..ox.oxo.': (-inf, 0.0),
#         '..ox.oxox': (-inf, 0.0),
#         '..ox.x..o': (300, inf),
#         '..ox.x.oo': (-300, -300),
#         '..ox.xoox': (300, inf),
#         '..ox.xxoo': (-300, -300),
#         '..oxo.x..': (300, 300),
#         '..oxo.x.o': (-inf, -300),
#         '..oxo.xo.': (-inf, -300),
#         '..oxo.xox': (300, inf),
#         '..oxo.xxo': (300, inf),
#         '..oxoo..x': (-300, -300),
#         '..oxoo.xx': (300, inf),
#         '..oxoox..': (-inf, -300),
#         '..oxoox.x': (-300, -300),
#         '..oxooxox': (-300, -300),
#         '..oxooxx.': (300, inf),
#         '..oxox...': (300, inf),
#         '..oxox..o': (300, inf),
#         '..oxox.ox': (300, inf),
#         '..oxox.xo': (300, inf),
#         '..oxoxx.o': (300, inf),
#         '..oxoxxo.': (300, inf),
#         '..oxoxxoo': (-300, -300),
#         '..oxx.o..': (-inf, 0.0),
#         '..oxx.o.o': (-inf, -300),
#         '..oxx.oo.': (-inf, 0.0),
#         '..oxx.oox': (-inf, 0.0),
#         '..oxx.oxo': (300, 300),
#         '..oxx.xoo': (300, inf),
#         '..oxxo...': (300, inf),
#         '..oxxo.ox': (0.0, inf),
#         '..oxxoo..': (-inf, 0.0),
#         '..oxxoo.x': (-inf, 0.0),
#         '..oxxooox': (-inf, -300),
#         '..oxxoox.': (300, inf),
#         '..x.....o': (300, inf),
#         '..x....o.': (300, inf),
#         '..x....oo': (300, inf),
#         '..x...o..': (0.0, inf),
#         '..x...o.o': (0.0, inf),
#         '..x...oo.': (-300, -300),
#         '..x...oox': (-300, -300),
#         '..x...oxo': (0.0, inf),
#         '..x...xoo': (300, inf),
#         '..x..o...': (0.0, 0.0),
#         '..x..o..o': (-300, -300),
#         '..x..o.o.': (-inf, 0.0),
#         '..x..o.ox': (300, 300),
#         '..x..o.xo': (300, inf),
#         '..x..oo..': (-inf, 0.0),
#         '..x..oo.x': (300, 300),
#         '..x..ooox': (-inf, -300),
#         '..x..ooxo': (-300, -300),
#         '..x..ox.o': (300, inf),
#         '..x..oxoo': (-300, -300),
#         '..x..x.oo': (300, 300),
#         '..x..xo.o': (300, 300),
#         '..x..xoo.': (300, inf),
#         '..x.o....': (0.0, 0.0),
#         '..x.o...o': (-inf, 0.0),
#         '..x.o..o.': (-inf, 0.0),
#         '..x.o..ox': (300, inf),
#         '..x.o..xo': (300, inf),
#         '..x.o.o..': (-inf, 0.0),
#         '..x.o.o.x': (-inf, 0.0),
#         '..x.o.oox': (-inf, -300),
#         '..x.o.ox.': (0.0, inf),
#         '..x.o.oxo': (0.0, inf),
#         '..x.o.xo.': (300, inf),
#         '..x.o.xoo': (300, inf),
#         '..x.oo...': (0.0, 0.0),
#         '..x.oo..x': (300, 300),
#         '..x.oo.ox': (300, 300),
#         '..x.oo.x.': (300, inf),
#         '..x.oo.xo': (300, inf),
#         '..x.ooo.x': (-inf, 0.0),
#         '..x.oooxx': (300, 300),
#         '..x.oox..': (300, inf),
#         '..x.oox.o': (300, inf),
#         '..x.ooxox': (300, inf),
#         '..x.ooxxo': (300, inf),
#         '..x.ox..o': (300, 300),
#         '..x.ox.o.': (300, 300),
#         '..x.ox.oo': (300, 300),
#         '..x.oxo..': (300, 300),
#         '..x.oxo.o': (300, 300),
#         '..x.oxoo.': (-inf, -300),
#         '..x.oxoxo': (300, 300),
#         '..x.oxxoo': (300, inf),
#         '..x.x..oo': (300, inf),
#         '..x.x.o.o': (300, inf),
#         '..x.x.oo.': (300, inf),
#         '..x.xo..o': (0.0, 0.0),
#         '..x.xo.o.': (-inf, 0.0),
#         '..x.xo.oo': (-300, -300),
#         '..x.xoo..': (-inf, 0.0),
#         '..x.xoo.o': (0.0, 0.0),
#         '..x.xooo.': (-inf, 0.0),
#         '..x.xooox': (0.0, 0.0),
#         '..x.xooxo': (0.0, 0.0),
#         '..xo.....': (300, inf),
#         '..xo..o..': (-300, -300),
#         '..xo..o.x': (300, inf),
#         '..xo..oox': (-300, -300),
#         '..xo..ox.': (300, inf),
#         '..xo..oxo': (-inf, 0.0),
#         '..xo..xo.': (300, inf),
#         '..xo..xoo': (-inf, -300),
#         '..xo.o...': (-inf, -300),
#         '..xo.o..x': (300, 300),
#         '..xo.o.ox': (-inf, -300),
#         '..xo.oo.x': (300, 300),
#         '..xo.ooxx': (300, 300),
#         '..xo.x..o': (-inf, 300),
#         '..xo.x.oo': (-inf, 300),
#         '..xo.xo..': (300, inf),
#         '..xo.xo.o': (-inf, 300),
#         '..xo.xoxo': (300, 300),
#         '..xo.xxoo': (300, inf),
#         '..xoo....': (-inf, 0.0),
#         '..xoo.o.x': (-inf, -300),
#         '..xoo.ox.': (300, inf),
#         '..xoo.oxx': (300, inf),
#         '..xoo.x..': (300, inf),
#         '..xoo.xo.': (300, inf),
#         '..xoo.xox': (300, inf),
#         '..xoo.xxo': (300, inf),
#         '..xoox...': (-inf, 0.0),
#         '..xoox..o': (-inf, 0.0),
#         '..xoox.o.': (-inf, -300),
#         '..xoox.xo': (-inf, 300),
#         '..xooxo..': (-inf, -300),
#         '..xooxox.': (300, inf),
#         '..xooxoxo': (0.0, 0.0),
#         '..xooxxo.': (300, inf),
#         '..xooxxoo': (300, inf),
#         '..xox.o..': (300, inf),
#         '..xox.oox': (300, inf),
#         '..xox.oxo': (300, inf),
#         '..xoxo...': (-inf, -300),
#         '..xoxo..o': (-inf, -300),
#         '..xoxo.o.': (-inf, -300),
#         '..xoxo.ox': (-inf, -300),
#         '..xoxo.xo': (-inf, -300),
#         '..xoxoo..': (-inf, -300),
#         '..xoxoo.x': (300, inf),
#         '..xoxooox': (-300, -300),
#         '..xoxoox.': (300, inf),
#         '..xoxooxo': (-300, -300),
#         '..xoxx.oo': (-inf, 300),
#         '..xx...oo': (300, inf),
#         '..xx..o.o': (300, inf),
#         '..xx..oo.': (300, inf),
#         '..xx.o..o': (0.0, inf),
#         '..xx.o.oo': (-300, -300),
#         '..xx.oo.o': (0.0, inf),
#         '..xx.ooox': (0.0, inf),
#         '..xx.ooxo': (0.0, 0.0),
#         '..xx.oxoo': (-300, -300),
#         '..xxo..oo': (300, inf),
#         '..xxo.o..': (0.0, inf),
#         '..xxo.oo.': (300, inf),
#         '..xxo.oox': (300, inf),
#         '..xxo.oxo': (300, inf),
#         '..xxo.xoo': (300, inf),
#         '..xxoo...': (0.0, 0.0),
#         '..xxoo..o': (-300, -300),
#         '..xxoo.o.': (-inf, 0.0),
#         '..xxoo.ox': (300, inf),
#         '..xxoo.xo': (300, inf),
#         '..xxooo..': (-inf, 0.0),
#         '..xxooo.x': (-inf, 0.0),
#         '..xxoooox': (0.0, 0.0),
#         '..xxoooxo': (0.0, 0.0),
#         '..xxoox.o': (300, inf),
#         '..xxooxoo': (-300, -300),
#         '..xxox.oo': (300, inf),
#         '..xxoxo.o': (300, inf),
#         '..xxoxoo.': (300, inf),
#         '..xxxo.oo': (300, inf),
#         '..xxxoo.o': (300, inf),
#         '.o.......': (0.0, 0.0),
#         '.o......x': (300, inf),
#         '.o.....ox': (-inf, -300),
#         '.o.....x.': (0.0, inf),
#         '.o.....xo': (-inf, 300),
#         '.o....ox.': (-inf, 300),
#         '.o....oxx': (-inf, 300),
#         '.o....x..': (300, inf),
#         '.o....xo.': (-inf, -300),
#         '.o....xox': (300, 300),
#         '.o....xxo': (-inf, 300),
#         '.o...o..x': (-inf, 0.0),
#         '.o...o.xx': (300, inf),
#         '.o...ooxx': (300, 300),
#         '.o...oxox': (-inf, -300),
#         '.o...oxxo': (-inf, 300),
#         '.o...x...': (300, inf),
#         '.o...x..o': (-inf, 300),
#         '.o...x.ox': (300, inf),
#         '.o...xoox': (-inf, -300),
#         '.o...xoxo': (-inf, 300),
#         '.o..o...x': (-inf, 0.0),
#         '.o..o..xx': (-inf, 0.0),
#         '.o..o.oxx': (-inf, 0.0),
#         '.o..o.x..': (-inf, 0.0),
#         '.o..o.xx.': (-inf, 0.0),
#         '.o..o.xxo': (-inf, 0.0),
#         '.o..oo.xx': (-inf, -300),
#         '.o..ooxx.': (-inf, -300),
#         '.o..ox..x': (300, 300),
#         '.o..oxo.x': (-inf, -300),
#         '.o..oxoxx': (300, inf),
#         '.o..oxxxo': (-inf, 300),
#         '.o..x....': (0.0, inf),
#         '.o..x...o': (-inf, 0.0),
#         '.o..x..ox': (-inf, -300),
#         '.o..x.o..': (-inf, 0.0),
#         '.o..x.oox': (-inf, -300),
#         '.o..x.oxo': (0.0, 0.0),
#         '.o..x.xo.': (-inf, -300),
#         '.o..x.xoo': (-inf, -300),
#         '.o..xo..x': (-inf, 0.0),
#         '.o..xo.ox': (-inf, -300),
#         '.o..xoo.x': (-inf, 0.0),
#         '.o..xoox.': (-inf, 0.0),
#         '.o..xooxx': (300, inf),
#         '.o..xoxo.': (-inf, -300),
#         '.o..xoxox': (-inf, -300),
#         '.o..xoxxo': (-inf, 300),
#         '.o..xx..o': (-inf, 0.0),
#         '.o..xx.oo': (-inf, -300),
#         '.o..xxo.o': (-inf, 0.0),
#         '.o..xxoox': (-inf, -300),
#         '.o..xxoxo': (0.0, 0.0),
#         '.o..xxxoo': (-inf, -300),
#         '.o.o..oxx': (-inf, 300),
#         '.o.o..x..': (-inf, 0.0),
#         '.o.o..xox': (-inf, -300),
#         '.o.o..xx.': (300, inf),
#         '.o.o..xxo': (300, 300),
#         '.o.o.xxxo': (300, 300),
#         '.o.oo..xx': (-inf, -300),
#         '.o.oo.xx.': (-inf, -300),
#         '.o.oox..x': (-inf, -300),
#         '.o.ooxoxx': (-inf, 300),
#         '.o.ooxx..': (-inf, 0.0),
#         '.o.ooxxx.': (-inf, 0.0),
#         '.o.ooxxxo': (-inf, 0.0),
#         '.o.ox..ox': (-inf, -300),
#         '.o.ox..xo': (-inf, 0.0),
#         '.o.ox.oxx': (-inf, 300),
#         '.o.ox.x..': (-inf, 0.0),
#         '.o.ox.x.o': (-inf, 0.0),
#         '.o.ox.xo.': (-inf, -300),
#         '.o.ox.xox': (-inf, -300),
#         '.o.ox.xxo': (300, inf),
#         '.o.oxo..x': (-inf, -300),
#         '.o.oxooxx': (-inf, -300),
#         '.o.oxox..': (-inf, -300),
#         '.o.oxoxox': (-inf, -300),
#         '.o.oxoxxo': (-inf, -300),
#         '.o.oxx..o': (-inf, 0.0),
#         '.o.oxx.xo': (300, inf),
#         '.o.oxxoox': (-inf, -300),
#         '.o.oxxoxo': (0.0, 0.0),
#         '.o.oxxx.o': (-inf, 0.0),
#         '.o.oxxxoo': (-inf, -300),
#         '.o.x.....': (300, inf),
#         '.o.x..o..': (-inf, 300),
#         '.o.x..oxo': (-inf, 300),
#         '.o.x..xo.': (300, inf),
#         '.o.x..xoo': (-inf, -300),
#         '.o.x.ooxx': (300, 300),
#         '.o.x.xoox': (300, inf),
#         '.o.x.xxoo': (300, inf),
#         '.o.xo.oxx': (-inf, 300),
#         '.o.xo.x..': (300, 300),
#         '.o.xo.x.o': (-inf, -300),
#         '.o.xo.xxo': (300, inf),
#         '.o.xoo..x': (-inf, 0.0),
#         '.o.xoo.xx': (-inf, 0.0),
#         '.o.xoooxx': (-inf, 0.0),
#         '.o.xoox..': (-inf, -300),
#         '.o.xooxxo': (-inf, 300),
#         '.o.xoxoxo': (-inf, 300),
#         '.o.xx.o..': (-inf, 0.0),
#         '.o.xx.o.o': (-inf, 0.0),
#         '.o.xx.oo.': (-inf, -300),
#         '.o.xx.oox': (-inf, -300),
#         '.o.xx.oxo': (0.0, 0.0),
#         '.o.xx.xoo': (-inf, -300),
#         '.o.xxoo..': (-inf, 0.0),
#         '.o.xxoo.x': (-inf, 0.0),
#         '.o.xxooox': (-inf, -300),
#         '.o.xxoox.': (300, inf),
#         '.o.xxooxo': (0.0, 0.0),
#         '.o.xxoxoo': (-inf, -300),
#         '.oo.....x': (300, inf),
#         '.oo....x.': (0.0, inf),
#         '.oo....xx': (300, inf),
#         '.oo...oxx': (-inf, 300),
#         '.oo...x..': (-300, -300),
#         '.oo...x.x': (300, inf),
#         '.oo...xox': (300, 300),
#         '.oo...xx.': (300, inf),
#         '.oo...xxo': (-inf, 300),
#         '.oo..o.xx': (-300, -300),
#         '.oo..ox.x': (-300, -300),
#         '.oo..x...': (300, 300),
#         '.oo..x..x': (300, 300),
#         '.oo..x.ox': (-inf, 300),
#         '.oo..x.x.': (300, inf),
#         '.oo..x.xo': (-inf, 0.0),
#         '.oo..xo.x': (-inf, 300),
#         '.oo..xx..': (300, inf),
#         '.oo..xx.o': (-inf, 0.0),
#         '.oo..xxox': (300, 300),
#         '.oo..xxxo': (300, 300),
#         '.oo.o..xx': (-inf, -300),
#         '.oo.o.x.x': (-inf, -300),
#         '.oo.o.xx.': (-inf, -300),
#         '.oo.ox..x': (300, 300),
#         '.oo.ox.x.': (300, inf),
#         '.oo.ox.xx': (300, 300),
#         '.oo.oxx..': (300, inf),
#         '.oo.oxx.x': (300, inf),
#         '.oo.oxxx.': (300, inf),
#         '.oo.oxxxo': (0.0, 0.0),
#         '.oo.x....': (0.0, 0.0),
#         '.oo.x...x': (300, inf),
#         '.oo.x..ox': (-inf, -300),
#         '.oo.x..x.': (300, inf),
#         '.oo.x.ox.': (-inf, 0.0),
#         '.oo.x.oxx': (300, inf),
#         '.oo.x.x..': (300, inf),
#         '.oo.x.xo.': (-inf, -300),
#         '.oo.x.xox': (300, inf),
#         '.oo.xo..x': (-300, -300),
#         '.oo.xo.xx': (300, inf),
#         '.oo.xooxx': (-inf, -300),
#         '.oo.xox.x': (300, inf),
#         '.oo.xoxox': (-300, -300),
#         '.oo.xx...': (300, inf),
#         '.oo.xx..o': (-300, -300),
#         '.oo.xx.o.': (-inf, -300),
#         '.oo.xx.ox': (300, 300),
#         '.oo.xx.xo': (300, 300),
#         '.oo.xxo..': (-inf, 0.0),
#         '.oo.xxo.x': (300, 300),
#         '.oo.xxoox': (-inf, -300),
#         '.oo.xxox.': (300, inf),
#         '.oo.xxoxo': (-inf, -300),
#         '.oo.xxx.o': (300, inf),
#         '.oo.xxxo.': (300, inf),
#         '.oo.xxxoo': (-300, -300),
#         '.ooo..xx.': (-inf, 0.0),
#         '.ooo.x..x': (-inf, 300),
#         '.ooo.xxox': (300, 300),
#         '.ooo.xxxo': (-inf, 300),
#         '.oooox.xx': (-inf, 300),
#         '.ooooxx.x': (-inf, -300),
#         '.ooooxxx.': (-inf, 0.0),
#         '.ooox.oxx': (-inf, -300),
#         '.ooox.x..': (-inf, 0.0),
#         '.ooox.xox': (-inf, -300),
#         '.ooox.xxo': (300, inf),
#         '.oooxo.xx': (-inf, -300),
#         '.oooxox.x': (-inf, -300),
#         '.oooxoxx.': (-inf, -300),
#         '.oooxx..x': (-inf, 300),
#         '.oooxx.ox': (-inf, -300),
#         '.oooxx.xo': (0.0, 0.0),
#         '.oooxxo.x': (-inf, -300),
#         '.oooxxoxx': (300, 300),
#         '.oooxxx.o': (-inf, 0.0),
#         '.oooxxxo.': (-inf, 0.0),
#         '.oooxxxox': (300, 300),
#         '.oooxxxxo': (300, 300),
#         '.oox.....': (-300, -300),
#         '.oox....x': (300, inf),
#         '.oox...x.': (300, inf),
#         '.oox..oxx': (-inf, 300),
#         '.oox..x..': (300, inf),
#         '.oox..xox': (300, inf),
#         '.oox.o..x': (-300, -300),
#         '.oox.o.xx': (300, inf),
#         '.oox.ooxx': (300, 300),
#         '.oox.ox.x': (-300, inf),
#         '.oox.oxox': (-inf, -300),
#         '.oox.x...': (300, inf),
#         '.oox.x..o': (-300, -300),
#         '.oox.x.xo': (300, inf),
#         '.oox.xx.o': (-300, inf),
#         '.oox.xxoo': (-inf, -300),
#         '.ooxo...x': (300, inf),
#         '.ooxo..xx': (300, inf),
#         '.ooxo.x..': (-inf, -300),
#         '.ooxo.x.x': (300, inf),
#         '.ooxo.xx.': (300, inf),
#         '.ooxoo.xx': (-300, -300),
#         '.ooxoox.x': (-300, -300),
#         '.ooxox...': (300, inf),
#         '.ooxox..x': (300, inf),
#         '.ooxox.x.': (300, inf),
#         '.ooxox.xo': (300, inf),
#         '.ooxoxx..': (300, inf),
#         '.ooxoxx.o': (-300, -300),
#         '.ooxoxxxo': (300, inf),
#         '.ooxx....': (300, inf),
#         '.ooxx.o..': (-inf, -300),
#         '.ooxx.oox': (-inf, -300),
#         '.ooxx.ox.': (300, inf),
#         '.ooxx.oxo': (-inf, -300),
#         '.ooxx.xo.': (300, inf),
#         '.ooxx.xoo': (-inf, -300),
#         '.ooxxo..x': (300, inf),
#         '.ooxxo.ox': (-300, -300),
#         '.ooxxoo.x': (-inf, -300),
#         '.ooxxoox.': (300, inf),
#         '.ooxxooxx': (300, 300),
#         '.ooxxoxo.': (-inf, -300),
#         '.ooxxoxox': (300, inf),
#         '.ox......': (0.0, 0.0),
#         '.ox.....o': (-inf, 0.0),
#         '.ox....o.': (-inf, -300),
#         '.ox...o..': (-inf, 0.0),
#         '.ox...oox': (-inf, -300),
#         '.ox..o...': (0.0, 0.0),
#         '.ox..o..x': (300, 300),
#         '.ox..o.ox': (-inf, -300),
#         '.ox..o.x.': (0.0, inf),
#         '.ox..o.xo': (0.0, inf),
#         '.ox..oo.x': (-inf, 0.0),
#         '.ox..ooxx': (300, inf),
#         '.ox..ox..': (300, inf),
#         '.ox..ox.o': (-inf, -300),
#         '.ox..oxxo': (300, inf),
#         '.ox..x..o': (300, 300),
#         '.ox..x.o.': (300, inf),
#         '.ox..x.oo': (-inf, 300),
#         '.ox..xo..': (300, inf),
#         '.ox..xo.o': (300, 300),
#         '.ox..xoxo': (300, 300),
#         '.ox.o....': (0.0, 0.0),
#         '.ox.o...x': (300, inf),
#         '.ox.o..x.': (0.0, 0.0),
#         '.ox.o..xo': (-inf, 0.0),
#         '.ox.o.o.x': (-inf, 0.0),
#         '.ox.o.ox.': (-inf, 0.0),
#         '.ox.o.oxx': (-inf, 0.0),
#         '.ox.o.x..': (300, inf),
#         '.ox.oo..x': (300, 300),
#         '.ox.oo.x.': (0.0, 0.0),
#         '.ox.oo.xx': (300, 300),
#         '.ox.oooxx': (-inf, 0.0),
#         '.ox.oox..': (300, inf),
#         '.ox.oox.x': (300, inf),
#         '.ox.ooxx.': (300, inf),
#         '.ox.ooxxo': (300, inf),
#         '.ox.ox...': (300, inf),
#         '.ox.ox..o': (300, 300),
#         '.ox.ox.xo': (300, 300),
#         '.ox.oxo..': (-inf, -300),
#         '.ox.oxoxo': (-inf, 0.0),
#         '.ox.oxx.o': (300, inf),
#         '.ox.x...o': (-inf, 0.0),
#         '.ox.x..o.': (-inf, -300),
#         '.ox.x..oo': (-inf, -300),
#         '.ox.x.o..': (-inf, 0.0),
#         '.ox.x.o.o': (-inf, 0.0),
#         '.ox.x.oo.': (-inf, -300),
#         '.ox.x.oox': (-inf, -300),
#         '.ox.x.oxo': (0.0, 0.0),
#         '.ox.xo...': (0.0, 0.0),
#         '.ox.xo..o': (-inf, -300),
#         '.ox.xo.o.': (-inf, -300),
#         '.ox.xo.ox': (-inf, -300),
#         '.ox.xo.xo': (0.0, 0.0),
#         '.ox.xoo..': (0.0, 0.0),
#         '.ox.xoo.x': (0.0, 0.0),
#         '.ox.xooox': (-inf, -300),
#         '.ox.xoox.': (0.0, inf),
#         '.ox.xooxo': (0.0, 0.0),
#         '.ox.xx.oo': (300, 300),
#         '.ox.xxo.o': (300, inf),
#         '.ox.xxoo.': (300, inf),
#         '.oxo.....': (-inf, 0.0),
#         '.oxo..xxo': (300, inf),
#         '.oxo.o..x': (-inf, -300),
#         '.oxo.ooxx': (300, 300),
#         '.oxo.x...': (300, inf),
#         '.oxo.x..o': (300, 300),
#         '.oxo.x.xo': (300, 300),
#         '.oxo.xo..': (-inf, 0.0),
#         '.oxo.xoxo': (-inf, 300),
#         '.oxo.xx.o': (300, inf),
#         '.oxoo..x.': (-inf, 0.0),
#         '.oxoo.oxx': (-inf, -300),
#         '.oxoo.xxo': (300, inf),
#         '.oxoox...': (-inf, -300),
#         '.oxoox.x.': (-inf, 0.0),
#         '.oxoox.xo': (-inf, 0.0),
#         '.oxooxox.': (-inf, 0.0),
#         '.oxooxx.o': (300, inf),
#         '.oxooxxxo': (300, 300),
#         '.oxox....': (-inf, 0.0),
#         '.oxox...o': (-inf, 0.0),
#         '.oxox..o.': (-inf, -300),
#         '.oxox..xo': (-inf, 0.0),
#         '.oxox.o..': (-inf, 0.0),
#         '.oxox.oox': (-inf, -300),
#         '.oxox.oxo': (-inf, 0.0),
#         '.oxoxo...': (-inf, -300),
#         '.oxoxo..x': (-inf, -300),
#         '.oxoxo.ox': (-inf, -300),
#         '.oxoxo.xo': (-inf, -300),
#         '.oxoxoo.x': (-inf, -300),
#         '.oxoxoox.': (-inf, 0.0),
#         '.oxoxooxx': (300, 300),
#         '.oxoxx..o': (300, inf),
#         '.oxoxx.oo': (-inf, -300),
#         '.oxoxxo.o': (300, inf),
#         '.oxoxxoo.': (-inf, -300),
#         '.oxoxxoxo': (300, 300),
#         '.oxx..oox': (300, inf),
#         '.oxx.o...': (0.0, inf),
#         '.oxx.o..o': (-inf, -300),
#         '.oxx.o.xo': (0.0, inf),
#         '.oxx.ooxo': (-inf, 0.0),
#         '.oxx.ox.o': (-inf, -300),
#         '.oxx.oxoo': (-inf, -300),
#         '.oxx.xo.o': (300, inf),
#         '.oxxo....': (300, inf),
#         '.oxxoo...': (0.0, 0.0),
#         '.oxxoo..x': (300, inf),
#         '.oxxoo.x.': (0.0, 0.0),
#         '.oxxoo.xo': (0.0, 0.0),
#         '.oxxooo.x': (-inf, 0.0),
#         '.oxxooox.': (-inf, 0.0),
#         '.oxxoooxx': (-inf, 0.0),
#         '.oxxoox..': (300, inf),
#         '.oxxoox.o': (-inf, -300),
#         '.oxxooxxo': (300, 300),
#         '.oxxox..o': (300, inf),
#         '.oxxoxo..': (300, inf),
#         '.oxxoxo.o': (300, inf),
#         '.oxxoxoxo': (300, 300),
#         '.oxxx.o.o': (300, inf),
#         '.oxxx.oo.': (300, inf),
#         '.oxxxo..o': (0.0, inf),
#         '.oxxxo.oo': (-300, -300),
#         '.oxxxoo..': (0.0, inf),
#         '.oxxxoo.o': (0.0, 0.0),
#         '.oxxxooo.': (-inf, 0.0),
#         '.oxxxooox': (0.0, 0.0),
#         '.oxxxooxo': (0.0, 0.0),
#         '.x......o': (300, inf),
#         '.x.....o.': (0.0, inf),
#         '.x.....oo': (0.0, inf),
#         '.x....o..': (300, inf),
#         '.x....oo.': (0.0, inf),
#         '.x....oox': (0.0, inf),
#         '.x....oxo': (300, inf),
#         '.x....xoo': (0.0, inf),
#         '.x...o...': (300, inf),
#         '.x...o..o': (-300, -300),
#         '.x...o.ox': (0.0, inf),
#         '.x...o.xo': (300, inf),
#         '.x...ooox': (-inf, -300),
#         '.x...ooxo': (-300, -300),
#         '.x...ox.o': (300, inf),
#         '.x...oxoo': (-300, -300),
#         '.x...x.oo': (300, inf),
#         '.x...xo.o': (300, inf),
#         '.x...xoo.': (300, inf),
#         '.x..o....': (0.0, inf),
#         '.x..o..ox': (0.0, 0.0),
#         '.x..o..xo': (300, inf),
#         '.x..o.oox': (-300, -300),
#         '.x..o.ox.': (300, inf),
#         '.x..o.oxo': (300, inf),
#         '.x..o.xo.': (0.0, 0.0),
#         '.x..o.xoo': (-300, -300),
#         '.x..oo..x': (300, inf),
#         '.x..oo.ox': (0.0, 0.0),
#         '.x..oo.xo': (300, inf),
#         '.x..oooxx': (300, inf),
#         '.x..oox.o': (300, inf),
#         '.x..ooxo.': (-inf, 0.0),
#         '.x..ooxox': (300, inf),
#         '.x..ooxxo': (300, inf),
#         '.x..ox..o': (300, inf),
#         '.x..ox.oo': (300, inf),
#         '.x..oxoox': (300, inf),
#         '.x..oxoxo': (300, inf),
#         '.x..oxxoo': (300, inf),
#         '.x..x..oo': (300, inf),
#         '.x..x.oo.': (300, inf),
#         '.x..xo..o': (300, inf),
#         '.x..xooox': (0.0, inf),
#         '.x..xoxoo': (300, inf),
#         '.x.o.....': (300, inf),
#         '.x.o..o..': (-300, -300),
#         '.x.o..o.x': (300, inf),
#         '.x.o..oox': (-300, -300),
#         '.x.o..ox.': (300, inf),
#         '.x.o..oxo': (-300, -300),
#         '.x.o..xo.': (0.0, inf),
#         '.x.o..xoo': (-inf, -300),
#         '.x.o.xo..': (300, inf),
#         '.x.o.xoox': (300, inf),
#         '.x.o.xoxo': (300, inf),
#         '.x.o.xxoo': (0.0, inf),
#         '.x.oo..ox': (-inf, 0.0),
#         '.x.oo.o.x': (300, inf),
#         '.x.oo.ox.': (300, inf),
#         '.x.oo.oxx': (300, inf),
#         '.x.oo.x..': (300, inf),
#         '.x.oo.xo.': (0.0, 0.0),
#         '.x.oo.xox': (300, inf),
#         '.x.oo.xxo': (300, inf),
#         '.x.oox.ox': (-inf, 0.0),
#         '.x.ooxo.x': (300, inf),
#         '.x.ooxoox': (-300, -300),
#         '.x.ooxox.': (300, inf),
#         '.x.ooxoxo': (300, inf),
#         '.x.ooxxo.': (0.0, 0.0),
#         '.x.ooxxoo': (0.0, 0.0),
#         '.x.ox.o..': (300, inf),
#         '.x.ox.oox': (300, inf),
#         '.x.ox.xoo': (0.0, inf),
#         '.x.oxooox': (-300, -300),
#         '.x.oxoxoo': (-300, -300),
#         '.x.x...oo': (300, inf),
#         '.x.x..o.o': (300, inf),
#         '.x.x..oo.': (300, inf),
#         '.x.x.o..o': (300, inf),
#         '.x.x.ooox': (0.0, inf),
#         '.x.x.ooxo': (300, inf),
#         '.x.x.oxoo': (300, inf),
#         '.x.xo.o..': (300, inf),
#         '.x.xo.oo.': (300, inf),
#         '.x.xo.oox': (300, inf),
#         '.x.xo.oxo': (300, inf),
#         '.x.xo.xoo': (300, inf),
#         '.x.xoo.ox': (0.0, 0.0),
#         '.x.xoo.xo': (300, inf),
#         '.x.xoooox': (0.0, 0.0),
#         '.x.xoooxo': (300, inf),
#         '.x.xoox.o': (300, inf),
#         '.x.xooxo.': (-inf, 0.0),
#         '.x.xooxoo': (-300, -300),
#         '.x.xox.oo': (300, inf),
#         '.x.xoxoo.': (300, inf),
#         '.xo......': (300, 300),
#         '.xo.....o': (300, 300),
#         '.xo....o.': (-inf, 300),
#         '.xo....xo': (300, inf),
#         '.xo...o..': (-inf, 300),
#         '.xo...x.o': (300, inf),
#         '.xo...xoo': (0.0, inf),
#         '.xo..o...': (300, 300),
#         '.xo..o..x': (300, inf),
#         '.xo..o.ox': (0.0, inf),
#         '.xo..o.x.': (300, inf),
#         '.xo..ooxx': (300, inf),
#         '.xo..ox..': (300, inf),
#         '.xo..oxox': (0.0, inf),
#         '.xo..x..o': (300, 300),
#         '.xo..x.oo': (-inf, 0.0),
#         '.xo..xo.o': (-inf, 300),
#         '.xo..xoox': (-inf, 300),
#         '.xo..xxoo': (0.0, 0.0),
#         '.xo.o....': (0.0, 300),
#         '.xo.o...x': (300, inf),
#         '.xo.o..ox': (-inf, 0.0),
#         '.xo.o..x.': (300, inf),
#         '.xo.o.x..': (0.0, inf),
#         '.xo.o.xo.': (-inf, 0.0),
#         '.xo.o.xox': (-inf, 0.0),
#         '.xo.o.xxo': (300, inf),
#         '.xo.oo..x': (300, inf),
#         '.xo.oo.x.': (300, inf),
#         '.xo.oo.xx': (300, inf),
#         '.xo.oox..': (300, inf),
#         '.xo.oox.x': (300, inf),
#         '.xo.ooxox': (0.0, 0.0),
#         '.xo.ooxx.': (300, inf),
#         '.xo.ox...': (300, inf),
#         '.xo.ox..o': (300, 300),
#         '.xo.ox.ox': (300, 300),
#         '.xo.ox.xo': (300, 300),
#         '.xo.oxx.o': (300, inf),
#         '.xo.oxxoo': (0.0, 0.0),
#         '.xo.x...o': (300, inf),
#         '.xo.x.o..': (-inf, 0.0),
#         '.xo.x.o.o': (-inf, -300),
#         '.xo.x.oo.': (-inf, 0.0),
#         '.xo.x.oox': (-inf, 0.0),
#         '.xo.x.xoo': (300, inf),
#         '.xo.xo...': (300, inf),
#         '.xo.xo.ox': (0.0, 0.0),
#         '.xo.xoo..': (-inf, 0.0),
#         '.xo.xoo.x': (-inf, 0.0),
#         '.xo.xooox': (-inf, -300),
#         '.xo.xx.oo': (300, 300),
#         '.xo.xxo.o': (300, 300),
#         '.xo.xxoo.': (300, inf),
#         '.xoo.....': (-inf, 300),
#         '.xoo..xxo': (300, inf),
#         '.xoo.o.xx': (300, inf),
#         '.xoo.ox.x': (300, inf),
#         '.xoo.x..o': (-inf, 300),
#         '.xoo.x.ox': (300, 300),
#         '.xoo.xo.x': (-inf, 300),
#         '.xoo.xoox': (300, 300),
#         '.xoo.xxoo': (-inf, 0.0),
#         '.xooo.xox': (-inf, 0.0),
#         '.xooo.xx.': (300, inf),
#         '.xooo.xxo': (300, inf),
#         '.xooox..x': (-inf, 300),
#         '.xooox.ox': (-inf, 0.0),
#         '.xooox.xo': (-inf, 300),
#         '.xoooxxo.': (-inf, 0.0),
#         '.xoooxxox': (-inf, 0.0),
#         '.xoooxxxo': (300, 300),
#         '.xoox....': (-inf, 0.0),
#         '.xoox...o': (-inf, 0.0),
#         '.xoox..o.': (-inf, 0.0),
#         '.xoox..ox': (-inf, 0.0),
#         '.xoox.o..': (-inf, -300),
#         '.xoox.oox': (-inf, -300),
#         '.xoox.x.o': (300, inf),
#         '.xoox.xo.': (0.0, inf),
#         '.xoox.xoo': (0.0, 0.0),
#         '.xooxo...': (-inf, -300),
#         '.xooxo..x': (-inf, -300),
#         '.xooxo.ox': (-inf, -300),
#         '.xooxoo.x': (-inf, -300),
#         '.xooxox..': (300, inf),
#         '.xooxoxo.': (-inf, 0.0),
#         '.xooxoxox': (0.0, 0.0),
#         '.xooxx..o': (0.0, 0.0),
#         '.xooxx.o.': (300, inf),
#         '.xooxx.oo': (0.0, 0.0),
#         '.xooxxo..': (300, inf),
#         '.xooxxo.o': (-inf, -300),
#         '.xooxxoo.': (300, inf),
#         '.xooxxoox': (300, 300),
#         '.xooxxxoo': (0.0, 0.0),
#         '.xox....o': (300, inf),
#         '.xox..xoo': (300, inf),
#         '.xox.o...': (300, inf),
#         '.xox.o.ox': (0.0, inf),
#         '.xox.x.oo': (300, inf),
#         '.xoxo....': (300, inf),
#         '.xoxo.xoo': (-inf, -300),
#         '.xoxoo...': (300, inf),
#         '.xoxoo..x': (300, inf),
#         '.xoxoo.ox': (0.0, 0.0),
#         '.xoxoo.x.': (300, inf),
#         '.xoxoox..': (300, inf),
#         '.xoxooxo.': (-inf, 0.0),
#         '.xoxooxox': (0.0, 0.0),
#         '.xoxox..o': (300, inf),
#         '.xoxox.oo': (300, inf),
#         '.xoxoxxoo': (300, inf),
#         '.xoxx.o.o': (300, inf),
#         '.xoxx.oo.': (300, inf),
#         '.xoxxoo..': (300, inf),
#         '.xx....oo': (300, inf),
#         '.xx...o.o': (300, inf),
#         '.xx...oo.': (300, inf),
#         '.xx..o..o': (-300, -300),
#         '.xx..o.o.': (300, inf),
#         '.xx..o.oo': (-300, -300),
#         '.xx..oo..': (300, inf),
#         '.xx..oo.o': (-inf, -300),
#         '.xx..ooo.': (-inf, 0.0),
#         '.xx..ooox': (-inf, 0.0),
#         '.xx..ooxo': (-300, -300),
#         '.xx..oxoo': (-300, -300),
#         '.xx.o...o': (300, inf),
#         '.xx.o..o.': (-inf, 0.0),
#         '.xx.o..oo': (-inf, -300),
#         '.xx.o.o..': (300, 300),
#         '.xx.o.o.o': (-inf, -300),
#         '.xx.o.oo.': (-inf, -300),
#         '.xx.o.oox': (-300, -300),
#         '.xx.o.oxo': (300, inf),
#         '.xx.o.xoo': (300, inf),
#         '.xx.oo...': (300, inf),
#         '.xx.oo..o': (-inf, -300),
#         '.xx.oo.o.': (-inf, -300),
#         '.xx.oo.ox': (300, 300),
#         '.xx.oo.xo': (300, inf),
#         '.xx.ooo..': (-inf, -300),
#         '.xx.ooo.x': (300, inf),
#         '.xx.oooox': (-300, -300),
#         '.xx.ooox.': (300, inf),
#         '.xx.oooxo': (-300, -300),
#         '.xx.oox.o': (300, inf),
#         '.xx.ooxoo': (-300, -300),
#         '.xx.ox.oo': (300, 300),
#         '.xx.oxo.o': (300, inf),
#         '.xx.oxoo.': (300, inf),
#         '.xx.xo.oo': (300, inf),
#         '.xx.xoo.o': (300, inf),
#         '.xxo..o..': (300, inf),
#         '.xxo..oox': (-300, inf),
#         '.xxo..oxo': (-300, inf),
#         '.xxo..xoo': (-inf, -300),
#         '.xxo.o...': (300, inf),
#         '.xxo.o..o': (-inf, -300),
#         '.xxo.o.xo': (300, inf),
#         '.xxo.oo.x': (300, inf),
#         '.xxo.ooox': (-inf, -300),
#         '.xxo.ooxo': (-inf, -300),
#         '.xxo.oxoo': (-inf, -300),
#         '.xxoo....': (300, 300),
#         '.xxoo...o': (-inf, -300),
#         '.xxoo..o.': (-inf, -300),
#         '.xxoo.o..': (-inf, -300),
#         '.xxoo.o.x': (300, inf),
#         '.xxoo.oox': (-300, -300),
#         '.xxoo.ox.': (300, inf),
#         '.xxoo.oxo': (-300, -300),
#         '.xxoo.xo.': (300, inf),
#         '.xxoo.xoo': (-inf, -300),
#         '.xxoox..o': (300, inf),
#         '.xxoox.oo': (-inf, 300),
#         '.xxooxo..': (300, inf),
#         '.xxooxoxo': (300, inf),
#         '.xxooxxoo': (300, 300),
#         '.xxoxo..o': (-inf, -300),
#         '.xxoxo.oo': (-inf, -300),
#         '.xxoxoo..': (300, inf),
#         '.xxoxoo.o': (-inf, -300),
#         '.xxoxooo.': (-inf, -300),
#         '.xxoxooox': (300, inf),
#         '.xxx.o.oo': (300, inf),
#         '.xxx.oo.o': (300, inf),
#         '.xxxo..oo': (300, inf),
#         '.xxxo.oo.': (300, inf),
#         '.xxxoo..o': (300, inf),
#         '.xxxoo.o.': (-inf, 0.0),
#         '.xxxoo.oo': (-300, -300),
#         '.xxxooo.o': (-inf, -300),
#         '.xxxoooo.': (-inf, 0.0),
#         '.xxxoooox': (0.0, 0.0),
#         '.xxxoooxo': (300, inf),
#         '.xxxooxoo': (300, inf),
#         'o........': (0.0, 0.0),
#         'o.......x': (0.0, inf),
#         'o......ox': (-inf, 0.0),
#         'o......x.': (300, inf),
#         'o......xo': (-inf, 300),
#         'o.....o.x': (0.0, inf),
#         'o.....ox.': (300, 300),
#         'o.....oxx': (300, 300),
#         'o.....x..': (300, inf),
#         'o.....xo.': (-inf, 0.0),
#         'o.....xox': (300, 300),
#         'o.....xxo': (-inf, 300),
#         'o....o..x': (-inf, 0.0),
#         'o....o.xx': (300, inf),
#         'o....ooxx': (300, 300),
#         'o....oxox': (-inf, 0.0),
#         'o....oxxo': (-inf, 300),
#         'o....x...': (300, inf),
#         'o....x..o': (-inf, 300),
#         'o....x.ox': (300, inf),
#         'o....xo.x': (300, inf),
#         'o....xoox': (-inf, -300),
#         'o....xox.': (300, inf),
#         'o....xoxo': (-inf, 300),
#         'o...o...x': (-inf, 0.0),
#         'o...o..xx': (300, 300),
#         'o...o.oxx': (300, 300),
#         'o...o.x..': (-inf, 0.0),
#         'o...o.x.x': (-inf, 0.0),
#         'o...o.xox': (-inf, 0.0),
#         'o...o.xx.': (300, inf),
#         'o...oo.xx': (-inf, -300),
#         'o...oox.x': (-inf, 0.0),
#         'o...ooxx.': (-inf, -300),
#         'o...ox..x': (300, 300),
#         'o...ox.ox': (-inf, -300),
#         'o...oxo.x': (-inf, -300),
#         'o...oxoxx': (300, inf),
#         'o...oxxox': (300, inf),
#         'o...x....': (0.0, 0.0),
#         'o...x...o': (-inf, 0.0),
#         'o...x..o.': (-inf, 0.0),
#         'o...x..ox': (-inf, 0.0),
#         'o...x..xo': (-inf, 0.0),
#         'o...x.o..': (-inf, 0.0),
#         'o...x.o.x': (300, inf),
#         'o...x.oox': (0.0, 0.0),
#         'o...x.ox.': (300, inf),
#         'o...x.oxo': (-inf, -300),
#         'o...x.xo.': (-inf, 0.0),
#         'o...x.xoo': (-inf, 0.0),
#         'o...xo...': (-inf, 0.0),
#         'o...xo..x': (-inf, 0.0),
#         'o...xo.ox': (0.0, 0.0),
#         'o...xo.xo': (-inf, 0.0),
#         'o...xoo.x': (-inf, 0.0),
#         'o...xoox.': (-inf, 0.0),
#         'o...xooxx': (300, inf),
#         'o...xoxo.': (-inf, 0.0),
#         'o...xoxox': (0.0, 0.0),
#         'o...xoxxo': (300, 300),
#         'o...xx..o': (-inf, 0.0),
#         'o...xx.oo': (-inf, 0.0),
#         'o...xxo.o': (-inf, -300),
#         'o...xxoox': (300, inf),
#         'o...xxoxo': (300, 300),
#         'o...xxxoo': (-inf, 0.0),
#         'o..o....x': (-300, -300),
#         'o..o...x.': (-300, -300),
#         'o..o...xx': (300, inf),
#         'o..o..x..': (-300, -300),
#         'o..o..x.x': (-300, -300),
#         'o..o..xox': (-inf, -300),
#         'o..o..xx.': (-300, -300),
#         'o..o..xxo': (-inf, -300),
#         'o..o.ox.x': (-inf, -300),
#         'o..o.oxx.': (-inf, -300),
#         'o..o.x...': (0.0, inf),
#         'o..o.x..x': (300, inf),
#         'o..o.x.ox': (-inf, 0.0),
#         'o..o.x.x.': (300, inf),
#         'o..o.xx..': (0.0, inf),
#         'o..o.xxo.': (-inf, -300),
#         'o..o.xxox': (-inf, 0.0),
#         'o..o.xxxo': (-inf, 300),
#         'o..oo..xx': (-inf, -300),
#         'o..oo.x.x': (-inf, -300),
#         'o..oo.xx.': (-inf, -300),
#         'o..oox..x': (-inf, -300),
#         'o..oox.xx': (300, inf),
#         'o..ooxx..': (-300, -300),
#         'o..ooxx.x': (-300, -300),
#         'o..ooxxox': (-300, -300),
#         'o..ooxxx.': (300, inf),
#         'o..ox....': (0.0, 0.0),
#         'o..ox...x': (300, inf),
#         'o..ox..ox': (-inf, 0.0),
#         'o..ox..x.': (300, inf),
#         'o..ox..xo': (-inf, -300),
#         'o..ox.x..': (0.0, 0.0),
#         'o..ox.x.o': (-inf, 0.0),
#         'o..ox.xo.': (-inf, -300),
#         'o..ox.xox': (0.0, 0.0),
#         'o..ox.xxo': (-inf, -300),
#         'o..oxo..x': (-inf, -300),
#         'o..oxo.xx': (300, inf),
#         'o..oxox..': (-inf, -300),
#         'o..oxox.x': (-inf, -300),
#         'o..oxoxox': (-inf, -300),
#         'o..oxoxx.': (-inf, -300),
#         'o..oxoxxo': (-inf, -300),
#         'o..oxx...': (300, inf),
#         'o..oxx..o': (-inf, 0.0),
#         'o..oxx.xo': (300, inf),
#         'o..oxxx.o': (-inf, 0.0),
#         'o..oxxxo.': (0.0, inf),
#         'o..oxxxoo': (-inf, -300),
#         'o..x.....': (300, 300),
#         'o..x....o': (-inf, 300),
#         'o..x...o.': (-inf, 300),
#         'o..x..o..': (0.0, 0.0),
#         'o..x..o.x': (0.0, inf),
#         'o..x..oox': (-300, -300),
#         'o..x..ox.': (300, 300),
#         'o..x..oxo': (-inf, -300),
#         'o..x..x.o': (-inf, 300),
#         'o..x..xo.': (300, 300),
#         'o..x..xoo': (-inf, -300),
#         'o..x.o...': (-inf, 300),
#         'o..x.oox.': (-inf, 300),
#         'o..x.ooxx': (300, 300),
#         'o..x.ox..': (-inf, 300),
#         'o..x.ox.o': (-inf, 300),
#         'o..x.oxo.': (300, 300),
#         'o..x.oxox': (300, inf),
#         'o..x.xo..': (300, inf),
#         'o..x.xoo.': (-300, -300),
#         'o..x.xoox': (-300, -300),
#         'o..x.xxoo': (300, inf),
#         'o..xo....': (0.0, 300),
#         'o..xo...x': (0.0, inf),
#         'o..xo..x.': (300, inf),
#         'o..xo.o.x': (0.0, inf),
#         'o..xo.ox.': (300, 300),
#         'o..xo.oxx': (300, 300),
#         'o..xo.x..': (300, 300),
#         'o..xo.xo.': (300, 300),
#         'o..xo.xox': (300, 300),
#         'o..xoo..x': (-inf, 0.0),
#         'o..xoooxx': (-inf, 0.0),
#         'o..xoox..': (-inf, 0.0),
#         'o..xoox.x': (-inf, 0.0),
#         'o..xooxox': (-inf, 0.0),
#         'o..xooxx.': (300, inf),
#         'o..xox...': (300, inf),
#         'o..xox.ox': (300, inf),
#         'o..xoxo..': (300, inf),
#         'o..xoxo.x': (300, inf),
#         'o..xoxoox': (-300, -300),
#         'o..xoxox.': (300, inf),
#         'o..xoxxo.': (300, inf),
#         'o..xx...o': (-inf, 0.0),
#         'o..xx..o.': (-inf, 0.0),
#         'o..xx..oo': (-inf, -300),
#         'o..xx.o..': (0.0, 0.0),
#         'o..xx.o.o': (-inf, -300),
#         'o..xx.oo.': (-300, -300),
#         'o..xx.oox': (0.0, 0.0),
#         'o..xx.oxo': (-inf, -300),
#         'o..xx.xoo': (-inf, -300),
#         'o..xxo..o': (-inf, 0.0),
#         'o..xxo.o.': (-inf, 0.0),
#         'o..xxo.ox': (0.0, inf),
#         'o..xxo.xo': (300, inf),
#         'o..xxoo..': (0.0, 0.0),
#         'o..xxoo.x': (0.0, 0.0),
#         'o..xxooox': (0.0, 0.0),
#         'o..xxoox.': (0.0, 0.0),
#         'o..xxooxo': (-inf, -300),
#         'o..xxox.o': (300, inf),
#         'o..xxoxo.': (300, inf),
#         'o..xxoxoo': (-inf, -300),
#         'o.o.....x': (0.0, inf),
#         'o.o....xx': (300, inf),
#         'o.o...oxx': (-inf, 300),
#         'o.o...x..': (0.0, inf),
# ...
#         'xo.xoxo.o': (300, inf),
#         'xo.xoxoxo': (300, 300),
#         'xo.xx..oo': (300, inf),
#         'xo.xx.o.o': (300, inf),
#         'xo.xx.oo.': (300, 300),
#         'xo.xxo.oo': (-inf, -300),
#         'xo.xxoo..': (300, inf),
#         'xo.xxoo.o': (300, inf),
#         'xo.xxooo.': (-inf, -300),
#         'xo.xxooxo': (300, 300),
#         'xoo......': (-300, -300),
#         'xoo.....x': (300, inf),
#         'xoo....x.': (0.0, inf),
#         'xoo....xo': (0.0, inf),
#         'xoo...x..': (-300, -300),
#         'xoo...x.o': (-inf, -300),
#         'xoo...xo.': (-inf, -300),
#         'xoo...xox': (300, inf),
#         'xoo...xxo': (300, inf),
#         'xoo..o..x': (-300, -300),
#         'xoo..o.x.': (-300, -300),
#         'xoo..o.xx': (-300, -300),
#         'xoo..ooxx': (-inf, -300),
#         'xoo..ox..': (-300, -300),
#         'xoo..ox.x': (-300, inf),
#         'xoo..oxox': (-inf, -300),
#         'xoo..oxx.': (-300, inf),
#         'xoo..x...': (300, inf),
#         'xoo..x..o': (-300, -300),
#         'xoo..x.xo': (0.0, 0.0),
#         'xoo..xoxo': (-inf, 0.0),
#         'xoo..xx.o': (0.0, 0.0),
#         'xoo..xxo.': (300, inf),
#         'xoo..xxoo': (-inf, 0.0),
#         'xoo.o...x': (300, inf),
#         'xoo.o..x.': (-300, -300),
#         'xoo.o..xx': (300, inf),
#         'xoo.o.x..': (-inf, -300),
#         'xoo.o.x.x': (300, inf),
#         'xoo.o.xx.': (-300, -300),
#         'xoo.o.xxo': (-inf, -300),
#         'xoo.oo.xx': (-300, -300),
#         'xoo.oox.x': (-300, -300),
#         'xoo.ooxx.': (-300, -300),
#         'xoo.ox...': (300, inf),
#         'xoo.ox..x': (300, inf),
#         'xoo.ox.x.': (300, inf),
#         'xoo.ox.xo': (0.0, 0.0),
#         'xoo.oxx..': (300, inf),
#         'xoo.oxx.o': (-300, -300),
#         'xoo.oxxxo': (0.0, 0.0),
#         'xoo.x....': (0.0, 0.0),
#         'xoo.x...o': (0.0, 0.0),
#         'xoo.x..o.': (-inf, -300),
#         'xoo.x..xo': (300, inf),
#         'xoo.x.o..': (-inf, 0.0),
#         'xoo.x.ox.': (-inf, 0.0),
#         'xoo.x.oxo': (-inf, 0.0),
#         'xoo.x.x.o': (300, inf),
#         'xoo.x.xo.': (-inf, -300),
#         'xoo.x.xoo': (-inf, -300),
#         'xoo.xo...': (-300, -300),
#         'xoo.xo.x.': (300, inf),
#         'xoo.xoox.': (-inf, -300),
#         'xoo.xox..': (300, inf),
#         'xoo.xoxo.': (-inf, -300),
#         'xoo.xx..o': (0.0, 0.0),
#         'xoo.xx.o.': (-inf, -300),
#         'xoo.xx.oo': (-300, -300),
#         'xoo.xxo..': (-inf, 0.0),
#         'xoo.xxo.o': (-inf, 0.0),
#         'xoo.xxoo.': (-inf, -300),
#         'xoo.xxoxo': (-inf, 0.0),
#         'xoo.xxxoo': (0.0, 0.0),
#         'xooo....x': (-inf, -300),
#         'xooo...x.': (-inf, -300),
#         'xooo...xx': (-inf, -300),
#         'xooo..oxx': (-inf, -300),
#         'xooo..x..': (-inf, -300),
#         'xooo..x.x': (-inf, -300),
#         'xooo..xox': (-inf, -300),
#         'xooo..xx.': (-inf, 0.0),
#         'xooo..xxo': (-inf, 0.0),
#         'xooo.o.xx': (-inf, -300),
#         'xooo.ox.x': (-inf, -300),
#         'xooo.oxx.': (-inf, -300),
#         'xooo.x...': (0.0, inf),
#         'xooo.x..x': (300, inf),
#         'xooo.x.x.': (0.0, inf),
#         'xooo.x.xo': (-inf, 0.0),
#         'xooo.xo.x': (-inf, -300),
#         'xooo.xoxx': (300, inf),
#         'xooo.xx..': (0.0, inf),
#         'xooo.xx.o': (0.0, 0.0),
#         'xooo.xxox': (300, inf),
#         'xooo.xxxo': (0.0, 0.0),
#         'xoooo..xx': (-inf, -300),
#         'xoooo.x.x': (-inf, -300),
#         'xoooo.xx.': (-300, -300),
#         'xoooox..x': (300, inf),
#         'xoooox.x.': (0.0, 0.0),
#         'xoooox.xx': (300, 300),
#         'xooooxx..': (0.0, 0.0),
#         'xooooxx.x': (300, inf),
#         'xooooxxx.': (0.0, 0.0),
#         'xooox....': (-inf, -300),
#         'xooox..x.': (0.0, inf),
#         'xooox..xo': (0.0, 0.0),
#         'xooox.ox.': (-inf, -300),
#         'xooox.x..': (0.0, 0.0),
#         'xooox.x.o': (0.0, 0.0),
#         'xooox.xo.': (-inf, -300),
#         'xooox.xxo': (300, 300),
#         'xoooxo.x.': (-300, -300),
#         'xoooxox..': (-300, -300),
#         'xoooxoxx.': (300, inf),
#         'xoooxx...': (0.0, 0.0),
#         'xoooxx..o': (0.0, 0.0),
#         'xoooxx.o.': (-inf, -300),
#         'xoooxx.xo': (0.0, 0.0),
#         'xoooxxo..': (-inf, -300),
#         'xoooxxx.o': (0.0, 0.0),
#         'xoooxxxo.': (0.0, 0.0),
#         'xoox.....': (-300, -300),
#         'xoox....o': (-inf, -300),
#         'xoox...o.': (-inf, -300),
#         'xoox...xo': (300, inf),
#         'xoox..o..': (-inf, -300),
#         'xoox..ox.': (-inf, 300),
#         'xoox..oxo': (300, 300),
#         'xoox.o...': (-300, -300),
#         'xoox.o..x': (-300, -300),
#         'xoox.o.ox': (-inf, -300),
#         'xoox.o.x.': (300, inf),
#         'xoox.oo.x': (-inf, -300),
#         'xoox.oox.': (300, 300),
#         'xoox.ooxx': (300, inf),
#         'xoox.x..o': (-300, -300),
#         'xoox.x.o.': (300, inf),
#         'xoox.x.oo': (-inf, -300),
#         'xoox.xo..': (300, inf),
#         'xoox.xo.o': (-inf, -300),
#         'xoox.xoxo': (300, inf),
#         'xooxo....': (-inf, -300),
#         'xooxo...x': (300, inf),
#         'xooxo..x.': (300, inf),
#         'xooxo..xo': (-inf, -300),
#         'xooxoo..x': (-300, -300),
#         'xooxoo.x.': (-300, -300),
#         'xooxoo.xx': (300, inf),
#         'xooxox...': (300, inf),
#         'xooxox..o': (-300, -300),
#         'xooxox.xo': (300, inf),
#         'xooxx...o': (300, inf),
#         'xooxx..o.': (-inf, -300),
#         'xooxx..oo': (-inf, -300),
#         'xooxx.o..': (-inf, -300),
#         'xooxx.o.o': (-inf, -300),
#         'xooxx.oo.': (-inf, -300),
#         'xooxx.oxo': (300, 300),
#         'xooxxo...': (300, inf),
#         'xooxxo.o.': (-inf, -300),
#         'xooxxoo..': (-inf, -300),
#         'xooxxoox.': (300, 300),
#         'xox.....o': (300, 300),
#         'xox....o.': (300, 300),
#         'xox....oo': (300, 300),
#         'xox...o..': (300, 300),
#         'xox...o.o': (-inf, 300),
#         'xox...oo.': (300, 300),
#         'xox...oox': (300, inf),
#         'xox...xoo': (300, inf),
#         'xox..o...': (300, 300),
#         'xox..o..o': (-inf, -300),
#         'xox..o.o.': (-inf, -300),
#         'xox..o.xo': (0.0, inf),
#         'xox..oo..': (-inf, 0.0),
#         'xox..ooox': (-inf, -300),
#         'xox..ooxo': (0.0, 0.0),
#         'xox..ox.o': (-inf, -300),
#         'xox..oxoo': (-inf, -300),
#         'xox..x.oo': (300, 300),
#         'xox..xo.o': (300, 300),
#         'xox..xoo.': (300, inf),
#         'xox.o....': (300, 300),
#         'xox.o...o': (-inf, 0.0),
#         'xox.o..xo': (-inf, 0.0),
#         'xox.o.o..': (-inf, 0.0),
#         'xox.o.ox.': (-inf, 0.0),
#         'xox.o.oxo': (0.0, 0.0),
#         'xox.oo...': (300, 300),
#         'xox.oo..x': (300, inf),
#         'xox.oo.x.': (300, inf),
#         'xox.oo.xo': (0.0, 0.0),
#         'xox.ooox.': (-inf, 0.0),
#         'xox.oooxx': (300, 300),
#         'xox.oox..': (300, inf),
#         'xox.oox.o': (-inf, -300),
#         'xox.ooxxo': (300, inf),
#         'xox.ox..o': (300, 300),
#         'xox.oxo..': (300, inf),
#         'xox.oxo.o': (-inf, 0.0),
#         'xox.oxoxo': (0.0, 0.0),
#         'xox.x..oo': (300, inf),
#         'xox.x.o.o': (300, inf),
#         'xox.x.oo.': (300, inf),
#         'xox.xo..o': (0.0, 0.0),
#         'xox.xo.o.': (-inf, -300),
#         'xox.xo.oo': (-300, -300),
#         'xox.xoo..': (0.0, 0.0),
#         'xox.xoo.o': (0.0, 0.0),
#         'xox.xooo.': (-inf, -300),
#         'xox.xooxo': (0.0, 0.0),
#         'xoxo.....': (300, 300),
#         'xoxo....o': (-inf, 0.0),
#         'xoxo...o.': (-inf, -300),
#         'xoxo..o..': (-inf, -300),
#         'xoxo..o.x': (-inf, -300),
#         'xoxo..oox': (-inf, -300),
#         'xoxo..ox.': (0.0, inf),
#         'xoxo..oxo': (0.0, 0.0),
#         'xoxo..xoo': (-inf, -300),
#         'xoxo.o...': (-inf, -300),
#         'xoxo.oo.x': (-inf, -300),
#         'xoxo.ooxx': (300, inf),
#         'xoxo.ox.o': (-inf, -300),
#         'xoxo.oxxo': (300, inf),
#         'xoxo.x..o': (300, inf),
#         'xoxo.x.oo': (300, 300),
#         'xoxo.xo..': (-inf, 0.0),
#         'xoxo.xo.o': (-inf, 0.0),
#         'xoxo.xoo.': (-inf, -300),
#         'xoxo.xoxo': (0.0, 0.0),
#         'xoxo.xxoo': (300, inf),
#         'xoxoo....': (300, 300),
#         'xoxoo...x': (300, inf),
#         'xoxoo..x.': (300, inf),
#         'xoxoo..xo': (-inf, 0.0),
#         'xoxoo.o.x': (-inf, -300),
#         'xoxoo.ox.': (0.0, 0.0),
#         'xoxoo.oxx': (300, inf),
#         'xoxoo.x..': (300, inf),
#         'xoxoo.xxo': (300, 300),
#         'xoxoox...': (300, 300),
#         'xoxoox..o': (-inf, 0.0),
#         'xoxoox.xo': (-inf, 0.0),
#         'xoxooxo..': (-300, -300),
#         'xoxooxox.': (0.0, 0.0),
#         'xoxooxx.o': (300, 300),
#         'xoxox...o': (0.0, 0.0),
#         'xoxox..o.': (-inf, -300),
#         'xoxox..oo': (-inf, -300),
#         'xoxox.o..': (0.0, 0.0),
#         'xoxox.o.o': (0.0, 0.0),
#         'xoxox.oo.': (-300, -300),
#         'xoxox.oxo': (0.0, 0.0),
#         'xoxoxo...': (-inf, -300),
#         'xoxoxo..o': (-inf, -300),
#         'xoxoxo.o.': (-inf, -300),
#         'xoxoxo.xo': (0.0, 0.0),
#         'xoxoxoo..': (-inf, -300),
#         'xoxoxoox.': (0.0, 0.0),
#         'xoxoxx.oo': (300, 300),
#         'xoxoxxo.o': (300, 300),
#         'xoxoxxoo.': (300, inf),
#         'xoxx...oo': (300, inf),
#         'xoxx..o.o': (300, 300),
#         'xoxx..oo.': (300, 300),
#         'xoxx.o..o': (-inf, 0.0),
#         'xoxx.o.oo': (-inf, -300),
#         'xoxx.oo..': (300, inf),
#         'xoxx.oo.o': (-inf, 0.0),
#         'xoxx.ooo.': (300, 300),
#         'xoxx.ooox': (300, inf),
#         'xoxx.ooxo': (0.0, 0.0),
#         'xoxxo...o': (300, inf),
#         'xoxxo.o..': (300, 300),
#         'xoxxo.o.o': (-inf, 0.0),
#         'xoxxo.oxo': (0.0, 0.0),
#         'xoxxoo...': (300, 300),
#         'xoxxoo..o': (-300, -300),
#         'xoxxoo.xo': (0.0, 0.0),
#         'xoxxooo..': (-inf, 0.0),
#         'xoxxooo.x': (300, 300),
#         'xoxxooox.': (-inf, 0.0),
#         'xoxxoxo.o': (300, 300),
#         'xoxxxo.oo': (300, inf),
#         'xoxxxoo.o': (300, 300),
#         'xoxxxooo.': (300, 300),
#         'xx.....oo': (300, inf),
#         'xx....o.o': (300, inf),
#         'xx....oo.': (300, inf),
#         'xx...o..o': (300, inf),
#         'xx...ooox': (-inf, -300),
#         'xx...ooxo': (-300, inf),
#         'xx...oxoo': (-300, inf),
#         'xx..o...o': (300, 300),
#         'xx..o..o.': (-inf, 0.0),
#         'xx..o..oo': (-inf, -300),
#         'xx..o.o..': (300, inf),
#         'xx..o.o.o': (-inf, -300),
#         'xx..o.oo.': (-inf, -300),
#         'xx..o.oox': (300, inf),
#         'xx..o.oxo': (300, inf),
#         'xx..o.xoo': (-300, -300),
#         'xx..oo...': (300, 300),
#         'xx..oo..o': (-inf, -300),
#         'xx..oo.o.': (-inf, -300),
#         'xx..oo.ox': (300, inf),
#         'xx..oo.xo': (300, inf),
#         'xx..ooo..': (-inf, -300),
#         'xx..oooox': (-inf, -300),
#         'xx..oooxo': (-300, -300),
#         'xx..oox.o': (300, inf),
#         'xx..ooxoo': (-300, -300),
#         'xx..ox.oo': (300, inf),
#         'xx..oxoo.': (300, inf),
#         'xx.o....o': (300, inf),
#         'xx.o...o.': (300, inf),
#         'xx.o...oo': (-inf, 0.0),
#         'xx.o..o..': (-300, -300),
#         'xx.o..o.o': (-inf, -300),
#         'xx.o..oo.': (-300, -300),
#         'xx.o..oox': (-300, -300),
#         'xx.o..oxo': (-300, -300),
#         'xx.o..xoo': (-inf, 0.0),
#         'xx.o.o...': (300, inf),
#         'xx.o.oo..': (-inf, -300),
#         'xx.o.ooox': (-inf, -300),
#         'xx.o.oox.': (300, inf),
#         'xx.o.ooxo': (-inf, -300),
#         'xx.o.ox.o': (300, inf),
#         'xx.o.oxoo': (-inf, -300),
#         'xx.o.xo.o': (300, inf),
#         'xx.o.xoo.': (300, inf),
#         'xx.oo....': (300, inf),
#         'xx.oo...o': (-inf, -300),
#         'xx.oo..o.': (-inf, -300),
#         'xx.oo..xo': (300, inf),
#         'xx.oo.o..': (-inf, -300),
#         'xx.oo.o.x': (300, inf),
#         'xx.oo.oox': (-300, -300),
#         'xx.oo.ox.': (300, inf),
#         'xx.oo.oxo': (-300, -300),
#         'xx.oo.x.o': (300, inf),
#         'xx.oo.xo.': (300, 300),
#         'xx.oo.xoo': (-300, -300),
#         'xx.oox.o.': (-inf, 0.0),
#         'xx.oox.oo': (-inf, 0.0),
#         'xx.ooxo..': (300, inf),
#         'xx.ooxo.o': (-inf, -300),
#         'xx.ooxoo.': (-300, -300),
#         'xx.ooxoox': (300, inf),
#         'xx.ooxoxo': (300, inf),
#         'xx.ooxxoo': (0.0, 0.0),
#         'xx.ox.o.o': (300, inf),
#         'xx.ox.oo.': (300, inf),
#         'xx.oxo..o': (300, inf),
#         'xx.oxo.oo': (-inf, -300),
#         'xx.oxoo..': (-inf, -300),
#         'xx.oxoo.o': (-inf, -300),
#         'xx.oxooo.': (-inf, -300),
#         'xx.oxoxoo': (300, inf),
#         'xx.xo..oo': (300, inf),
#         'xx.xo.o.o': (300, inf),
#         'xx.xo.oo.': (300, 300),
#         'xx.xoo..o': (300, inf),
#         'xx.xooo..': (300, inf),
#         'xx.xoooo.': (-inf, 300),
#         'xx.xoooox': (300, 300),
#         'xx.xoooxo': (300, inf),
#         'xxo.....o': (300, 300),
#         'xxo....o.': (-inf, 300),
#         'xxo....oo': (-inf, 300),
#         'xxo...o..': (-inf, 300),
#         'xxo...o.o': (-inf, 300),
#         'xxo...oo.': (-inf, 300),
#         'xxo...xoo': (300, inf),
#         'xxo..o...': (300, 300),
#         'xxo..o.o.': (-inf, 300),
#         'xxo..o.ox': (300, inf),
#         'xxo..oo..': (-inf, 300),
#         'xxo..ooox': (-inf, -300),
#         'xxo..x.oo': (300, 300),
#         'xxo..xo.o': (-inf, 300),
#         'xxo..xoo.': (-inf, 300),
#         'xxo.o....': (300, 300),
#         'xxo.o...o': (300, 300),
#         'xxo.o..o.': (-inf, 0.0),
#         'xxo.o..xo': (300, inf),
#         'xxo.o.x.o': (300, inf),
#         'xxo.o.xo.': (-inf, 0.0),
#         'xxo.o.xoo': (-inf, -300),
#         'xxo.oo...': (300, 300),
#         'xxo.oo..x': (300, inf),
#         'xxo.oo.ox': (300, inf),
#         'xxo.oo.x.': (300, inf),
#         'xxo.oox..': (300, inf),
#         'xxo.ooxo.': (-inf, -300),
#         'xxo.ooxox': (300, inf),
#         'xxo.ox..o': (300, 300),
#         'xxo.ox.o.': (-inf, 300),
#         'xxo.ox.oo': (0.0, 0.0),
#         'xxo.oxxoo': (0.0, 0.0),
#         'xxo.x.o.o': (300, inf),
#         'xxo.x.oo.': (300, inf),
#         'xxo.xo.o.': (-inf, 300),
#         'xxo.xoo..': (300, 300),
#         'xxo.xooo.': (-inf, -300),
#         'xxoo.....': (300, 300),
#         'xxoo....o': (300, 300),
#         'xxoo...o.': (300, 300),
#         'xxoo...ox': (300, inf),
#         'xxoo...xo': (300, inf),
#         'xxoo..o..': (-inf, -300),
#         'xxoo..oox': (-inf, -300),
#         'xxoo..ox.': (300, inf),
#         'xxoo..oxo': (-inf, -300),
#         'xxoo..x.o': (300, 300),
#         'xxoo..xo.': (300, inf),
#         'xxoo..xoo': (-inf, 0.0),
#         'xxoo.o...': (-inf, 300),
#         'xxoo.ox..': (300, 300),
#         'xxoo.oxo.': (300, 300),
#         'xxoo.oxox': (300, inf),
#         'xxoo.x..o': (300, 300),
#         'xxoo.x.o.': (300, 300),
#         'xxoo.x.oo': (-inf, 300),
#         'xxoo.xo..': (-inf, 300),
#         'xxoo.xo.o': (300, 300),
#         'xxoo.xoo.': (300, 300),
#         'xxoo.xoox': (300, inf),
#         'xxoo.xoxo': (300, inf),
#         'xxoo.xxoo': (0.0, 0.0),
#         'xxooo....': (300, 300),
#         'xxooo...x': (300, inf),
#         'xxooo..ox': (300, inf),
#         'xxooo..x.': (300, inf),
#         'xxooo..xo': (300, inf),
#         'xxooo.x..': (300, 300),
#         'xxooo.x.o': (-inf, 0.0),
#         'xxooo.xo.': (-inf, 0.0),
#         'xxooo.xox': (300, 300),
#         'xxooo.xxo': (300, 300),
#         'xxooox...': (300, 300),
#         'xxooox..o': (-inf, 0.0),
#         'xxooox.o.': (-inf, 0.0),
#         'xxooox.ox': (300, 300),
#         'xxooox.xo': (300, 300),
#         'xxoooxx.o': (0.0, 0.0),
#         'xxoooxxo.': (-inf, 0.0),
#         'xxoox...o': (300, inf),
#         'xxoox..o.': (300, inf),
#         'xxoox..oo': (300, inf),
#         'xxoox.o..': (-inf, -300),
#         'xxoox.o.o': (-inf, -300),
#         'xxoox.oo.': (-inf, -300),
#         'xxoox.xoo': (300, 300),
#         'xxooxo...': (300, 300),
#         'xxooxo.o.': (-inf, -300),
#         'xxooxoo..': (-inf, -300),
#         'xxooxoxo.': (300, 300),
#         'xxooxx.oo': (300, 300),
#         'xxooxxo.o': (300, 300),
#         'xxooxxoo.': (300, 300),
#         'xxox.ooox': (300, inf),
#         'xxoxo...o': (300, inf),
#         'xxoxo..o.': (300, inf),
#         'xxoxoo...': (300, 300),
#         'xxoxoo.o.': (-inf, 300),
#         'xxoxoo.ox': (300, 300),
#         'xxoxox.oo': (300, inf),
#         'xxoxxooo.': (300, 300)}}

# %%
@ai_by_mmscore
def ai_abs_dls(mb, debug=False, timelimit_pc=None, maxdepth=1, eval_func=None,
               eval_params={}, use_tt=False, tt=None):           
    count = 0
    def ab_search(mborig, depth, tt, alpha=float("-inf"), beta=float("inf")):
        nonlocal count
        if timelimit_pc is not None and perf_counter() >= timelimit_pc:
            raise RuntimeError("time out")
        
        count += 1
        if mborig.status != Marubatsu.PLAYING or depth == maxdepth:
            return eval_func(mborig, calc_score=True, **eval_params)
        
        if use_tt:
            boardtxt = mborig.board_to_str()
            if boardtxt in tt:
                lower_bound, upper_bound, _ = tt[boardtxt]
                if lower_bound == upper_bound:
                    return lower_bound
                elif upper_bound <= alpha:
                    return upper_bound
                elif beta <= lower_bound:
                    return lower_bound
                else:
                    alpha = max(alpha, lower_bound)
                    beta = min(beta, upper_bound)
            else:
                lower_bound = min_score
                upper_bound = max_score
        
        alphaorig = alpha
        betaorig = beta

        legal_moves = mborig.calc_legal_moves()
        if mborig.turn == Marubatsu.CIRCLE:
            score = float("-inf")
            for x, y in legal_moves:
                mb = deepcopy(mborig)
                mb.move(x, y)
                abscore = ab_search(mb, depth + 1, tt, alpha, beta)
                if abscore > score:
                    bestmove = (x, y)
                score = max(score, abscore)
                if score >= beta:
                    break
                alpha = max(alpha, score)
        else:
            score = float("inf")
            for x, y in legal_moves:
                mb = deepcopy(mborig)
                mb.move(x, y)
                abscore = ab_search(mb, depth + 1, tt, alpha, beta)
                if abscore < score:
                    bestmove = (x, y)
                score = min(score, abscore)
                if score <= alpha:
                    break
                beta = min(beta, score)   
            
        from util import calc_same_boardtexts

        if use_tt:
            boardtxtlist = calc_same_boardtexts(mborig)
            if score <= alphaorig:
                upper_bound = score
            elif score < betaorig:
                lower_bound = score
                upper_bound = score
            else:
                lower_bound = score
            for boardtxt in boardtxtlist:
                tt[boardtxt] = (lower_bound, upper_bound, bestmove)
        return score
                
    min_score = float("-inf")
    max_score = float("inf")
    
    if tt is None:
        tt = {}
    score = ab_search(mb, depth=0, tt=tt, alpha=min_score, beta=max_score)
    dprint(debug, "count =", count)
    return score, count

# %%
result = ai_abs_dls(mb, maxdepth=9, eval_func=ai14s, eval_params=eval_params, 
                    use_tt=True, analyze=True)
tt = result["tt"]
pprint(tt)
# Out:
# {'........o': (0.0, 0.0, (1, 1)),
#  '.......o.': (0.0, 0.0, (0, 0)),
#  '.......ox': (0.0, 0.0, (0, 1)),
#  '.......xo': (300, 300, (0, 1)),
#  '......o..': (0.0, 0.0, (1, 1)),
#  '......o.x': (300, inf, (0, 1)),
#  '......oox': (-300, -300, (2, 1)),
#  '......ox.': (300, 300, (0, 1)),
#  '......oxo': (0.0, 0.0, (1, 1)),
#  '......x.o': (300, inf, (0, 1)),
#  '......xo.': (0.0, 0.0, (0, 1)),
#  '......xoo': (-300, -300, (2, 1)),
#  '.....o...': (0.0, 0.0, (0, 0)),
#  '.....o..x': (0.0, 0.0, (0, 1)),
#  '.....o.ox': (0.0, 0.0, (1, 1)),
#  '.....o.x.': (300, inf, (0, 0)),
#  '.....o.xo': (300, 300, (2, 0)),
#  '.....oo.x': (-inf, 0.0, (1, 1)),
#  '.....oox.': (-inf, 300, (2, 0)),
#  '.....ooxx': (300, 300, (1, 1)),
#  '.....ox..': (300, inf, (0, 0)),
#  '.....ox.o': (300, inf, (1, 0)),
#  '.....oxo.': (-inf, 0.0, (1, 1)),
#  '.....oxox': (300, 300, (1, 1)),
#  '.....oxxo': (300, 300, (1, 1)),
#  '.....x..o': (300, 300, (0, 1)),
#  '.....x.o.': (300, inf, (0, 0)),
#  '.....x.oo': (300, 300, (2, 0)),
#  '.....xo..': (300, inf, (2, 0)),
#  '.....xo.o': (300, 300, (1, 0)),
#  '.....xoo.': (-300, -300, (2, 0)),
#  '.....xoox': (-300, -300, (0, 1)),
#  '.....xoxo': (300, 300, (1, 1)),
#  '.....xxoo': (300, inf, (1, 1)),
#  '....o....': (0.0, 0.0, (0, 0)),
#  '....o...x': (0.0, 0.0, (1, 0)),
#  '....o..ox': (0.0, 0.0, (1, 2)),
#  '....o..x.': (0.0, inf, (0, 0)),
#  '....o..xo': (0.0, 300, (2, 2)),
#  '....o.o.x': (-inf, 0.0, (0, 2)),
#  '....o.ox.': (0.0, 300, (2, 2)),
#  '....o.oxx': (300, 300, (0, 1)),
#  '....o.x..': (0.0, 0.0, (1, 0)),
#  '....o.x.o': (-inf, 0.0, (0, 2)),
#  '....o.xo.': (0.0, 0.0, (1, 2)),
#  '....o.xox': (300, 300, (0, 1)),
#  '....o.xxo': (300, 300, (0, 1)),
#  '....oo..x': (0.0, 0.0, (1, 2)),
#  '....oo.xx': (300, inf, (0, 2)),
#  '....oooxx': (300, 300, (2, 0)),
#  '....oox..': (-inf, 0.0, (0, 1)),
#  '....oox.x': (300, inf, (0, 1)),
#  '....ooxox': (300, 300, (2, 1)),
#  '....ooxx.': (300, 300, (2, 0)),
#  '....ooxxo': (300, 300, (2, 1)),
#  '....ox...': (0.0, inf, (0, 0)),
#  '....ox..o': (0.0, 300, (2, 2)),
#  '....ox.ox': (300, inf, (0, 2)),
#  '....ox.xo': (300, inf, (2, 0)),
#  '....oxo.x': (300, inf, (0, 2)),
#  '....oxoox': (-inf, -300, (2, 2)),
#  '....oxox.': (300, inf, (2, 0)),
#  '....oxoxo': (300, 300, (2, 1)),
#  '....oxx.o': (300, inf, (1, 0)),
#  '....oxxo.': (300, inf, (2, 0)),
#  '....oxxoo': (300, inf, (2, 0)),
#  '....x...o': (0.0, 0.0, (1, 0)),
#  '....x..o.': (0.0, inf, (0, 0)),
#  '....x..oo': (0.0, 0.0, (2, 0)),
#  '....x.o..': (0.0, 0.0, (1, 0)),
#  '....x.o.o': (-inf, 0.0, (1, 0)),
#  '....x.oo.': (0.0, 0.0, (2, 0)),
#  '....x.oox': (0.0, 0.0, (0, 2)),
#  '....x.oxo': (0.0, 0.0, (1, 2)),
#  '....x.xoo': (0.0, 0.0, (0, 2)),
#  '....xo...': (0.0, inf, (0, 0)),
#  '....xo..o': (0.0, 0.0, (2, 0)),
#  '....xo.ox': (0.0, 0.0, (2, 2)),
#  '....xo.xo': (300, inf, (0, 2)),
#  '....xoo..': (-inf, 0.0, (1, 0)),
#  '....xoo.x': (-inf, 0.0, (2, 0)),
#  '....xooox': (-inf, -300, (0, 2)),
#  '....xoox.': (-inf, 0.0, (0, 2)),
#  '....xooxo': (-300, -300, (1, 2)),
#  '....xox.o': (300, inf, (0, 2)),
#  '....xoxo.': (-inf, 0.0, (0, 2)),
#  '....xoxoo': (-300, -300, (0, 2)),
#  '....xx.oo': (300, inf, (0, 2)),
#  '....xxo.o': (300, inf, (1, 0)),
#  '....xxoo.': (300, inf, (2, 0)),
#  '...o.....': (0.0, 0.0, (0, 0)),
#  '...o....x': (300, inf, (0, 0)),
#  '...o...ox': (-inf, 0.0, (1, 1)),
#  '...o...x.': (300, inf, (0, 0)),
#  '...o...xo': (-inf, 300, (2, 0)),
#  '...o..o.x': (300, inf, (1, 0)),
#  '...o..ox.': (300, 300, (2, 0)),
#  '...o..oxx': (300, 300, (1, 1)),
#  '...o..x..': (0.0, 0.0, (0, 1)),
#  '...o..x.o': (-inf, 0.0, (1, 1)),
#  '...o..xo.': (0.0, 0.0, (1, 1)),
#  '...o..xox': (300, 300, (1, 1)),
#  '...o..xxo': (300, 300, (1, 1)),
#  '...o.o..x': (-inf, -300, (1, 1)),
#  '...o.o.xx': (300, inf, (1, 1)),
#  '...o.ooxx': (-inf, 300, (1, 1)),
#  '...o.ox..': (-inf, -300, (1, 1)),
#  '...o.oxox': (-inf, -300, (1, 1)),
#  '...o.oxx.': (300, inf, (1, 1)),
#  '...o.oxxo': (-inf, 300, (1, 1)),
#  '...o.x...': (0.0, inf, (0, 0)),
#  '...o.x..o': (-inf, 300, (2, 0)),
#  '...o.x.ox': (300, inf, (0, 2)),
#  '...o.xo..': (0.0, inf, (2, 0)),
#  '...o.xo.x': (300, inf, (0, 2)),
#  '...o.xoox': (-300, -300, (0, 2)),
#  '...o.xox.': (300, inf, (1, 1)),
#  '...o.xoxo': (-inf, 0.0, (0, 2)),
#  '...o.xxo.': (0.0, inf, (2, 0)),
#  '...o.xxoo': (0.0, inf, (1, 1)),
#  '...oo...x': (-inf, 0.0, (0, 1)),
#  '...oo..xx': (300, 300, (2, 0)),
#  '...oo.oxx': (300, 300, (2, 1)),
#  '...oo.x..': (0.0, 0.0, (1, 2)),
#  '...oo.x.x': (300, inf, (0, 1)),
#  '...oo.xox': (300, 300, (2, 1)),
#  '...oo.xx.': (300, inf, (0, 2)),
#  '...oo.xxo': (300, 300, (2, 0)),
#  '...oox..x': (-inf, 0.0, (0, 2)),
#  '...oox.ox': (-inf, -300, (0, 2)),
#  '...ooxo.x': (-inf, -300, (2, 2)),
#  '...ooxox.': (300, inf, (2, 0)),
#  '...ooxoxx': (300, 300, (0, 2)),
#  '...ooxx..': (0.0, 0.0, (0, 1)),
#  '...ooxx.o': (-inf, 0.0, (2, 0)),
#  '...ooxxo.': (0.0, 0.0, (2, 1)),
#  '...ooxxox': (300, 300, (1, 2)),
#  '...ooxxxo': (300, 300, (2, 0)),
#  '...ox....': (0.0, inf, (0, 0)),
#  '...ox...o': (-inf, 0.0, (1, 0)),
#  '...ox..ox': (-inf, 0.0, (0, 2)),
#  '...ox..xo': (-inf, 0.0, (0, 2)),
#  '...ox.o..': (0.0, 0.0, (2, 0)),
#  '...ox.o.x': (300, inf, (0, 2)),
#  '...ox.oox': (-300, -300, (0, 2)),
#  '...ox.ox.': (300, inf, (0, 2)),
#  '...ox.oxo': (-300, -300, (1, 2)),
#  '...ox.x.o': (-inf, 0.0, (2, 0)),
#  '...ox.xo.': (0.0, 0.0, (2, 2)),
#  '...ox.xoo': (-inf, -300, (0, 2)),
#  '...oxo..x': (-inf, -300, (2, 0)),
#  '...oxo.ox': (-inf, -300, (2, 0)),
#  '...oxo.xo': (-inf, -300, (0, 2)),
#  '...oxoo.x': (-inf, -300, (0, 2)),
#  '...oxoox.': (-inf, -300, (0, 2)),
#  '...oxooxx': (300, 300, (0, 2)),
#  '...oxox..': (-inf, -300, (2, 0)),
#  '...oxox.o': (-inf, -300, (0, 2)),
#  '...oxoxo.': (-inf, -300, (2, 0)),
#  '...oxoxox': (-inf, -300, (0, 2)),
#  '...oxoxxo': (300, 300, (0, 2)),
#  '...oxxo..': (300, inf, (2, 0)),
#  '...oxxoox': (300, inf, (0, 2)),
#  '...oxxoxo': (300, 300, (0, 2)),
#  '...oxxxoo': (0.0, 0.0, (0, 2)),
#  '...x....o': (300, inf, (2, 0)),
#  '...x...o.': (300, inf, (0, 0)),
#  '...x...oo': (-300, -300, (2, 0)),
#  '...x..o..': (300, 300, (0, 1)),
#  '...x..o.o': (300, 300, (1, 0)),
#  '...x..oo.': (300, 300, (2, 0)),
#  '...x..oox': (300, inf, (1, 1)),
#  '...x..oxo': (300, 300, (1, 1)),
#  '...x..xoo': (-300, -300, (0, 1)),
#  '...x.o...': (0.0, inf, (0, 0)),
#  '...x.o..o': (0.0, inf, (2, 0)),
#  '...x.o.ox': (0.0, inf, (2, 0)),
#  '...x.o.xo': (300, inf, (1, 1)),
#  '...x.oo..': (-inf, 300, (2, 0)),
#  '...x.ooox': (0.0, inf, (1, 1)),
#  '...x.ooxo': (-inf, 0.0, (0, 2)),
#  '...x.ox.o': (300, inf, (0, 2)),
#  '...x.oxo.': (300, inf, (0, 2)),
#  '...x.oxoo': (-300, -300, (0, 2)),
#  '...x.x.oo': (300, inf, (1, 1)),
#  '...x.xo.o': (300, inf, (1, 0)),
#  '...x.xoo.': (300, inf, (1, 1)),
#  '...xo....': (0.0, inf, (0, 0)),
#  '...xo..ox': (300, inf, (2, 0)),
#  '...xo..xo': (300, inf, (2, 0)),
#  '...xo.o..': (0.0, 300, (2, 2)),
#  '...xo.o.x': (300, inf, (1, 0)),
#  '...xo.oox': (300, inf, (2, 0)),
#  '...xo.ox.': (300, inf, (2, 0)),
#  '...xo.oxo': (300, 300, (2, 1)),
#  '...xo.x.o': (300, inf, (0, 2)),
#  '...xo.xo.': (300, inf, (0, 2)),
#  '...xo.xoo': (-inf, -300, (2, 2)),
#  '...xoo..x': (0.0, 0.0, (0, 1)),
#  '...xoo.ox': (0.0, 0.0, (2, 1)),
#  '...xoo.xo': (300, inf, (2, 0)),
#  '...xooo.x': (-inf, 0.0, (2, 0)),
#  '...xoooxx': (300, 300, (2, 0)),
#  '...xoox..': (-inf, 0.0, (0, 2)),
#  '...xoox.o': (-inf, -300, (2, 2)),
#  '...xooxo.': (-inf, -300, (0, 2)),
#  '...xooxox': (300, 300, (1, 2)),
#  '...xooxxo': (300, 300, (0, 2)),
#  '...xox..o': (300, inf, (2, 0)),
#  '...xox.oo': (300, inf, (2, 0)),
#  '...xoxo..': (300, inf, (2, 0)),
#  '...xoxoo.': (300, inf, (2, 0)),
#  '...xoxoox': (300, inf, (2, 1)),
#  '...xoxoxo': (300, 300, (0, 2)),
#  '...xoxxoo': (300, inf, (2, 1)),
#  '...xx..oo': (300, inf, (2, 0)),
#  '...xx.o.o': (300, inf, (1, 0)),
#  '...xx.oo.': (300, inf, (0, 2)),
#  '...xxo..o': (300, inf, (2, 0)),
#  '...xxooox': (0.0, 0.0, (0, 2)),
#  '...xxooxo': (300, 300, (0, 2)),
#  '...xxoxoo': (300, inf, (0, 2)),
#  '..o......': (0.0, 0.0, (1, 1)),
#  '..o.....x': (300, inf, (0, 1)),
#  '..o....ox': (-inf, 0.0, (1, 1)),
#  '..o....x.': (300, inf, (2, 0)),
#  '..o....xo': (300, 300, (1, 0)),
#  '..o...ox.': (-inf, 300, (2, 0)),
#  '..o...oxx': (-inf, 300, (0, 1)),
#  '..o...x..': (0.0, inf, (2, 0)),
#  '..o...x.o': (0.0, inf, (1, 0)),
#  '..o...xo.': (-inf, 0.0, (1, 1)),
#  '..o...xox': (300, 300, (1, 2)),
#  '..o...xxo': (300, 300, (1, 0)),
#  '..o..o..x': (-300, -300, (2, 1)),
#  '..o..o.x.': (-300, -300, (2, 0)),
#  '..o..o.xx': (-300, -300, (0, 1)),
#  '..o..ooxx': (-inf, -300, (1, 1)),
#  '..o..ox..': (-300, -300, (2, 0)),
#  '..o..ox.x': (-300, -300, (0, 1)),
#  '..o..oxox': (-inf, -300, (0, 2)),
#  '..o..oxx.': (300, inf, (2, 0)),
#  '..o..x...': (300, 300, (0, 1)),
#  '..o..x..o': (0.0, 0.0, (1, 1)),
#  '..o..x.o.': (-inf, 300, (2, 0)),
#  '..o..x.ox': (300, 300, (1, 1)),
#  '..o..x.xo': (300, 300, (1, 1)),
#  '..o..xo..': (-inf, 300, (2, 0)),
#  '..o..xo.x': (-inf, 300, (0, 1)),
#  '..o..xoox': (-inf, -300, (1, 1)),
#  '..o..xoxo': (-inf, -300, (1, 1)),
#  '..o..xx.o': (0.0, inf, (1, 1)),
#  '..o..xxoo': (-300, -300, (1, 2)),
#  '..o.o...x': (-inf, 0.0, (0, 2)),
#  '..o.o..xx': (300, inf, (0, 2)),
#  '..o.o.x..': (-inf, 0.0, (2, 0)),
#  '..o.o.x.x': (-inf, 0.0, (0, 1)),
#  '..o.o.xox': (-inf, 0.0, (1, 2)),
#  '..o.o.xx.': (300, 300, (2, 0)),
#  '..o.o.xxo': (300, 300, (0, 1)),
#  '..o.oo.xx': (-inf, -300, (2, 2)),
#  '..o.oox.x': (-inf, -300, (2, 1)),
#  '..o.ooxx.': (-inf, -300, (2, 0)),
#  '..o.ox...': (0.0, 300, (2, 2)),
#  '..o.ox..x': (300, 300, (0, 1)),
#  '..o.ox.ox': (300, 300, (2, 0)),
#  '..o.ox.x.': (300, inf, (2, 0)),
#  '..o.ox.xo': (300, 300, (2, 1)),
#  '..o.oxx..': (0.0, inf, (2, 0)),
#  '..o.oxx.o': (0.0, inf, (2, 2)),
#  '..o.oxxox': (300, 300, (1, 2)),
#  '..o.oxxxo': (300, 300, (2, 2)),
#  '..o.x....': (0.0, 0.0, (1, 0)),
#  '..o.x...o': (-inf, 0.0, (1, 0)),
#  '..o.x..o.': (-inf, 0.0, (1, 0)),
#  '..o.x..ox': (-inf, 0.0, (2, 0)),
#  '..o.x..xo': (300, inf, (1, 0)),
#  '..o.x.o..': (-inf, 0.0, (1, 0)),
#  '..o.x.oox': (-inf, 0.0, (0, 1)),
#  '..o.x.ox.': (-inf, 0.0, (0, 1)),
#  '..o.x.oxo': (-inf, -300, (0, 1)),
#  '..o.x.x.o': (300, inf, (1, 0)),
#  '..o.x.xo.': (-inf, 0.0, (2, 0)),
#  '..o.x.xoo': (0.0, 0.0, (0, 1)),
#  '..o.xo...': (0.0, 0.0, (2, 0)),
#  '..o.xo..x': (0.0, 0.0, (0, 2)),
#  '..o.xo.ox': (-inf, -300, (0, 2)),
#  '..o.xo.x.': (300, inf, (2, 0)),
#  '..o.xoo.x': (-inf, 0.0, (0, 1)),
#  '..o.xoox.': (-inf, -300, (2, 0)),
#  '..o.xooxx': (-inf, -300, (0, 1)),
#  '..o.xox..': (300, inf, (2, 0)),
#  '..o.xoxo.': (-inf, 0.0, (2, 0)),
#  '..o.xoxox': (0.0, 0.0, (0, 2)),
#  '..o.xx..o': (0.0, 0.0, (1, 2)),
#  '..o.xx.o.': (-inf, 0.0, (0, 2)),
#  '..o.xx.oo': (-300, -300, (1, 2)),
#  '..o.xxo..': (-inf, 0.0, (0, 1)),
#  '..o.xxo.o': (-inf, -300, (0, 1)),
#  '..o.xxoo.': (-inf, -300, (2, 0)),
#  '..o.xxoox': (-inf, -300, (0, 1)),
#  '..o.xxoxo': (-inf, -300, (2, 1)),
#  '..o.xxxoo': (0.0, 0.0, (1, 2)),
#  '..oo..oxx': (-inf, 300, (1, 1)),
#  '..oo..x..': (-inf, 0.0, (1, 1)),
#  '..oo..xox': (-inf, 0.0, (1, 1)),
#  '..oo..xx.': (300, inf, (0, 2)),
#  '..oo..xxo': (300, 300, (2, 0)),
#  '..oo.o.xx': (-inf, -300, (1, 1)),
#  '..oo.ox.x': (-inf, -300, (1, 1)),
#  '..oo.x...': (-inf, 300, (2, 0)),
#  '..oo.x..x': (-inf, 300, (0, 1)),
#  '..oo.x.ox': (300, 300, (2, 0)),
#  '..oo.x.xo': (-inf, 300, (1, 1)),
#  '..oo.xo.x': (-inf, 300, (0, 1)),
#  '..oo.xxox': (300, inf, (1, 2)),
#  '..oo.xxxo': (300, 300, (2, 0)),
#  '..ooo..xx': (-inf, -300, (2, 0)),
#  '..ooo.x.x': (-inf, 0.0, (1, 0)),
#  '..ooo.xx.': (-inf, -300, (0, 2)),
#  '..ooox..x': (-inf, 0.0, (2, 0)),
#  '..ooox.xx': (300, inf, (2, 0)),
#  '..oooxx..': (-inf, 0.0, (2, 0)),
#  '..oooxx.x': (-inf, 0.0, (0, 1)),
#  '..oooxxox': (-inf, 0.0, (1, 2)),
#  '..oooxxxo': (-inf, 0.0, (2, 2)),
#  '..oox....': (-inf, 0.0, (1, 0)),
#  '..oox..ox': (-inf, 0.0, (2, 0)),
#  '..oox..xo': (-inf, 0.0, (0, 1)),
#  '..oox.ox.': (-inf, 0.0, (0, 2)),
#  '..oox.oxx': (300, 300, (0, 2)),
#  '..oox.x..': (-inf, 0.0, (2, 0)),
#  '..oox.x.o': (-inf, 0.0, (1, 2)),
#  '..oox.xo.': (0.0, 0.0, (2, 0)),
#  '..oox.xox': (0.0, 0.0, (0, 2)),
#  '..oox.xxo': (300, inf, (0, 1)),
#  '..ooxo..x': (-inf, -300, (0, 1)),
#  '..ooxo.xx': (-inf, -300, (0, 1)),
#  '..ooxooxx': (-inf, -300, (0, 2)),
#  '..ooxox..': (-inf, -300, (0, 2)),
#  '..ooxox.x': (-inf, -300, (0, 1)),
#  '..ooxoxox': (-inf, -300, (0, 2)),
#  '..ooxoxx.': (300, inf, (0, 2)),
#  '..ooxx..o': (0.0, 0.0, (0, 1)),
#  '..ooxx.o.': (-inf, 0.0, (0, 2)),
#  '..ooxx.ox': (300, inf, (0, 2)),
#  '..ooxx.xo': (0.0, 0.0, (2, 1)),
#  '..ooxxo..': (-inf, 0.0, (0, 2)),
#  '..ooxxo.x': (300, inf, (0, 2)),
#  '..ooxxoox': (-inf, -300, (0, 2)),
#  '..ooxxox.': (300, inf, (0, 2)),
#  '..ooxxoxo': (-inf, -300, (1, 2)),
#  '..ooxxx.o': (0.0, 0.0, (2, 0)),
#  '..ooxxxo.': (0.0, inf, (2, 0)),
#  '..ooxxxoo': (0.0, 0.0, (2, 1)),
#  '..ox.....': (300, inf, (2, 0)),
#  '..ox...xo': (300, inf, (1, 0)),
#  '..ox..o..': (-inf, 300, (2, 0)),
#  '..ox..oxo': (-inf, 300, (1, 1)),
#  '..ox..x.o': (300, inf, (1, 0)),
#  '..ox..xo.': (300, inf, (0, 2)),
#  '..ox..xoo': (-inf, -300, (0, 1)),
#  '..ox.o...': (0.0, inf, (2, 0)),
#  '..ox.o..x': (0.0, inf, (0, 2)),
#  '..ox.o.ox': (-inf, -300, (0, 2)),
#  '..ox.o.x.': (300, inf, (2, 0)),
#  '..ox.ooxx': (-inf, 300, (1, 1)),
#  '..ox.ox..': (300, inf, (2, 0)),
#  '..ox.oxo.': (-inf, 0.0, (2, 0)),
#  '..ox.oxox': (-inf, 0.0, (0, 2)),
#  '..ox.x..o': (300, inf, (1, 1)),
#  '..ox.x.oo': (-300, -300, (1, 1)),
#  '..ox.xoox': (300, inf, (1, 1)),
#  '..ox.xxoo': (-300, -300, (1, 1)),
#  '..oxo.x..': (300, 300, (2, 0)),
#  '..oxo.x.o': (-inf, -300, (2, 0)),
#  '..oxo.xo.': (-inf, -300, (0, 2)),
#  '..oxo.xox': (300, inf, (1, 2)),
#  '..oxo.xxo': (300, inf, (2, 1)),
#  '..oxoo..x': (-300, -300, (0, 2)),
#  '..oxoo.xx': (300, inf, (2, 2)),
#  '..oxoox..': (-inf, -300, (2, 0)),
#  '..oxoox.x': (-300, -300, (0, 1)),
#  '..oxooxox': (-300, -300, (2, 2)),
#  '..oxooxx.': (300, inf, (2, 0)),
#  '..oxox...': (300, inf, (2, 0)),
#  '..oxox..o': (300, inf, (0, 1)),
#  '..oxox.ox': (300, inf, (2, 0)),
#  '..oxox.xo': (300, inf, (2, 1)),
#  '..oxoxx.o': (300, inf, (2, 2)),
#  '..oxoxxo.': (300, inf, (0, 2)),
#  '..oxoxxoo': (-300, -300, (2, 2)),
#  '..oxx.o..': (-inf, 0.0, (0, 1)),
#  '..oxx.o.o': (-inf, -300, (1, 2)),
#  '..oxx.oo.': (-inf, 0.0, (0, 2)),
#  '..oxx.oox': (-inf, 0.0, (0, 2)),
#  '..oxx.oxo': (300, 300, (1, 2)),
#  '..oxx.xoo': (300, inf, (0, 1)),
#  '..oxxo...': (300, inf, (2, 0)),
#  '..oxxo.ox': (0.0, inf, (0, 2)),
#  '..oxxoo..': (-inf, 0.0, (0, 2)),
#  '..oxxoo.x': (-inf, 0.0, (2, 0)),
#  '..oxxooox': (-inf, -300, (0, 2)),
#  '..oxxoox.': (300, inf, (2, 1)),
#  '..x.....o': (300, inf, (0, 1)),
#  '..x....o.': (300, inf, (0, 0)),
#  '..x....oo': (300, inf, (1, 0)),
#  '..x...o..': (0.0, inf, (2, 0)),
#  '..x...o.o': (0.0, inf, (1, 0)),
#  '..x...oo.': (-300, -300, (2, 0)),
#  '..x...oox': (-300, -300, (0, 1)),
#  '..x...oxo': (0.0, inf, (1, 1)),
#  '..x...xoo': (300, inf, (1, 1)),
#  '..x..o...': (0.0, 0.0, (0, 1)),
#  '..x..o..o': (-300, -300, (2, 1)),
#  '..x..o.o.': (-inf, 0.0, (1, 1)),
#  '..x..o.ox': (300, 300, (1, 1)),
#  '..x..o.xo': (300, inf, (1, 1)),
#  '..x..oo..': (-inf, 0.0, (1, 1)),
#  '..x..oo.x': (300, 300, (1, 2)),
#  '..x..ooox': (-inf, -300, (0, 2)),
#  '..x..ooxo': (-300, -300, (1, 2)),
#  '..x..ox.o': (300, inf, (1, 1)),
#  '..x..oxoo': (-300, -300, (1, 1)),
#  '..x..x.oo': (300, 300, (1, 1)),
#  '..x..xo.o': (300, 300, (1, 0)),
#  '..x..xoo.': (300, inf, (2, 0)),
#  '..x.o....': (0.0, 0.0, (1, 0)),
#  '..x.o...o': (-inf, 0.0, (0, 2)),
#  '..x.o..o.': (-inf, 0.0, (0, 1)),
#  '..x.o..ox': (300, inf, (0, 1)),
#  '..x.o..xo': (300, inf, (1, 0)),
#  '..x.o.o..': (-inf, 0.0, (2, 0)),
#  '..x.o.o.x': (-inf, 0.0, (0, 1)),
#  '..x.o.oox': (-inf, -300, (2, 1)),
#  '..x.o.ox.': (0.0, inf, (2, 0)),
#  '..x.o.oxo': (0.0, inf, (2, 2)),
#  '..x.o.xo.': (300, inf, (2, 0)),
#  '..x.o.xoo': (300, inf, (1, 0)),
#  '..x.oo...': (0.0, 0.0, (1, 2)),
#  '..x.oo..x': (300, 300, (0, 1)),
#  '..x.oo.ox': (300, 300, (2, 1)),
#  '..x.oo.x.': (300, inf, (2, 0)),
#  '..x.oo.xo': (300, inf, (2, 0)),
#  '..x.ooo.x': (-inf, 0.0, (1, 2)),
#  '..x.oooxx': (300, 300, (1, 2)),
#  '..x.oox..': (300, inf, (2, 0)),
#  '..x.oox.o': (300, inf, (1, 0)),
#  '..x.ooxox': (300, inf, (2, 1)),
#  '..x.ooxxo': (300, inf, (2, 1)),
#  '..x.ox..o': (300, 300, (0, 1)),
#  '..x.ox.o.': (300, 300, (2, 0)),
#  '..x.ox.oo': (300, 300, (2, 1)),
#  '..x.oxo..': (300, 300, (2, 0)),
#  '..x.oxo.o': (300, 300, (0, 1)),
#  '..x.oxoo.': (-inf, -300, (2, 0)),
#  '..x.oxoxo': (300, 300, (2, 2)),
#  '..x.oxxoo': (300, inf, (2, 1)),
#  '..x.x..oo': (300, inf, (0, 2)),
#  '..x.x.o.o': (300, inf, (1, 0)),
#  '..x.x.oo.': (300, inf, (2, 0)),
#  '..x.xo..o': (0.0, 0.0, (0, 2)),
#  '..x.xo.o.': (-inf, 0.0, (0, 2)),
#  '..x.xo.oo': (-300, -300, (0, 2)),
#  '..x.xoo..': (-inf, 0.0, (2, 0)),
#  '..x.xoo.o': (0.0, 0.0, (0, 1)),
#  '..x.xooo.': (-inf, 0.0, (2, 0)),
#  '..x.xooox': (0.0, 0.0, (0, 2)),
#  '..x.xooxo': (0.0, 0.0, (1, 2)),
#  '..xo.....': (300, inf, (0, 0)),
#  '..xo..o..': (-300, -300, (2, 0)),
#  '..xo..o.x': (300, inf, (2, 1)),
#  '..xo..oox': (-300, -300, (2, 1)),
#  '..xo..ox.': (300, inf, (1, 1)),
#  '..xo..oxo': (-inf, 0.0, (0, 2)),
#  '..xo..xo.': (300, inf, (1, 1)),
#  '..xo..xoo': (-inf, -300, (1, 1)),
#  '..xo.o...': (-inf, -300, (1, 1)),
#  '..xo.o..x': (300, 300, (1, 1)),
#  '..xo.o.ox': (-inf, -300, (1, 1)),
#  '..xo.oo.x': (300, 300, (0, 1)),
#  '..xo.ooxx': (300, 300, (1, 1)),
#  '..xo.x..o': (-inf, 300, (0, 1)),
#  '..xo.x.oo': (-inf, 300, (1, 1)),
#  '..xo.xo..': (300, inf, (2, 0)),
#  '..xo.xo.o': (-inf, 300, (0, 1)),
#  '..xo.xoxo': (300, 300, (2, 1)),
#  '..xo.xxoo': (300, inf, (1, 1)),
#  '..xoo....': (-inf, 0.0, (0, 1)),
#  '..xoo.o.x': (-inf, -300, (2, 1)),
#  '..xoo.ox.': (300, inf, (2, 0)),
#  '..xoo.oxx': (300, inf, (2, 1)),
#  '..xoo.x..': (300, inf, (2, 0)),
#  '..xoo.xo.': (300, inf, (2, 0)),
#  '..xoo.xox': (300, inf, (2, 1)),
#  '..xoo.xxo': (300, inf, (2, 0)),
#  '..xoox...': (-inf, 0.0, (0, 2)),
#  '..xoox..o': (-inf, 0.0, (2, 0)),
#  '..xoox.o.': (-inf, -300, (2, 0)),
#  '..xoox.xo': (-inf, 300, (2, 1)),
#  '..xooxo..': (-inf, -300, (2, 0)),
#  '..xooxox.': (300, inf, (0, 2)),
#  '..xooxoxo': (0.0, 0.0, (2, 2)),
#  '..xooxxo.': (300, inf, (2, 0)),
#  '..xooxxoo': (300, inf, (0, 2)),
#  '..xox.o..': (300, inf, (2, 0)),
#  '..xox.oox': (300, inf, (0, 2)),
#  '..xox.oxo': (300, inf, (0, 2)),
#  '..xoxo...': (-inf, -300, (2, 0)),
#  '..xoxo..o': (-inf, -300, (0, 1)),
#  '..xoxo.o.': (-inf, -300, (2, 0)),
#  '..xoxo.ox': (-inf, -300, (0, 1)),
#  '..xoxo.xo': (-inf, -300, (2, 0)),
#  '..xoxoo..': (-inf, -300, (0, 2)),
#  '..xoxoo.x': (300, inf, (0, 2)),
#  '..xoxooox': (-300, -300, (0, 2)),
#  '..xoxoox.': (300, inf, (0, 2)),
#  '..xoxooxo': (-300, -300, (1, 2)),
#  '..xoxx.oo': (-inf, 300, (0, 2)),
#  '..xx...oo': (300, inf, (1, 1)),
#  '..xx..o.o': (300, inf, (1, 0)),
#  '..xx..oo.': (300, inf, (1, 1)),
#  '..xx.o..o': (0.0, inf, (0, 2)),
#  '..xx.o.oo': (-300, -300, (0, 2)),
#  '..xx.oo.o': (0.0, inf, (0, 1)),
#  '..xx.ooox': (0.0, inf, (1, 1)),
#  '..xx.ooxo': (0.0, 0.0, (1, 1)),
#  '..xx.oxoo': (-300, -300, (1, 1)),
#  '..xxo..oo': (300, inf, (1, 0)),
#  '..xxo.o..': (0.0, inf, (2, 0)),
#  '..xxo.oo.': (300, inf, (2, 0)),
#  '..xxo.oox': (300, inf, (2, 1)),
#  '..xxo.oxo': (300, inf, (0, 2)),
#  '..xxo.xoo': (300, inf, (1, 2)),
#  '..xxoo...': (0.0, 0.0, (0, 1)),
#  '..xxoo..o': (-300, -300, (0, 2)),
#  '..xxoo.o.': (-inf, 0.0, (0, 1)),
#  '..xxoo.ox': (300, inf, (2, 1)),
#  '..xxoo.xo': (300, inf, (2, 2)),
#  '..xxooo..': (-inf, 0.0, (2, 0)),
#  '..xxooo.x': (-inf, 0.0, (0, 1)),
#  '..xxoooox': (0.0, 0.0, (2, 1)),
#  '..xxoooxo': (0.0, 0.0, (0, 2)),
#  '..xxoox.o': (300, inf, (2, 2)),
#  '..xxooxoo': (-300, -300, (2, 2)),
#  '..xxox.oo': (300, inf, (2, 1)),
#  '..xxoxo.o': (300, inf, (0, 1)),
#  '..xxoxoo.': (300, inf, (2, 1)),
#  '..xxxo.oo': (300, inf, (0, 2)),
#  '..xxxoo.o': (300, inf, (0, 1)),
#  '.o.......': (0.0, 0.0, (0, 0)),
#  '.o......x': (300, inf, (0, 0)),
#  '.o.....ox': (-inf, -300, (1, 1)),
#  '.o.....x.': (0.0, inf, (0, 0)),
#  '.o.....xo': (-inf, 300, (2, 0)),
#  '.o....ox.': (-inf, 300, (2, 0)),
#  '.o....oxx': (-inf, 300, (0, 1)),
#  '.o....x..': (300, inf, (0, 0)),
#  '.o....xo.': (-inf, -300, (1, 1)),
#  '.o....xox': (300, 300, (1, 1)),
#  '.o....xxo': (-inf, 300, (0, 1)),
#  '.o...o..x': (-inf, 0.0, (1, 1)),
#  '.o...o.xx': (300, inf, (0, 2)),
#  '.o...ooxx': (300, 300, (2, 0)),
#  '.o...oxox': (-inf, -300, (1, 1)),
#  '.o...oxxo': (-inf, 300, (1, 1)),
#  '.o...x...': (300, inf, (0, 0)),
#  '.o...x..o': (-inf, 300, (2, 0)),
#  '.o...x.ox': (300, inf, (1, 1)),
#  '.o...xoox': (-inf, -300, (1, 1)),
#  '.o...xoxo': (-inf, 300, (1, 1)),
#  '.o..o...x': (-inf, 0.0, (0, 1)),
#  '.o..o..xx': (-inf, 0.0, (0, 2)),
#  '.o..o.oxx': (-inf, 0.0, (2, 0)),
#  '.o..o.x..': (-inf, 0.0, (0, 1)),
#  '.o..o.xx.': (-inf, 0.0, (0, 2)),
#  '.o..o.xxo': (-inf, 0.0, (2, 0)),
#  '.o..oo.xx': (-inf, -300, (0, 2)),
#  '.o..ooxx.': (-inf, -300, (2, 0)),
#  '.o..ox..x': (300, 300, (2, 0)),
#  '.o..oxo.x': (-inf, -300, (2, 0)),
#  '.o..oxoxx': (300, inf, (2, 0)),
#  '.o..oxxxo': (-inf, 300, (2, 1)),
#  '.o..x....': (0.0, inf, (0, 0)),
#  '.o..x...o': (-inf, 0.0, (1, 0)),
#  '.o..x..ox': (-inf, -300, (2, 0)),
#  '.o..x.o..': (-inf, 0.0, (1, 0)),
#  '.o..x.oox': (-inf, -300, (0, 1)),
#  '.o..x.oxo': (0.0, 0.0, (0, 1)),
#  '.o..x.xo.': (-inf, -300, (2, 0)),
#  '.o..x.xoo': (-inf, -300, (0, 1)),
#  '.o..xo..x': (-inf, 0.0, (0, 2)),
#  '.o..xo.ox': (-inf, -300, (2, 0)),
#  '.o..xoo.x': (-inf, 0.0, (2, 0)),
#  '.o..xoox.': (-inf, 0.0, (0, 2)),
#  '.o..xooxx': (300, inf, (0, 2)),
#  '.o..xoxo.': (-inf, -300, (2, 0)),
#  '.o..xoxox': (-inf, -300, (0, 1)),
#  '.o..xoxxo': (-inf, 300, (0, 2)),
#  '.o..xx..o': (-inf, 0.0, (0, 2)),
#  '.o..xx.oo': (-inf, -300, (0, 2)),
#  '.o..xxo.o': (-inf, 0.0, (0, 1)),
#  '.o..xxoox': (-inf, -300, (0, 1)),
#  '.o..xxoxo': (0.0, 0.0, (2, 1)),
#  '.o..xxxoo': (-inf, -300, (2, 0)),
#  '.o.o..oxx': (-inf, 300, (1, 1)),
#  '.o.o..x..': (-inf, 0.0, (1, 1)),
#  '.o.o..xox': (-inf, -300, (1, 1)),
#  '.o.o..xx.': (300, inf, (0, 2)),
#  '.o.o..xxo': (300, 300, (2, 0)),
#  '.o.o.xxxo': (300, 300, (2, 0)),
#  '.o.oo..xx': (-inf, -300, (2, 0)),
#  '.o.oo.xx.': (-inf, -300, (0, 2)),
#  '.o.oox..x': (-inf, -300, (2, 0)),
#  '.o.ooxoxx': (-inf, 300, (0, 2)),
#  '.o.ooxx..': (-inf, 0.0, (0, 1)),
#  '.o.ooxxx.': (-inf, 0.0, (0, 2)),
#  '.o.ooxxxo': (-inf, 0.0, (2, 0)),
#  '.o.ox..ox': (-inf, -300, (2, 0)),
#  '.o.ox..xo': (-inf, 0.0, (0, 2)),
#  '.o.ox.oxx': (-inf, 300, (0, 2)),
#  '.o.ox.x..': (-inf, 0.0, (0, 2)),
#  '.o.ox.x.o': (-inf, 0.0, (2, 0)),
#  '.o.ox.xo.': (-inf, -300, (2, 0)),
#  '.o.ox.xox': (-inf, -300, (0, 1)),
#  '.o.ox.xxo': (300, inf, (0, 2)),
#  '.o.oxo..x': (-inf, -300, (2, 0)),
#  '.o.oxooxx': (-inf, -300, (0, 2)),
#  '.o.oxox..': (-inf, -300, (2, 0)),
#  '.o.oxoxox': (-inf, -300, (0, 2)),
#  '.o.oxoxxo': (-inf, -300, (0, 2)),
#  '.o.oxx..o': (-inf, 0.0, (0, 2)),
#  '.o.oxx.xo': (300, inf, (2, 2)),
#  '.o.oxxoox': (-inf, -300, (0, 2)),
#  '.o.oxxoxo': (0.0, 0.0, (2, 2)),
#  '.o.oxxx.o': (-inf, 0.0, (2, 0)),
#  '.o.oxxxoo': (-inf, -300, (2, 0)),
#  '.o.x.....': (300, inf, (0, 0)),
#  '.o.x..o..': (-inf, 300, (2, 0)),
#  '.o.x..oxo': (-inf, 300, (1, 1)),
#  '.o.x..xo.': (300, inf, (1, 1)),
#  '.o.x..xoo': (-inf, -300, (1, 1)),
#  '.o.x.ooxx': (300, 300, (2, 0)),
#  '.o.x.xoox': (300, inf, (1, 1)),
#  '.o.x.xxoo': (300, inf, (1, 1)),
#  '.o.xo.oxx': (-inf, 300, (2, 1)),
#  '.o.xo.x..': (300, 300, (2, 0)),
#  '.o.xo.x.o': (-inf, -300, (2, 0)),
#  '.o.xo.xxo': (300, inf, (2, 0)),
#  '.o.xoo..x': (-inf, 0.0, (0, 1)),
#  '.o.xoo.xx': (-inf, 0.0, (0, 2)),
#  '.o.xoooxx': (-inf, 0.0, (2, 0)),
#  '.o.xoox..': (-inf, -300, (2, 0)),
#  '.o.xooxxo': (-inf, 300, (0, 2)),
#  '.o.xoxoxo': (-inf, 300, (0, 2)),
#  '.o.xx.o..': (-inf, 0.0, (0, 2)),
#  '.o.xx.o.o': (-inf, 0.0, (0, 1)),
#  '.o.xx.oo.': (-inf, -300, (0, 2)),
#  '.o.xx.oox': (-inf, -300, (2, 0)),
#  '.o.xx.oxo': (0.0, 0.0, (2, 1)),
#  '.o.xx.xoo': (-inf, -300, (0, 1)),
#  '.o.xxoo..': (-inf, 0.0, (0, 2)),
#  '.o.xxoo.x': (-inf, 0.0, (2, 0)),
#  '.o.xxooox': (-inf, -300, (2, 0)),
#  '.o.xxoox.': (300, inf, (2, 2)),
#  '.o.xxooxo': (0.0, 0.0, (2, 2)),
#  '.o.xxoxoo': (-inf, -300, (0, 2)),
#  '.oo.....x': (300, inf, (1, 0)),
#  '.oo....x.': (0.0, inf, (2, 0)),
#  '.oo....xx': (300, inf, (0, 2)),
#  '.oo...oxx': (-inf, 300, (0, 1)),
#  '.oo...x..': (-300, -300, (2, 0)),
#  '.oo...x.x': (300, inf, (2, 1)),
#  '.oo...xox': (300, 300, (0, 1)),
#  '.oo...xx.': (300, inf, (2, 0)),
#  '.oo...xxo': (-inf, 300, (0, 1)),
#  '.oo..o.xx': (-300, -300, (0, 2)),
#  '.oo..ox.x': (-300, -300, (2, 1)),
#  '.oo..x...': (300, 300, (2, 0)),
#  '.oo..x..x': (300, 300, (1, 1)),
#  '.oo..x.ox': (-inf, 300, (1, 1)),
#  '.oo..x.x.': (300, inf, (1, 1)),
#  '.oo..x.xo': (-inf, 0.0, (0, 2)),
#  '.oo..xo.x': (-inf, 300, (1, 1)),
#  '.oo..xx..': (300, inf, (1, 1)),
#  '.oo..xx.o': (-inf, 0.0, (0, 2)),
#  '.oo..xxox': (300, 300, (1, 1)),
#  '.oo..xxxo': (300, 300, (2, 1)),
#  '.oo.o..xx': (-inf, -300, (2, 2)),
#  '.oo.o.x.x': (-inf, -300, (2, 1)),
#  '.oo.o.xx.': (-inf, -300, (2, 0)),
#  '.oo.ox..x': (300, 300, (2, 1)),
#  '.oo.ox.x.': (300, inf, (2, 0)),
#  '.oo.ox.xx': (300, 300, (0, 2)),
#  '.oo.oxx..': (300, inf, (2, 0)),
#  '.oo.oxx.x': (300, inf, (2, 1)),
#  '.oo.oxxx.': (300, inf, (0, 2)),
#  '.oo.oxxxo': (0.0, 0.0, (2, 2)),
#  '.oo.x....': (0.0, 0.0, (2, 0)),
#  '.oo.x...x': (300, inf, (0, 2)),
#  '.oo.x..ox': (-inf, -300, (0, 2)),
#  '.oo.x..x.': (300, inf, (2, 0)),
#  '.oo.x.ox.': (-inf, 0.0, (0, 2)),
#  '.oo.x.oxx': (300, inf, (0, 2)),
#  '.oo.x.x..': (300, inf, (2, 0)),
#  '.oo.x.xo.': (-inf, -300, (0, 2)),
#  '.oo.x.xox': (300, inf, (0, 2)),
#  '.oo.xo..x': (-300, -300, (0, 2)),
#  '.oo.xo.xx': (300, inf, (0, 2)),
#  '.oo.xooxx': (-inf, -300, (0, 2)),
#  '.oo.xox.x': (300, inf, (0, 2)),
#  '.oo.xoxox': (-300, -300, (0, 2)),
#  '.oo.xx...': (300, inf, (0, 2)),
#  '.oo.xx..o': (-300, -300, (1, 2)),
#  '.oo.xx.o.': (-inf, -300, (0, 2)),
#  '.oo.xx.ox': (300, 300, (0, 2)),
#  '.oo.xx.xo': (300, 300, (0, 2)),
#  '.oo.xxo..': (-inf, 0.0, (0, 2)),
#  '.oo.xxo.x': (300, 300, (0, 2)),
#  '.oo.xxoox': (-inf, -300, (0, 2)),
#  '.oo.xxox.': (300, inf, (0, 2)),
#  '.oo.xxoxo': (-inf, -300, (1, 2)),
#  '.oo.xxx.o': (300, inf, (0, 2)),
#  '.oo.xxxo.': (300, inf, (0, 2)),
#  '.oo.xxxoo': (-300, -300, (1, 2)),
#  '.ooo..xx.': (-inf, 0.0, (2, 0)),
#  '.ooo.x..x': (-inf, 300, (1, 1)),
#  '.ooo.xxox': (300, 300, (1, 1)),
#  '.ooo.xxxo': (-inf, 300, (1, 1)),
#  '.oooox.xx': (-inf, 300, (0, 2)),
#  '.ooooxx.x': (-inf, -300, (0, 1)),
#  '.ooooxxx.': (-inf, 0.0, (2, 0)),
#  '.ooox.oxx': (-inf, -300, (0, 2)),
#  '.ooox.x..': (-inf, 0.0, (2, 0)),
#  '.ooox.xox': (-inf, -300, (0, 2)),
#  '.ooox.xxo': (300, inf, (0, 1)),
#  '.oooxo.xx': (-inf, -300, (0, 2)),
#  '.oooxox.x': (-inf, -300, (2, 1)),
#  '.oooxoxx.': (-inf, -300, (0, 2)),
#  '.oooxx..x': (-inf, 300, (0, 2)),
#  '.oooxx.ox': (-inf, -300, (0, 2)),
#  '.oooxx.xo': (0.0, 0.0, (2, 2)),
#  '.oooxxo.x': (-inf, -300, (0, 2)),
#  '.oooxxoxx': (300, 300, (0, 2)),
#  '.oooxxx.o': (-inf, 0.0, (2, 2)),
#  '.oooxxxo.': (-inf, 0.0, (0, 2)),
#  '.oooxxxox': (300, 300, (0, 2)),
#  '.oooxxxxo': (300, 300, (2, 2)),
#  '.oox.....': (-300, -300, (2, 0)),
#  '.oox....x': (300, inf, (1, 1)),
#  '.oox...x.': (300, inf, (2, 0)),
#  '.oox..oxx': (-inf, 300, (1, 1)),
#  '.oox..x..': (300, inf, (2, 0)),
#  '.oox..xox': (300, inf, (1, 1)),
#  '.oox.o..x': (-300, -300, (0, 2)),
#  '.oox.o.xx': (300, inf, (0, 2)),
#  '.oox.ooxx': (300, 300, (1, 1)),
#  '.oox.ox.x': (-300, inf, (1, 1)),
#  '.oox.oxox': (-inf, -300, (0, 2)),
#  '.oox.x...': (300, inf, (1, 1)),
#  '.oox.x..o': (-300, -300, (1, 1)),
#  '.oox.x.xo': (300, inf, (1, 1)),
#  '.oox.xx.o': (-300, inf, (1, 1)),
#  '.oox.xxoo': (-inf, -300, (1, 1)),
#  '.ooxo...x': (300, inf, (1, 0)),
#  '.ooxo..xx': (300, inf, (0, 2)),
#  '.ooxo.x..': (-inf, -300, (2, 0)),
#  '.ooxo.x.x': (300, inf, (2, 1)),
#  '.ooxo.xx.': (300, inf, (2, 0)),
#  '.ooxoo.xx': (-300, -300, (2, 2)),
#  '.ooxoox.x': (-300, -300, (2, 1)),
#  '.ooxox...': (300, inf, (2, 0)),
#  '.ooxox..x': (300, inf, (2, 1)),
#  '.ooxox.x.': (300, inf, (2, 0)),
#  '.ooxox.xo': (300, inf, (0, 2)),
#  '.ooxoxx..': (300, inf, (2, 1)),
#  '.ooxoxx.o': (-300, -300, (0, 2)),
#  '.ooxoxxxo': (300, inf, (2, 2)),
#  '.ooxx....': (300, inf, (2, 0)),
#  '.ooxx.o..': (-inf, -300, (2, 0)),
#  '.ooxx.oox': (-inf, -300, (2, 0)),
#  '.ooxx.ox.': (300, inf, (2, 1)),
#  '.ooxx.oxo': (-inf, -300, (2, 1)),
#  '.ooxx.xo.': (300, inf, (0, 2)),
#  '.ooxx.xoo': (-inf, -300, (0, 1)),
#  '.ooxxo..x': (300, inf, (0, 2)),
#  '.ooxxo.ox': (-300, -300, (0, 2)),
#  '.ooxxoo.x': (-inf, -300, (2, 0)),
#  '.ooxxoox.': (300, inf, (2, 0)),
#  '.ooxxooxx': (300, 300, (0, 2)),
#  '.ooxxoxo.': (-inf, -300, (0, 2)),
#  '.ooxxoxox': (300, inf, (0, 2)),
#  '.ox......': (0.0, 0.0, (0, 1)),
#  '.ox.....o': (-inf, 0.0, (1, 1)),
#  '.ox....o.': (-inf, -300, (1, 1)),
#  '.ox...o..': (-inf, 0.0, (1, 1)),
#  '.ox...oox': (-inf, -300, (1, 1)),
#  '.ox..o...': (0.0, 0.0, (1, 1)),
#  '.ox..o..x': (300, 300, (1, 1)),
#  '.ox..o.ox': (-inf, -300, (1, 1)),
#  '.ox..o.x.': (0.0, inf, (2, 0)),
#  '.ox..o.xo': (0.0, inf, (1, 1)),
#  '.ox..oo.x': (-inf, 0.0, (1, 1)),
#  '.ox..ooxx': (300, inf, (1, 2)),
#  '.ox..ox..': (300, inf, (1, 1)),
#  '.ox..ox.o': (-inf, -300, (1, 1)),
#  '.ox..oxxo': (300, inf, (1, 1)),
#  '.ox..x..o': (300, 300, (1, 1)),
#  '.ox..x.o.': (300, inf, (1, 1)),
#  '.ox..x.oo': (-inf, 300, (1, 1)),
#  '.ox..xo..': (300, inf, (0, 2)),
#  '.ox..xo.o': (300, 300, (2, 0)),
#  '.ox..xoxo': (300, 300, (2, 0)),
#  '.ox.o....': (0.0, 0.0, (1, 2)),
#  '.ox.o...x': (300, inf, (0, 1)),
#  '.ox.o..x.': (0.0, 0.0, (0, 1)),
#  '.ox.o..xo': (-inf, 0.0, (2, 0)),
#  '.ox.o.o.x': (-inf, 0.0, (1, 0)),
#  '.ox.o.ox.': (-inf, 0.0, (2, 0)),
#  '.ox.o.oxx': (-inf, 0.0, (0, 1)),
#  '.ox.o.x..': (300, inf, (2, 0)),
#  '.ox.oo..x': (300, 300, (2, 1)),
#  '.ox.oo.x.': (0.0, 0.0, (2, 1)),
#  '.ox.oo.xx': (300, 300, (1, 2)),
#  '.ox.oooxx': (-inf, 0.0, (1, 2)),
#  '.ox.oox..': (300, inf, (2, 0)),
#  '.ox.oox.x': (300, inf, (2, 1)),
#  '.ox.ooxx.': (300, inf, (2, 0)),
#  '.ox.ooxxo': (300, inf, (0, 2)),
#  '.ox.ox...': (300, inf, (0, 2)),
#  '.ox.ox..o': (300, 300, (2, 0)),
#  '.ox.ox.xo': (300, 300, (2, 0)),
#  '.ox.oxo..': (-inf, -300, (0, 2)),
#  '.ox.oxoxo': (-inf, 0.0, (2, 2)),
#  '.ox.oxx.o': (300, inf, (2, 0)),
#  '.ox.x...o': (-inf, 0.0, (2, 0)),
#  '.ox.x..o.': (-inf, -300, (2, 0)),
#  '.ox.x..oo': (-inf, -300, (0, 2)),
#  '.ox.x.o..': (-inf, 0.0, (2, 0)),
#  '.ox.x.o.o': (-inf, 0.0, (1, 2)),
#  '.ox.x.oo.': (-inf, -300, (0, 2)),
#  '.ox.x.oox': (-inf, -300, (0, 1)),
#  '.ox.x.oxo': (0.0, 0.0, (2, 0)),
#  '.ox.xo...': (0.0, 0.0, (2, 2)),
#  '.ox.xo..o': (-inf, -300, (0, 2)),
#  '.ox.xo.o.': (-inf, -300, (2, 0)),
#  '.ox.xo.ox': (-inf, -300, (0, 2)),
#  '.ox.xo.xo': (0.0, 0.0, (0, 2)),
#  '.ox.xoo..': (0.0, 0.0, (2, 0)),
#  '.ox.xoo.x': (0.0, 0.0, (0, 2)),
#  '.ox.xooox': (-inf, -300, (0, 2)),
#  '.ox.xoox.': (0.0, inf, (2, 0)),
#  '.ox.xooxo': (0.0, 0.0, (2, 1)),
#  '.ox.xx.oo': (300, 300, (0, 2)),
#  '.ox.xxo.o': (300, inf, (0, 1)),
#  '.ox.xxoo.': (300, inf, (0, 2)),
#  '.oxo.....': (-inf, 0.0, (1, 1)),
#  '.oxo..xxo': (300, inf, (1, 1)),
#  '.oxo.o..x': (-inf, -300, (1, 1)),
#  '.oxo.ooxx': (300, 300, (1, 1)),
#  '.oxo.x...': (300, inf, (0, 2)),
#  '.oxo.x..o': (300, 300, (2, 0)),
#  '.oxo.x.xo': (300, 300, (2, 0)),
#  '.oxo.xo..': (-inf, 0.0, (2, 0)),
#  '.oxo.xoxo': (-inf, 300, (1, 1)),
#  '.oxo.xx.o': (300, inf, (1, 1)),
#  '.oxoo..x.': (-inf, 0.0, (0, 1)),
#  '.oxoo.oxx': (-inf, -300, (0, 1)),
#  '.oxoo.xxo': (300, inf, (2, 0)),
#  '.oxoox...': (-inf, -300, (0, 2)),
#  '.oxoox.x.': (-inf, 0.0, (0, 2)),
#  '.oxoox.xo': (-inf, 0.0, (2, 0)),
#  '.oxooxox.': (-inf, 0.0, (2, 0)),
#  '.oxooxx.o': (300, inf, (2, 0)),
#  '.oxooxxxo': (300, 300, (2, 0)),
#  '.oxox....': (-inf, 0.0, (0, 2)),
#  '.oxox...o': (-inf, 0.0, (2, 0)),
#  '.oxox..o.': (-inf, -300, (2, 0)),
#  '.oxox..xo': (-inf, 0.0, (2, 0)),
#  '.oxox.o..': (-inf, 0.0, (2, 0)),
#  '.oxox.oox': (-inf, -300, (2, 1)),
#  '.oxox.oxo': (-inf, 0.0, (2, 2)),
#  '.oxoxo...': (-inf, -300, (2, 0)),
#  '.oxoxo..x': (-inf, -300, (0, 1)),
#  '.oxoxo.ox': (-inf, -300, (0, 2)),
#  '.oxoxo.xo': (-inf, -300, (2, 0)),
#  '.oxoxoo.x': (-inf, -300, (0, 2)),
#  '.oxoxoox.': (-inf, 0.0, (0, 2)),
#  '.oxoxooxx': (300, 300, (0, 2)),
#  '.oxoxx..o': (300, inf, (0, 2)),
#  '.oxoxx.oo': (-inf, -300, (0, 2)),
#  '.oxoxxo.o': (300, inf, (0, 1)),
#  '.oxoxxoo.': (-inf, -300, (0, 2)),
#  '.oxoxxoxo': (300, 300, (2, 2)),
#  '.oxx..oox': (300, inf, (1, 1)),
#  '.oxx.o...': (0.0, inf, (2, 0)),
#  '.oxx.o..o': (-inf, -300, (0, 2)),
#  '.oxx.o.xo': (0.0, inf, (1, 1)),
#  '.oxx.ooxo': (-inf, 0.0, (1, 1)),
#  '.oxx.ox.o': (-inf, -300, (0, 1)),
#  '.oxx.oxoo': (-inf, -300, (1, 1)),
#  '.oxx.xo.o': (300, inf, (1, 1)),
#  '.oxxo....': (300, inf, (2, 0)),
#  '.oxxoo...': (0.0, 0.0, (2, 1)),
#  '.oxxoo..x': (300, inf, (2, 1)),
#  '.oxxoo.x.': (0.0, 0.0, (2, 0)),
#  '.oxxoo.xo': (0.0, 0.0, (0, 2)),
#  '.oxxooo.x': (-inf, 0.0, (0, 1)),
#  '.oxxooox.': (-inf, 0.0, (2, 0)),
#  '.oxxoooxx': (-inf, 0.0, (2, 2)),
#  '.oxxoox..': (300, inf, (2, 0)),
#  '.oxxoox.o': (-inf, -300, (2, 2)),
#  '.oxxooxxo': (300, 300, (2, 2)),
#  '.oxxox..o': (300, inf, (2, 0)),
#  '.oxxoxo..': (300, inf, (0, 2)),
#  '.oxxoxo.o': (300, inf, (2, 0)),
#  '.oxxoxoxo': (300, 300, (2, 2)),
#  '.oxxx.o.o': (300, inf, (1, 2)),
#  '.oxxx.oo.': (300, inf, (0, 2)),
#  '.oxxxo..o': (0.0, inf, (0, 2)),
#  '.oxxxo.oo': (-300, -300, (0, 2)),
#  '.oxxxoo..': (0.0, inf, (2, 0)),
#  '.oxxxoo.o': (0.0, 0.0, (0, 1)),
#  '.oxxxooo.': (-inf, 0.0, (0, 2)),
#  '.oxxxooox': (0.0, 0.0, (2, 0)),
#  '.oxxxooxo': (0.0, 0.0, (2, 2)),
#  '.x......o': (300, inf, (2, 0)),
#  '.x.....o.': (0.0, inf, (0, 0)),
#  '.x.....oo': (0.0, inf, (2, 0)),
#  '.x....o..': (300, inf, (2, 0)),
#  '.x....oo.': (0.0, inf, (2, 0)),
#  '.x....oox': (0.0, inf, (0, 2)),
#  '.x....oxo': (300, inf, (1, 1)),
#  '.x....xoo': (0.0, inf, (0, 2)),
#  '.x...o...': (300, inf, (0, 0)),
#  '.x...o..o': (-300, -300, (2, 0)),
#  '.x...o.ox': (0.0, inf, (2, 0)),
#  '.x...o.xo': (300, inf, (1, 1)),
#  '.x...ooox': (-inf, -300, (0, 2)),
#  '.x...ooxo': (-300, -300, (1, 1)),
#  '.x...ox.o': (300, inf, (1, 1)),
#  '.x...oxoo': (-300, -300, (0, 2)),
#  '.x...x.oo': (300, inf, (1, 1)),
#  '.x...xo.o': (300, inf, (1, 0)),
#  '.x...xoo.': (300, inf, (2, 0)),
#  '.x..o....': (0.0, inf, (0, 0)),
#  '.x..o..ox': (0.0, 0.0, (0, 1)),
#  '.x..o..xo': (300, inf, (2, 0)),
#  '.x..o.oox': (-300, -300, (0, 2)),
#  '.x..o.ox.': (300, inf, (2, 0)),
#  '.x..o.oxo': (300, inf, (0, 1)),
#  '.x..o.xo.': (0.0, 0.0, (0, 1)),
#  '.x..o.xoo': (-300, -300, (0, 2)),
#  '.x..oo..x': (300, inf, (2, 0)),
#  '.x..oo.ox': (0.0, 0.0, (2, 1)),
#  '.x..oo.xo': (300, inf, (2, 0)),
#  '.x..oooxx': (300, inf, (2, 0)),
#  '.x..oox.o': (300, inf, (1, 0)),
#  '.x..ooxo.': (-inf, 0.0, (0, 1)),
#  '.x..ooxox': (300, inf, (2, 1)),
#  '.x..ooxxo': (300, inf, (2, 1)),
#  '.x..ox..o': (300, inf, (2, 0)),
#  '.x..ox.oo': (300, inf, (2, 0)),
#  '.x..oxoox': (300, inf, (2, 2)),
#  '.x..oxoxo': (300, inf, (2, 1)),
#  '.x..oxxoo': (300, inf, (2, 2)),
#  '.x..x..oo': (300, inf, (2, 0)),
#  '.x..x.oo.': (300, inf, (2, 0)),
#  '.x..xo..o': (300, inf, (2, 0)),
#  '.x..xooox': (0.0, inf, (0, 2)),
#  '.x..xoxoo': (300, inf, (0, 2)),
#  '.x.o.....': (300, inf, (0, 0)),
#  '.x.o..o..': (-300, -300, (2, 0)),
#  '.x.o..o.x': (300, inf, (1, 1)),
#  '.x.o..oox': (-300, -300, (0, 2)),
#  '.x.o..ox.': (300, inf, (1, 1)),
#  '.x.o..oxo': (-300, -300, (1, 1)),
#  '.x.o..xo.': (0.0, inf, (2, 0)),
#  '.x.o..xoo': (-inf, -300, (0, 2)),
#  '.x.o.xo..': (300, inf, (2, 0)),
#  '.x.o.xoox': (300, inf, (0, 2)),
#  '.x.o.xoxo': (300, inf, (1, 1)),
#  '.x.o.xxoo': (0.0, inf, (1, 1)),
#  '.x.oo..ox': (-inf, 0.0, (0, 1)),
#  '.x.oo.o.x': (300, inf, (1, 0)),
#  '.x.oo.ox.': (300, inf, (2, 0)),
#  '.x.oo.oxx': (300, inf, (2, 1)),
#  '.x.oo.x..': (300, inf, (2, 0)),
#  '.x.oo.xo.': (0.0, 0.0, (2, 1)),
#  '.x.oo.xox': (300, inf, (2, 1)),
#  '.x.oo.xxo': (300, inf, (2, 0)),
#  '.x.oox.ox': (-inf, 0.0, (0, 2)),
#  '.x.ooxo.x': (300, inf, (0, 2)),
#  '.x.ooxoox': (-300, -300, (2, 2)),
#  '.x.ooxox.': (300, inf, (2, 0)),
#  '.x.ooxoxo': (300, inf, (0, 2)),
#  '.x.ooxxo.': (0.0, 0.0, (2, 0)),
#  '.x.ooxxoo': (0.0, 0.0, (0, 2)),
#  '.x.ox.o..': (300, inf, (2, 0)),
#  '.x.ox.oox': (300, inf, (0, 2)),
#  '.x.ox.xoo': (0.0, inf, (0, 2)),
#  '.x.oxooox': (-300, -300, (0, 2)),
#  '.x.oxoxoo': (-300, -300, (0, 2)),
#  '.x.x...oo': (300, inf, (2, 0)),
#  '.x.x..o.o': (300, inf, (1, 0)),
#  '.x.x..oo.': (300, inf, (1, 1)),
#  '.x.x.o..o': (300, inf, (2, 0)),
#  '.x.x.ooox': (0.0, inf, (1, 1)),
#  '.x.x.ooxo': (300, inf, (1, 1)),
#  '.x.x.oxoo': (300, inf, (0, 2)),
#  '.x.xo.o..': (300, inf, (2, 0)),
#  '.x.xo.oo.': (300, inf, (2, 0)),
#  '.x.xo.oox': (300, inf, (2, 2)),
#  '.x.xo.oxo': (300, inf, (2, 1)),
#  '.x.xo.xoo': (300, inf, (2, 2)),
#  '.x.xoo.ox': (0.0, 0.0, (2, 0)),
#  '.x.xoo.xo': (300, inf, (2, 0)),
#  '.x.xoooox': (0.0, 0.0, (0, 2)),
#  '.x.xoooxo': (300, inf, (0, 2)),
#  '.x.xoox.o': (300, inf, (0, 2)),
#  '.x.xooxo.': (-inf, 0.0, (0, 2)),
#  '.x.xooxoo': (-300, -300, (2, 2)),
#  '.x.xox.oo': (300, inf, (2, 0)),
#  '.x.xoxoo.': (300, inf, (2, 0)),
#  '.xo......': (300, 300, (0, 1)),
#  '.xo.....o': (300, 300, (1, 0)),
#  '.xo....o.': (-inf, 300, (2, 0)),
#  '.xo....xo': (300, inf, (1, 0)),
#  '.xo...o..': (-inf, 300, (2, 0)),
#  '.xo...x.o': (300, inf, (1, 0)),
#  '.xo...xoo': (0.0, inf, (0, 1)),
#  '.xo..o...': (300, 300, (2, 0)),
#  '.xo..o..x': (300, inf, (1, 1)),
#  '.xo..o.ox': (0.0, inf, (1, 1)),
#  '.xo..o.x.': (300, inf, (1, 1)),
#  '.xo..ooxx': (300, inf, (1, 1)),
#  '.xo..ox..': (300, inf, (1, 1)),
#  '.xo..oxox': (0.0, inf, (1, 1)),
#  '.xo..x..o': (300, 300, (1, 1)),
#  '.xo..x.oo': (-inf, 0.0, (0, 2)),
#  '.xo..xo.o': (-inf, 300, (1, 1)),
#  '.xo..xoox': (-inf, 300, (1, 1)),
#  '.xo..xxoo': (0.0, 0.0, (1, 1)),
#  '.xo.o....': (0.0, 300, (2, 2)),
#  '.xo.o...x': (300, inf, (1, 0)),
#  '.xo.o..ox': (-inf, 0.0, (2, 0)),
#  '.xo.o..x.': (300, inf, (2, 0)),
#  '.xo.o.x..': (0.0, inf, (2, 0)),
#  '.xo.o.xo.': (-inf, 0.0, (2, 0)),
#  '.xo.o.xox': (-inf, 0.0, (0, 1)),
#  '.xo.o.xxo': (300, inf, (0, 1)),
#  '.xo.oo..x': (300, inf, (2, 0)),
#  '.xo.oo.x.': (300, inf, (2, 0)),
#  '.xo.oo.xx': (300, inf, (2, 1)),
#  '.xo.oox..': (300, inf, (2, 0)),
#  '.xo.oox.x': (300, inf, (2, 1)),
#  '.xo.ooxox': (0.0, 0.0, (2, 1)),
#  '.xo.ooxx.': (300, inf, (2, 1)),
#  '.xo.ox...': (300, inf, (2, 0)),
#  '.xo.ox..o': (300, 300, (2, 1)),
#  '.xo.ox.ox': (300, 300, (2, 0)),
#  '.xo.ox.xo': (300, 300, (0, 2)),
#  '.xo.oxx.o': (300, inf, (0, 2)),
#  '.xo.oxxoo': (0.0, 0.0, (0, 2)),
#  '.xo.x...o': (300, inf, (1, 0)),
#  '.xo.x.o..': (-inf, 0.0, (0, 1)),
#  '.xo.x.o.o': (-inf, -300, (1, 2)),
#  '.xo.x.oo.': (-inf, 0.0, (0, 2)),
#  '.xo.x.oox': (-inf, 0.0, (2, 0)),
#  '.xo.x.xoo': (300, inf, (0, 1)),
#  '.xo.xo...': (300, inf, (0, 2)),
#  '.xo.xo.ox': (0.0, 0.0, (0, 2)),
#  '.xo.xoo..': (-inf, 0.0, (0, 2)),
#  '.xo.xoo.x': (-inf, 0.0, (0, 2)),
#  '.xo.xooox': (-inf, -300, (0, 2)),
#  '.xo.xx.oo': (300, 300, (0, 2)),
#  '.xo.xxo.o': (300, 300, (1, 2)),
#  '.xo.xxoo.': (300, inf, (2, 1)),
#  '.xoo.....': (-inf, 300, (2, 0)),
#  '.xoo..xxo': (300, inf, (1, 1)),
#  '.xoo.o.xx': (300, inf, (1, 1)),
#  '.xoo.ox.x': (300, inf, (1, 1)),
#  '.xoo.x..o': (-inf, 300, (1, 1)),
#  '.xoo.x.ox': (300, 300, (2, 0)),
#  '.xoo.xo.x': (-inf, 300, (1, 1)),
#  '.xoo.xoox': (300, 300, (1, 1)),
#  '.xoo.xxoo': (-inf, 0.0, (1, 1)),
#  '.xooo.xox': (-inf, 0.0, (0, 1)),
#  '.xooo.xx.': (300, inf, (0, 2)),
#  '.xooo.xxo': (300, inf, (2, 0)),
#  '.xooox..x': (-inf, 300, (2, 1)),
#  '.xooox.ox': (-inf, 0.0, (2, 0)),
#  '.xooox.xo': (-inf, 300, (0, 2)),
#  '.xoooxxo.': (-inf, 0.0, (2, 0)),
#  '.xoooxxox': (-inf, 0.0, (2, 2)),
#  '.xoooxxxo': (300, 300, (2, 2)),
#  '.xoox....': (-inf, 0.0, (0, 2)),
#  '.xoox...o': (-inf, 0.0, (0, 1)),
#  '.xoox..o.': (-inf, 0.0, (0, 2)),
#  '.xoox..ox': (-inf, 0.0, (2, 0)),
#  '.xoox.o..': (-inf, -300, (2, 0)),
#  '.xoox.oox': (-inf, -300, (2, 0)),
#  '.xoox.x.o': (300, inf, (1, 2)),
#  '.xoox.xo.': (0.0, inf, (2, 0)),
#  '.xoox.xoo': (0.0, 0.0, (0, 1)),
#  '.xooxo...': (-inf, -300, (0, 2)),
#  '.xooxo..x': (-inf, -300, (2, 0)),
#  '.xooxo.ox': (-inf, -300, (2, 0)),
#  '.xooxoo.x': (-inf, -300, (2, 0)),
#  '.xooxox..': (300, inf, (0, 2)),
#  '.xooxoxo.': (-inf, 0.0, (0, 2)),
#  '.xooxoxox': (0.0, 0.0, (2, 0)),
#  '.xooxx..o': (0.0, 0.0, (2, 1)),
#  '.xooxx.o.': (300, inf, (2, 2)),
#  '.xooxx.oo': (0.0, 0.0, (2, 2)),
#  '.xooxxo..': (300, inf, (2, 1)),
#  '.xooxxo.o': (-inf, -300, (2, 1)),
#  '.xooxxoo.': (300, inf, (2, 0)),
#  '.xooxxoox': (300, 300, (0, 2)),
#  '.xooxxxoo': (0.0, 0.0, (2, 2)),
#  '.xox....o': (300, inf, (1, 0)),
#  '.xox..xoo': (300, inf, (0, 1)),
#  '.xox.o...': (300, inf, (1, 1)),
#  '.xox.o.ox': (0.0, inf, (1, 1)),
#  '.xox.x.oo': (300, inf, (1, 1)),
#  '.xoxo....': (300, inf, (2, 0)),
#  '.xoxo.xoo': (-inf, -300, (2, 2)),
#  '.xoxoo...': (300, inf, (2, 0)),
#  '.xoxoo..x': (300, inf, (2, 2)),
#  '.xoxoo.ox': (0.0, 0.0, (0, 2)),
#  '.xoxoo.x.': (300, inf, (2, 0)),
#  '.xoxoox..': (300, inf, (0, 2)),
#  '.xoxooxo.': (-inf, 0.0, (2, 0)),
#  '.xoxooxox': (0.0, 0.0, (0, 2)),
#  '.xoxox..o': (300, inf, (2, 1)),
#  '.xoxox.oo': (300, inf, (0, 2)),
#  '.xoxoxxoo': (300, inf, (0, 2)),
#  '.xoxx.o.o': (300, inf, (0, 1)),
#  '.xoxx.oo.': (300, inf, (0, 2)),
#  '.xoxxoo..': (300, inf, (0, 2)),
#  '.xx....oo': (300, inf, (0, 2)),
#  '.xx...o.o': (300, inf, (1, 0)),
#  '.xx...oo.': (300, inf, (2, 0)),
#  '.xx..o..o': (-300, -300, (0, 1)),
#  '.xx..o.o.': (300, inf, (0, 2)),
#  '.xx..o.oo': (-300, -300, (0, 2)),
#  '.xx..oo..': (300, inf, (0, 2)),
#  '.xx..oo.o': (-inf, -300, (0, 1)),
#  '.xx..ooo.': (-inf, 0.0, (2, 0)),
#  '.xx..ooox': (-inf, 0.0, (0, 2)),
#  '.xx..ooxo': (-300, -300, (1, 1)),
#  '.xx..oxoo': (-300, -300, (1, 1)),
#  '.xx.o...o': (300, inf, (0, 2)),
#  '.xx.o..o.': (-inf, 0.0, (0, 2)),
#  '.xx.o..oo': (-inf, -300, (2, 2)),
#  '.xx.o.o..': (300, 300, (2, 0)),
#  '.xx.o.o.o': (-inf, -300, (2, 0)),
#  '.xx.o.oo.': (-inf, -300, (2, 0)),
#  '.xx.o.oox': (-300, -300, (0, 1)),
#  '.xx.o.oxo': (300, inf, (2, 2)),
#  '.xx.o.xoo': (300, inf, (2, 2)),
#  '.xx.oo...': (300, inf, (0, 2)),
#  '.xx.oo..o': (-inf, -300, (2, 2)),
#  '.xx.oo.o.': (-inf, -300, (0, 2)),
#  '.xx.oo.ox': (300, 300, (1, 2)),
#  '.xx.oo.xo': (300, inf, (2, 1)),
#  '.xx.ooo..': (-inf, -300, (0, 2)),
#  '.xx.ooo.x': (300, inf, (1, 2)),
#  '.xx.oooox': (-300, -300, (2, 2)),
#  '.xx.ooox.': (300, inf, (0, 2)),
#  '.xx.oooxo': (-300, -300, (2, 2)),
#  '.xx.oox.o': (300, inf, (1, 2)),
#  '.xx.ooxoo': (-300, -300, (2, 2)),
#  '.xx.ox.oo': (300, 300, (0, 2)),
#  '.xx.oxo.o': (300, inf, (2, 1)),
#  '.xx.oxoo.': (300, inf, (2, 0)),
#  '.xx.xo.oo': (300, inf, (0, 2)),
#  '.xx.xoo.o': (300, inf, (0, 1)),
#  '.xxo..o..': (300, inf, (2, 0)),
#  '.xxo..oox': (-300, inf, (1, 1)),
#  '.xxo..oxo': (-300, inf, (1, 1)),
#  '.xxo..xoo': (-inf, -300, (0, 1)),
#  '.xxo.o...': (300, inf, (1, 1)),
#  '.xxo.o..o': (-inf, -300, (1, 1)),
#  '.xxo.o.xo': (300, inf, (1, 1)),
#  '.xxo.oo.x': (300, inf, (1, 1)),
#  '.xxo.ooox': (-inf, -300, (0, 2)),
#  '.xxo.ooxo': (-inf, -300, (1, 1)),
#  '.xxo.oxoo': (-inf, -300, (1, 1)),
#  '.xxoo....': (300, 300, (2, 0)),
#  '.xxoo...o': (-inf, -300, (2, 0)),
#  '.xxoo..o.': (-inf, -300, (2, 0)),
#  '.xxoo.o..': (-inf, -300, (2, 0)),
#  '.xxoo.o.x': (300, inf, (2, 1)),
#  '.xxoo.oox': (-300, -300, (2, 1)),
#  '.xxoo.ox.': (300, inf, (2, 1)),
#  '.xxoo.oxo': (-300, -300, (0, 2)),
#  '.xxoo.xo.': (300, inf, (2, 0)),
#  '.xxoo.xoo': (-inf, -300, (2, 2)),
#  '.xxoox..o': (300, inf, (2, 0)),
#  '.xxoox.oo': (-inf, 300, (0, 2)),
#  '.xxooxo..': (300, inf, (2, 0)),
#  '.xxooxoxo': (300, inf, (2, 2)),
#  '.xxooxxoo': (300, 300, (2, 2)),
#  '.xxoxo..o': (-inf, -300, (0, 1)),
#  '.xxoxo.oo': (-inf, -300, (0, 2)),
#  '.xxoxoo..': (300, inf, (0, 2)),
#  '.xxoxoo.o': (-inf, -300, (0, 1)),
#  '.xxoxooo.': (-inf, -300, (0, 2)),
#  '.xxoxooox': (300, inf, (0, 2)),
#  '.xxx.o.oo': (300, inf, (0, 2)),
#  '.xxx.oo.o': (300, inf, (0, 1)),
#  '.xxxo..oo': (300, inf, (0, 2)),
#  '.xxxo.oo.': (300, inf, (0, 2)),
#  '.xxxoo..o': (300, inf, (2, 2)),
#  '.xxxoo.o.': (-inf, 0.0, (0, 2)),
#  '.xxxoo.oo': (-300, -300, (2, 2)),
#  '.xxxooo.o': (-inf, -300, (2, 2)),
#  '.xxxoooo.': (-inf, 0.0, (2, 0)),
#  '.xxxoooox': (0.0, 0.0, (0, 2)),
#  '.xxxoooxo': (300, inf, (0, 2)),
#  '.xxxooxoo': (300, inf, (2, 2)),
#  'o........': (0.0, 0.0, (1, 1)),
#  'o.......x': (0.0, inf, (2, 0)),
#  'o......ox': (-inf, 0.0, (1, 1)),
#  'o......x.': (300, inf, (2, 0)),
#  'o......xo': (-inf, 300, (2, 0)),
#  'o.....o.x': (0.0, inf, (1, 0)),
#  'o.....ox.': (300, 300, (1, 0)),
#  'o.....oxx': (300, 300, (1, 0)),
#  'o.....x..': (300, inf, (0, 1)),
#  'o.....xo.': (-inf, 0.0, (1, 1)),
#  'o.....xox': (300, 300, (1, 2)),
#  'o.....xxo': (-inf, 300, (0, 1)),
#  'o....o..x': (-inf, 0.0, (1, 1)),
#  'o....o.xx': (300, inf, (0, 2)),
#  'o....ooxx': (300, 300, (2, 0)),
#  'o....oxox': (-inf, 0.0, (1, 1)),
#  'o....oxxo': (-inf, 300, (1, 1)),
#  'o....x...': (300, inf, (2, 0)),
#  'o....x..o': (-inf, 300, (2, 0)),
#  'o....x.ox': (300, inf, (0, 2)),
#  'o....xo.x': (300, inf, (1, 0)),
#  'o....xoox': (-inf, -300, (0, 1)),
#  'o....xox.': (300, inf, (1, 0)),
#  'o....xoxo': (-inf, 300, (1, 1)),
#  'o...o...x': (-inf, 0.0, (2, 0)),
#  'o...o..xx': (300, 300, (2, 0)),
#  'o...o.oxx': (300, 300, (0, 1)),
#  'o...o.x..': (-inf, 0.0, (0, 2)),
#  'o...o.x.x': (-inf, 0.0, (0, 1)),
#  'o...o.xox': (-inf, 0.0, (1, 2)),
#  'o...o.xx.': (300, inf, (0, 2)),
#  'o...oo.xx': (-inf, -300, (0, 2)),
#  'o...oox.x': (-inf, 0.0, (1, 0)),
#  'o...ooxx.': (-inf, -300, (2, 0)),
#  'o...ox..x': (300, 300, (2, 0)),
#  'o...ox.ox': (-inf, -300, (0, 2)),
#  'o...oxo.x': (-inf, -300, (2, 0)),
#  'o...oxoxx': (300, inf, (2, 1)),
#  'o...oxxox': (300, inf, (1, 2)),
#  'o...x....': (0.0, 0.0, (1, 0)),
#  'o...x...o': (-inf, 0.0, (1, 0)),
#  'o...x..o.': (-inf, 0.0, (1, 0)),
#  'o...x..ox': (-inf, 0.0, (2, 0)),
#  'o...x..xo': (-inf, 0.0, (0, 1)),
#  'o...x.o..': (-inf, 0.0, (1, 0)),
#  'o...x.o.x': (300, inf, (1, 0)),
#  'o...x.oox': (0.0, 0.0, (0, 1)),
#  'o...x.ox.': (300, inf, (1, 0)),
#  'o...x.oxo': (-inf, -300, (0, 1)),
#  'o...x.xo.': (-inf, 0.0, (2, 0)),
#  'o...x.xoo': (-inf, 0.0, (0, 1)),
#  'o...xo...': (-inf, 0.0, (1, 0)),
#  'o...xo..x': (-inf, 0.0, (2, 0)),
#  'o...xo.ox': (0.0, 0.0, (2, 0)),
#  'o...xo.xo': (-inf, 0.0, (0, 2)),
#  'o...xoo.x': (-inf, 0.0, (1, 2)),
#  'o...xoox.': (-inf, 0.0, (0, 1)),
#  'o...xooxx': (300, inf, (0, 1)),
#  'o...xoxo.': (-inf, 0.0, (2, 0)),
#  'o...xoxox': (0.0, 0.0, (0, 2)),
#  'o...xoxxo': (300, 300, (0, 2)),
#  'o...xx..o': (-inf, 0.0, (0, 1)),
#  'o...xx.oo': (-inf, 0.0, (0, 2)),
#  'o...xxo.o': (-inf, -300, (1, 2)),
#  'o...xxoox': (300, inf, (0, 1)),
#  'o...xxoxo': (300, 300, (1, 2)),
#  'o...xxxoo': (-inf, 0.0, (0, 2)),
#  'o..o....x': (-300, -300, (2, 0)),
#  'o..o...x.': (-300, -300, (2, 0)),
#  'o..o...xx': (300, inf, (2, 0)),
#  'o..o..x..': (-300, -300, (2, 1)),
#  'o..o..x.x': (-300, -300, (0, 1)),
#  'o..o..xox': (-inf, -300, (0, 2)),
#  'o..o..xx.': (-300, -300, (0, 1)),
#  'o..o..xxo': (-inf, -300, (1, 1)),
#  'o..o.ox.x': (-inf, -300, (1, 1)),
#  'o..o.oxx.': (-inf, -300, (1, 1)),
#  'o..o.x...': (0.0, inf, (2, 0)),
#  'o..o.x..x': (300, inf, (2, 0)),
#  'o..o.x.ox': (-inf, 0.0, (2, 0)),
#  'o..o.x.x.': (300, inf, (2, 0)),
#  'o..o.xx..': (0.0, inf, (0, 2)),
#  'o..o.xxo.': (-inf, -300, (0, 2)),
#  'o..o.xxox': (-inf, 0.0, (0, 2)),
#  'o..o.xxxo': (-inf, 300, (1, 1)),
#  'o..oo..xx': (-inf, -300, (2, 0)),
#  'o..oo.x.x': (-inf, -300, (2, 1)),
#  'o..oo.xx.': (-inf, -300, (2, 2)),
#  'o..oox..x': (-inf, -300, (2, 0)),
#  'o..oox.xx': (300, inf, (2, 0)),
#  'o..ooxx..': (-300, -300, (0, 2)),
#  'o..ooxx.x': (-300, -300, (0, 1)),
#  'o..ooxxox': (-300, -300, (2, 2)),
#  'o..ooxxx.': (300, inf, (2, 2)),
#  'o..ox....': (0.0, 0.0, (2, 0)),
#  'o..ox...x': (300, inf, (2, 0)),
#  'o..ox..ox': (-inf, 0.0, (2, 0)),
#  'o..ox..x.': (300, inf, (2, 0)),
#  'o..ox..xo': (-inf, -300, (2, 0)),
#  'o..ox.x..': (0.0, 0.0, (0, 2)),
#  'o..ox.x.o': (-inf, 0.0, (0, 1)),
#  'o..ox.xo.': (-inf, -300, (0, 2)),
#  'o..ox.xox': (0.0, 0.0, (0, 2)),
#  'o..ox.xxo': (-inf, -300, (0, 1)),
#  'o..oxo..x': (-inf, -300, (0, 2)),
#  'o..oxo.xx': (300, inf, (0, 2)),
#  'o..oxox..': (-inf, -300, (0, 1)),
#  'o..oxox.x': (-inf, -300, (0, 1)),
#  'o..oxoxox': (-inf, -300, (0, 2)),
#  'o..oxoxx.': (-inf, -300, (0, 1)),
#  'o..oxoxxo': (-inf, -300, (0, 2)),
#  'o..oxx...': (300, inf, (2, 0)),
#  'o..oxx..o': (-inf, 0.0, (0, 2)),
#  'o..oxx.xo': (300, inf, (2, 1)),
#  'o..oxxx.o': (-inf, 0.0, (2, 0)),
#  'o..oxxxo.': (0.0, inf, (0, 2)),
#  'o..oxxxoo': (-inf, -300, (0, 2)),
#  'o..x.....': (300, 300, (0, 1)),
#  'o..x....o': (-inf, 300, (2, 0)),
#  'o..x...o.': (-inf, 300, (2, 0)),
#  'o..x..o..': (0.0, 0.0, (1, 1)),
#  'o..x..o.x': (0.0, inf, (1, 1)),
#  'o..x..oox': (-300, -300, (1, 2)),
#  'o..x..ox.': (300, 300, (1, 1)),
#  'o..x..oxo': (-inf, -300, (1, 1)),
#  'o..x..x.o': (-inf, 300, (0, 1)),
#  'o..x..xo.': (300, 300, (1, 1)),
#  'o..x..xoo': (-inf, -300, (1, 1)),
#  'o..x.o...': (-inf, 300, (2, 0)),
#  'o..x.oox.': (-inf, 300, (1, 1)),
#  'o..x.ooxx': (300, 300, (2, 0)),
#  'o..x.ox..': (-inf, 300, (0, 1)),
#  'o..x.ox.o': (-inf, 300, (0, 1)),
#  'o..x.oxo.': (300, 300, (2, 0)),
#  'o..x.oxox': (300, inf, (1, 2)),
#  'o..x.xo..': (300, inf, (1, 1)),
#  'o..x.xoo.': (-300, -300, (1, 1)),
#  'o..x.xoox': (-300, -300, (1, 1)),
#  'o..x.xxoo': (300, inf, (1, 1)),
#  'o..xo....': (0.0, 300, (2, 2)),
#  'o..xo...x': (0.0, inf, (2, 0)),
#  'o..xo..x.': (300, inf, (2, 0)),
#  'o..xo.o.x': (0.0, inf, (2, 2)),
#  'o..xo.ox.': (300, 300, (2, 1)),
#  'o..xo.oxx': (300, 300, (2, 2)),
#  'o..xo.x..': (300, 300, (0, 1)),
#  'o..xo.xo.': (300, 300, (2, 0)),
#  'o..xo.xox': (300, 300, (1, 2)),
#  'o..xoo..x': (-inf, 0.0, (2, 0)),
#  'o..xoooxx': (-inf, 0.0, (2, 2)),
#  'o..xoox..': (-inf, 0.0, (2, 0)),
#  'o..xoox.x': (-inf, 0.0, (0, 1)),
#  'o..xooxox': (-inf, 0.0, (1, 2)),
#  'o..xooxx.': (300, inf, (2, 0)),
#  'o..xox...': (300, inf, (2, 0)),
#  'o..xox.ox': (300, inf, (0, 2)),
#  'o..xoxo..': (300, inf, (0, 1)),
#  'o..xoxo.x': (300, inf, (2, 2)),
#  'o..xoxoox': (-300, -300, (2, 2)),
#  'o..xoxox.': (300, inf, (2, 1)),
#  'o..xoxxo.': (300, inf, (2, 0)),
#  'o..xx...o': (-inf, 0.0, (0, 1)),
# ...
#  'xoo....xo': (0.0, inf, (0, 1)),
#  'xoo...x..': (-300, -300, (0, 1)),
#  'xoo...x.o': (-inf, -300, (2, 1)),
#  'xoo...xo.': (-inf, -300, (1, 1)),
#  'xoo...xox': (300, inf, (1, 1)),
#  'xoo...xxo': (300, inf, (0, 1)),
#  'xoo..o..x': (-300, -300, (1, 1)),
#  'xoo..o.x.': (-300, -300, (0, 2)),
#  'xoo..o.xx': (-300, -300, (1, 1)),
#  'xoo..ooxx': (-inf, -300, (1, 1)),
#  'xoo..ox..': (-300, -300, (2, 1)),
#  'xoo..ox.x': (-300, inf, (1, 1)),
#  'xoo..oxox': (-inf, -300, (1, 1)),
#  'xoo..oxx.': (-300, inf, (1, 1)),
#  'xoo..x...': (300, inf, (1, 1)),
#  'xoo..x..o': (-300, -300, (1, 2)),
#  'xoo..x.xo': (0.0, 0.0, (1, 1)),
#  'xoo..xoxo': (-inf, 0.0, (1, 1)),
#  'xoo..xx.o': (0.0, 0.0, (2, 1)),
#  'xoo..xxo.': (300, inf, (1, 1)),
#  'xoo..xxoo': (-inf, 0.0, (1, 1)),
#  'xoo.o...x': (300, inf, (1, 0)),
#  'xoo.o..x.': (-300, -300, (0, 2)),
#  'xoo.o..xx': (300, inf, (2, 2)),
#  'xoo.o.x..': (-inf, -300, (2, 1)),
#  'xoo.o.x.x': (300, inf, (2, 1)),
#  'xoo.o.xx.': (-300, -300, (0, 1)),
#  'xoo.o.xxo': (-inf, -300, (0, 1)),
#  'xoo.oo.xx': (-300, -300, (2, 2)),
#  'xoo.oox.x': (-300, -300, (2, 1)),
#  'xoo.ooxx.': (-300, -300, (2, 1)),
#  'xoo.ox...': (300, inf, (2, 0)),
#  'xoo.ox..x': (300, inf, (2, 1)),
#  'xoo.ox.x.': (300, inf, (2, 2)),
#  'xoo.ox.xo': (0.0, 0.0, (0, 2)),
#  'xoo.oxx..': (300, inf, (2, 1)),
#  'xoo.oxx.o': (-300, -300, (1, 2)),
#  'xoo.oxxxo': (0.0, 0.0, (1, 2)),
#  'xoo.x....': (0.0, 0.0, (0, 2)),
#  'xoo.x...o': (0.0, 0.0, (0, 1)),
#  'xoo.x..o.': (-inf, -300, (0, 1)),
#  'xoo.x..xo': (300, inf, (0, 1)),
#  'xoo.x.o..': (-inf, 0.0, (0, 1)),
#  'xoo.x.ox.': (-inf, 0.0, (2, 0)),
#  'xoo.x.oxo': (-inf, 0.0, (2, 1)),
#  'xoo.x.x.o': (300, inf, (0, 1)),
#  'xoo.x.xo.': (-inf, -300, (0, 1)),
#  'xoo.x.xoo': (-inf, -300, (2, 1)),
#  'xoo.xo...': (-300, -300, (0, 2)),
#  'xoo.xo.x.': (300, inf, (0, 2)),
#  'xoo.xoox.': (-inf, -300, (2, 0)),
#  'xoo.xox..': (300, inf, (0, 2)),
#  'xoo.xoxo.': (-inf, -300, (2, 1)),
#  'xoo.xx..o': (0.0, 0.0, (1, 2)),
#  'xoo.xx.o.': (-inf, -300, (2, 0)),
#  'xoo.xx.oo': (-300, -300, (1, 2)),
#  'xoo.xxo..': (-inf, 0.0, (0, 2)),
#  'xoo.xxo.o': (-inf, 0.0, (2, 1)),
#  'xoo.xxoo.': (-inf, -300, (2, 0)),
#  'xoo.xxoxo': (-inf, 0.0, (1, 2)),
#  'xoo.xxxoo': (0.0, 0.0, (1, 2)),
#  'xooo....x': (-inf, -300, (1, 1)),
#  'xooo...x.': (-inf, -300, (0, 2)),
#  'xooo...xx': (-inf, -300, (0, 1)),
#  'xooo..oxx': (-inf, -300, (1, 1)),
#  'xooo..x..': (-inf, -300, (0, 2)),
#  'xooo..x.x': (-inf, -300, (0, 1)),
#  'xooo..xox': (-inf, -300, (1, 1)),
#  'xooo..xx.': (-inf, 0.0, (0, 2)),
#  'xooo..xxo': (-inf, 0.0, (1, 2)),
#  'xooo.o.xx': (-inf, -300, (1, 1)),
#  'xooo.ox.x': (-inf, -300, (1, 1)),
#  'xooo.oxx.': (-inf, -300, (0, 2)),
#  'xooo.x...': (0.0, inf, (1, 1)),
#  'xooo.x..x': (300, inf, (1, 1)),
#  'xooo.x.x.': (0.0, inf, (1, 1)),
#  'xooo.x.xo': (-inf, 0.0, (1, 1)),
#  'xooo.xo.x': (-inf, -300, (1, 1)),
#  'xooo.xoxx': (300, inf, (1, 1)),
#  'xooo.xx..': (0.0, inf, (1, 1)),
#  'xooo.xx.o': (0.0, 0.0, (1, 1)),
#  'xooo.xxox': (300, inf, (1, 1)),
#  'xooo.xxxo': (0.0, 0.0, (1, 1)),
#  'xoooo..xx': (-inf, -300, (2, 2)),
#  'xoooo.x.x': (-inf, -300, (1, 2)),
#  'xoooo.xx.': (-300, -300, (2, 2)),
#  'xoooox..x': (300, inf, (0, 2)),
#  'xoooox.x.': (0.0, 0.0, (0, 2)),
#  'xoooox.xx': (300, 300, (2, 2)),
#  'xooooxx..': (0.0, 0.0, (2, 1)),
#  'xooooxx.x': (300, inf, (1, 2)),
#  'xooooxxx.': (0.0, 0.0, (0, 2)),
#  'xooox....': (-inf, -300, (0, 2)),
#  'xooox..x.': (0.0, inf, (0, 2)),
#  'xooox..xo': (0.0, 0.0, (0, 1)),
#  'xooox.ox.': (-inf, -300, (0, 2)),
#  'xooox.x..': (0.0, 0.0, (0, 2)),
#  'xooox.x.o': (0.0, 0.0, (1, 2)),
#  'xooox.xo.': (-inf, -300, (0, 2)),
#  'xooox.xxo': (300, 300, (1, 2)),
#  'xoooxo.x.': (-300, -300, (0, 2)),
#  'xoooxox..': (-300, -300, (0, 2)),
#  'xoooxoxx.': (300, inf, (0, 2)),
#  'xoooxx...': (0.0, 0.0, (0, 2)),
#  'xoooxx..o': (0.0, 0.0, (2, 1)),
#  'xoooxx.o.': (-inf, -300, (2, 0)),
#  'xoooxx.xo': (0.0, 0.0, (2, 2)),
#  'xoooxxo..': (-inf, -300, (0, 2)),
#  'xoooxxx.o': (0.0, 0.0, (2, 1)),
#  'xoooxxxo.': (0.0, 0.0, (2, 0)),
#  'xoox.....': (-300, -300, (0, 1)),
#  'xoox....o': (-inf, -300, (0, 1)),
#  'xoox...o.': (-inf, -300, (1, 1)),
#  'xoox...xo': (300, inf, (0, 1)),
#  'xoox..o..': (-inf, -300, (1, 1)),
#  'xoox..ox.': (-inf, 300, (1, 1)),
#  'xoox..oxo': (300, 300, (1, 1)),
#  'xoox.o...': (-300, -300, (0, 2)),
#  'xoox.o..x': (-300, -300, (1, 1)),
#  'xoox.o.ox': (-inf, -300, (1, 1)),
#  'xoox.o.x.': (300, inf, (0, 2)),
#  'xoox.oo.x': (-inf, -300, (1, 1)),
#  'xoox.oox.': (300, 300, (1, 1)),
#  'xoox.ooxx': (300, inf, (1, 1)),
#  'xoox.x..o': (-300, -300, (1, 1)),
#  'xoox.x.o.': (300, inf, (1, 1)),
#  'xoox.x.oo': (-inf, -300, (1, 1)),
#  'xoox.xo..': (300, inf, (1, 1)),
#  'xoox.xo.o': (-inf, -300, (1, 1)),
#  'xoox.xoxo': (300, inf, (1, 1)),
#  'xooxo....': (-inf, -300, (2, 2)),
#  'xooxo...x': (300, inf, (1, 2)),
#  'xooxo..x.': (300, inf, (2, 2)),
#  'xooxo..xo': (-inf, -300, (2, 2)),
#  'xooxoo..x': (-300, -300, (2, 2)),
#  'xooxoo.x.': (-300, -300, (2, 2)),
#  'xooxoo.xx': (300, inf, (2, 2)),
#  'xooxox...': (300, inf, (2, 1)),
#  'xooxox..o': (-300, -300, (2, 2)),
#  'xooxox.xo': (300, inf, (0, 2)),
#  'xooxx...o': (300, inf, (0, 1)),
#  'xooxx..o.': (-inf, -300, (0, 1)),
#  'xooxx..oo': (-inf, -300, (0, 1)),
#  'xooxx.o..': (-inf, -300, (0, 1)),
#  'xooxx.o.o': (-inf, -300, (0, 1)),
#  'xooxx.oo.': (-inf, -300, (0, 2)),
#  'xooxx.oxo': (300, 300, (2, 1)),
#  'xooxxo...': (300, inf, (0, 2)),
#  'xooxxo.o.': (-inf, -300, (0, 2)),
#  'xooxxoo..': (-inf, -300, (0, 2)),
#  'xooxxoox.': (300, 300, (0, 2)),
#  'xox.....o': (300, 300, (1, 2)),
#  'xox....o.': (300, 300, (1, 1)),
#  'xox....oo': (300, 300, (0, 1)),
#  'xox...o..': (300, 300, (1, 2)),
#  'xox...o.o': (-inf, 300, (0, 1)),
#  'xox...oo.': (300, 300, (0, 1)),
#  'xox...oox': (300, inf, (1, 1)),
#  'xox...xoo': (300, inf, (1, 1)),
#  'xox..o...': (300, 300, (1, 1)),
#  'xox..o..o': (-inf, -300, (0, 2)),
#  'xox..o.o.': (-inf, -300, (1, 1)),
#  'xox..o.xo': (0.0, inf, (1, 1)),
#  'xox..oo..': (-inf, 0.0, (1, 1)),
#  'xox..ooox': (-inf, -300, (1, 1)),
#  'xox..ooxo': (0.0, 0.0, (1, 1)),
#  'xox..ox.o': (-inf, -300, (0, 1)),
#  'xox..oxoo': (-inf, -300, (1, 1)),
#  'xox..x.oo': (300, 300, (1, 1)),
#  'xox..xo.o': (300, 300, (1, 2)),
#  'xox..xoo.': (300, inf, (1, 1)),
#  'xox.o....': (300, 300, (0, 1)),
#  'xox.o...o': (-inf, 0.0, (1, 2)),
#  'xox.o..xo': (-inf, 0.0, (0, 1)),
#  'xox.o.o..': (-inf, 0.0, (1, 2)),
#  'xox.o.ox.': (-inf, 0.0, (0, 1)),
#  'xox.o.oxo': (0.0, 0.0, (0, 1)),
#  'xox.oo...': (300, 300, (2, 1)),
#  'xox.oo..x': (300, inf, (2, 1)),
#  'xox.oo.x.': (300, inf, (2, 1)),
#  'xox.oo.xo': (0.0, 0.0, (2, 1)),
#  'xox.ooox.': (-inf, 0.0, (0, 1)),
#  'xox.oooxx': (300, 300, (1, 2)),
#  'xox.oox..': (300, inf, (2, 1)),
#  'xox.oox.o': (-inf, -300, (1, 2)),
#  'xox.ooxxo': (300, inf, (1, 2)),
#  'xox.ox..o': (300, 300, (1, 2)),
#  'xox.oxo..': (300, inf, (1, 2)),
#  'xox.oxo.o': (-inf, 0.0, (1, 2)),
#  'xox.oxoxo': (0.0, 0.0, (2, 1)),
#  'xox.x..oo': (300, inf, (0, 2)),
#  'xox.x.o.o': (300, inf, (1, 2)),
#  'xox.x.oo.': (300, inf, (0, 2)),
#  'xox.xo..o': (0.0, 0.0, (0, 2)),
#  'xox.xo.o.': (-inf, -300, (0, 1)),
#  'xox.xo.oo': (-300, -300, (0, 2)),
#  'xox.xoo..': (0.0, 0.0, (0, 2)),
#  'xox.xoo.o': (0.0, 0.0, (1, 2)),
#  'xox.xooo.': (-inf, -300, (0, 2)),
#  'xox.xooxo': (0.0, 0.0, (2, 1)),
#  'xoxo.....': (300, 300, (1, 1)),
#  'xoxo....o': (-inf, 0.0, (1, 1)),
#  'xoxo...o.': (-inf, -300, (1, 1)),
#  'xoxo..o..': (-inf, -300, (0, 2)),
#  'xoxo..o.x': (-inf, -300, (0, 1)),
#  'xoxo..oox': (-inf, -300, (1, 1)),
#  'xoxo..ox.': (0.0, inf, (1, 1)),
#  'xoxo..oxo': (0.0, 0.0, (1, 1)),
#  'xoxo..xoo': (-inf, -300, (1, 1)),
#  'xoxo.o...': (-inf, -300, (1, 1)),
#  'xoxo.oo.x': (-inf, -300, (1, 1)),
#  'xoxo.ooxx': (300, inf, (1, 1)),
#  'xoxo.ox.o': (-inf, -300, (1, 1)),
#  'xoxo.oxxo': (300, inf, (1, 1)),
#  'xoxo.x..o': (300, inf, (1, 2)),
#  'xoxo.x.oo': (300, 300, (1, 1)),
#  'xoxo.xo..': (-inf, 0.0, (0, 2)),
#  'xoxo.xo.o': (-inf, 0.0, (1, 2)),
#  'xoxo.xoo.': (-inf, -300, (0, 2)),
#  'xoxo.xoxo': (0.0, 0.0, (1, 1)),
#  'xoxo.xxoo': (300, inf, (1, 1)),
#  'xoxoo....': (300, 300, (2, 1)),
#  'xoxoo...x': (300, inf, (2, 1)),
#  'xoxoo..x.': (300, inf, (2, 1)),
#  'xoxoo..xo': (-inf, 0.0, (0, 1)),
#  'xoxoo.o.x': (-inf, -300, (1, 2)),
#  'xoxoo.ox.': (0.0, 0.0, (2, 1)),
#  'xoxoo.oxx': (300, inf, (1, 2)),
#  'xoxoo.x..': (300, inf, (2, 1)),
#  'xoxoo.xxo': (300, 300, (1, 2)),
#  'xoxoox...': (300, 300, (1, 2)),
#  'xoxoox..o': (-inf, 0.0, (1, 2)),
#  'xoxoox.xo': (-inf, 0.0, (2, 2)),
#  'xoxooxo..': (-300, -300, (2, 2)),
#  'xoxooxox.': (0.0, 0.0, (0, 2)),
#  'xoxooxx.o': (300, 300, (1, 2)),
#  'xoxox...o': (0.0, 0.0, (0, 2)),
#  'xoxox..o.': (-inf, -300, (0, 1)),
#  'xoxox..oo': (-inf, -300, (0, 2)),
#  'xoxox.o..': (0.0, 0.0, (0, 2)),
#  'xoxox.o.o': (0.0, 0.0, (1, 2)),
#  'xoxox.oo.': (-300, -300, (0, 2)),
#  'xoxox.oxo': (0.0, 0.0, (2, 1)),
#  'xoxoxo...': (-inf, -300, (0, 2)),
#  'xoxoxo..o': (-inf, -300, (0, 2)),
#  'xoxoxo.o.': (-inf, -300, (0, 2)),
#  'xoxoxo.xo': (0.0, 0.0, (2, 0)),
#  'xoxoxoo..': (-inf, -300, (0, 2)),
#  'xoxoxoox.': (0.0, 0.0, (2, 0)),
#  'xoxoxx.oo': (300, 300, (0, 2)),
#  'xoxoxxo.o': (300, 300, (1, 2)),
#  'xoxoxxoo.': (300, inf, (0, 2)),
#  'xoxx...oo': (300, inf, (1, 1)),
#  'xoxx..o.o': (300, 300, (1, 2)),
#  'xoxx..oo.': (300, 300, (1, 1)),
#  'xoxx.o..o': (-inf, 0.0, (0, 2)),
#  'xoxx.o.oo': (-inf, -300, (0, 2)),
#  'xoxx.oo..': (300, inf, (1, 2)),
#  'xoxx.oo.o': (-inf, 0.0, (1, 2)),
#  'xoxx.ooo.': (300, 300, (1, 1)),
#  'xoxx.ooox': (300, inf, (1, 1)),
#  'xoxx.ooxo': (0.0, 0.0, (1, 1)),
#  'xoxxo...o': (300, inf, (1, 2)),
#  'xoxxo.o..': (300, 300, (1, 2)),
#  'xoxxo.o.o': (-inf, 0.0, (1, 2)),
#  'xoxxo.oxo': (0.0, 0.0, (2, 1)),
#  'xoxxoo...': (300, 300, (1, 2)),
#  'xoxxoo..o': (-300, -300, (2, 2)),
#  'xoxxoo.xo': (0.0, 0.0, (0, 2)),
#  'xoxxooo..': (-inf, 0.0, (1, 2)),
#  'xoxxooo.x': (300, 300, (1, 2)),
#  'xoxxooox.': (-inf, 0.0, (2, 2)),
#  'xoxxoxo.o': (300, 300, (1, 2)),
#  'xoxxxo.oo': (300, inf, (0, 2)),
#  'xoxxxoo.o': (300, 300, (1, 2)),
#  'xoxxxooo.': (300, 300, (0, 2)),
#  'xx.....oo': (300, inf, (2, 0)),
#  'xx....o.o': (300, inf, (1, 0)),
#  'xx....oo.': (300, inf, (0, 2)),
#  'xx...o..o': (300, inf, (2, 0)),
#  'xx...ooox': (-inf, -300, (0, 1)),
#  'xx...ooxo': (-300, inf, (1, 1)),
#  'xx...oxoo': (-300, inf, (1, 1)),
#  'xx..o...o': (300, 300, (2, 0)),
#  'xx..o..o.': (-inf, 0.0, (0, 2)),
#  'xx..o..oo': (-inf, -300, (2, 0)),
#  'xx..o.o..': (300, inf, (0, 2)),
#  'xx..o.o.o': (-inf, -300, (2, 0)),
#  'xx..o.oo.': (-inf, -300, (2, 2)),
#  'xx..o.oox': (300, inf, (2, 2)),
#  'xx..o.oxo': (300, inf, (2, 2)),
#  'xx..o.xoo': (-300, -300, (0, 1)),
#  'xx..oo...': (300, 300, (2, 0)),
#  'xx..oo..o': (-inf, -300, (2, 0)),
#  'xx..oo.o.': (-inf, -300, (2, 0)),
#  'xx..oo.ox': (300, inf, (2, 0)),
#  'xx..oo.xo': (300, inf, (2, 1)),
#  'xx..ooo..': (-inf, -300, (2, 0)),
#  'xx..oooox': (-inf, -300, (2, 2)),
#  'xx..oooxo': (-300, -300, (0, 2)),
#  'xx..oox.o': (300, inf, (2, 1)),
#  'xx..ooxoo': (-300, -300, (2, 1)),
#  'xx..ox.oo': (300, inf, (0, 2)),
#  'xx..oxoo.': (300, inf, (0, 2)),
#  'xx.o....o': (300, inf, (0, 2)),
#  'xx.o...o.': (300, inf, (0, 2)),
#  'xx.o...oo': (-inf, 0.0, (2, 0)),
#  'xx.o..o..': (-300, -300, (0, 1)),
#  'xx.o..o.o': (-inf, -300, (0, 1)),
#  'xx.o..oo.': (-300, -300, (0, 2)),
#  'xx.o..oox': (-300, -300, (1, 1)),
#  'xx.o..oxo': (-300, -300, (1, 1)),
#  'xx.o..xoo': (-inf, 0.0, (0, 2)),
#  'xx.o.o...': (300, inf, (1, 1)),
#  'xx.o.oo..': (-inf, -300, (1, 1)),
#  'xx.o.ooox': (-inf, -300, (1, 1)),
#  'xx.o.oox.': (300, inf, (1, 1)),
#  'xx.o.ooxo': (-inf, -300, (1, 1)),
#  'xx.o.ox.o': (300, inf, (1, 1)),
#  'xx.o.oxoo': (-inf, -300, (0, 2)),
#  'xx.o.xo.o': (300, inf, (0, 1)),
#  'xx.o.xoo.': (300, inf, (0, 2)),
#  'xx.oo....': (300, inf, (0, 2)),
#  'xx.oo...o': (-inf, -300, (0, 2)),
#  'xx.oo..o.': (-inf, -300, (0, 2)),
#  'xx.oo..xo': (300, inf, (0, 2)),
#  'xx.oo.o..': (-inf, -300, (2, 2)),
#  'xx.oo.o.x': (300, inf, (1, 2)),
#  'xx.oo.oox': (-300, -300, (2, 2)),
#  'xx.oo.ox.': (300, inf, (2, 1)),
#  'xx.oo.oxo': (-300, -300, (2, 2)),
#  'xx.oo.x.o': (300, inf, (1, 2)),
#  'xx.oo.xo.': (300, 300, (1, 2)),
#  'xx.oo.xoo': (-300, -300, (2, 2)),
#  'xx.oox.o.': (-inf, 0.0, (0, 2)),
#  'xx.oox.oo': (-inf, 0.0, (2, 0)),
#  'xx.ooxo..': (300, inf, (2, 2)),
#  'xx.ooxo.o': (-inf, -300, (2, 2)),
#  'xx.ooxoo.': (-300, -300, (2, 2)),
#  'xx.ooxoox': (300, inf, (2, 2)),
#  'xx.ooxoxo': (300, inf, (0, 2)),
#  'xx.ooxxoo': (0.0, 0.0, (0, 2)),
#  'xx.ox.o.o': (300, inf, (0, 1)),
#  'xx.ox.oo.': (300, inf, (0, 2)),
#  'xx.oxo..o': (300, inf, (0, 2)),
#  'xx.oxo.oo': (-inf, -300, (0, 2)),
#  'xx.oxoo..': (-inf, -300, (0, 1)),
#  'xx.oxoo.o': (-inf, -300, (0, 1)),
#  'xx.oxooo.': (-inf, -300, (0, 2)),
#  'xx.oxoxoo': (300, inf, (0, 2)),
#  'xx.xo..oo': (300, inf, (2, 0)),
#  'xx.xo.o.o': (300, inf, (2, 1)),
#  'xx.xo.oo.': (300, 300, (0, 2)),
#  'xx.xoo..o': (300, inf, (2, 0)),
#  'xx.xooo..': (300, inf, (2, 0)),
#  'xx.xoooo.': (-inf, 300, (0, 2)),
#  'xx.xoooox': (300, 300, (2, 2)),
#  'xx.xoooxo': (300, inf, (2, 2)),
#  'xxo.....o': (300, 300, (1, 0)),
#  'xxo....o.': (-inf, 300, (0, 1)),
#  'xxo....oo': (-inf, 300, (0, 1)),
#  'xxo...o..': (-inf, 300, (0, 1)),
#  'xxo...o.o': (-inf, 300, (0, 1)),
#  'xxo...oo.': (-inf, 300, (0, 1)),
#  'xxo...xoo': (300, inf, (0, 1)),
#  'xxo..o...': (300, 300, (1, 1)),
#  'xxo..o.o.': (-inf, 300, (1, 1)),
#  'xxo..o.ox': (300, inf, (1, 1)),
#  'xxo..oo..': (-inf, 300, (1, 1)),
#  'xxo..ooox': (-inf, -300, (1, 1)),
#  'xxo..x.oo': (300, 300, (2, 1)),
#  'xxo..xo.o': (-inf, 300, (1, 1)),
#  'xxo..xoo.': (-inf, 300, (1, 1)),
#  'xxo.o....': (300, 300, (0, 1)),
#  'xxo.o...o': (300, 300, (0, 1)),
#  'xxo.o..o.': (-inf, 0.0, (2, 0)),
#  'xxo.o..xo': (300, inf, (0, 1)),
#  'xxo.o.x.o': (300, inf, (2, 1)),
#  'xxo.o.xo.': (-inf, 0.0, (0, 1)),
#  'xxo.o.xoo': (-inf, -300, (0, 1)),
#  'xxo.oo...': (300, 300, (2, 1)),
#  'xxo.oo..x': (300, inf, (2, 1)),
#  'xxo.oo.ox': (300, inf, (0, 2)),
#  'xxo.oo.x.': (300, inf, (2, 1)),
#  'xxo.oox..': (300, inf, (2, 1)),
#  'xxo.ooxo.': (-inf, -300, (0, 1)),
#  'xxo.ooxox': (300, inf, (1, 2)),
#  'xxo.ox..o': (300, 300, (2, 2)),
#  'xxo.ox.o.': (-inf, 300, (2, 1)),
#  'xxo.ox.oo': (0.0, 0.0, (2, 2)),
#  'xxo.oxxoo': (0.0, 0.0, (1, 2)),
#  'xxo.x.o.o': (300, inf, (0, 1)),
#  'xxo.x.oo.': (300, inf, (0, 2)),
#  'xxo.xo.o.': (-inf, 300, (0, 2)),
#  'xxo.xoo..': (300, 300, (0, 2)),
#  'xxo.xooo.': (-inf, -300, (0, 2)),
#  'xxoo.....': (300, 300, (1, 1)),
#  'xxoo....o': (300, 300, (2, 0)),
#  'xxoo...o.': (300, 300, (2, 0)),
#  'xxoo...ox': (300, inf, (1, 1)),
#  'xxoo...xo': (300, inf, (1, 1)),
#  'xxoo..o..': (-inf, -300, (1, 1)),
#  'xxoo..oox': (-inf, -300, (1, 1)),
#  'xxoo..ox.': (300, inf, (1, 1)),
#  'xxoo..oxo': (-inf, -300, (1, 1)),
#  'xxoo..x.o': (300, 300, (1, 2)),
#  'xxoo..xo.': (300, inf, (1, 2)),
#  'xxoo..xoo': (-inf, 0.0, (1, 2)),
#  'xxoo.o...': (-inf, 300, (1, 1)),
#  'xxoo.ox..': (300, 300, (1, 1)),
#  'xxoo.oxo.': (300, 300, (1, 1)),
#  'xxoo.oxox': (300, inf, (1, 1)),
#  'xxoo.x..o': (300, 300, (2, 0)),
#  'xxoo.x.o.': (300, 300, (2, 0)),
#  'xxoo.x.oo': (-inf, 300, (1, 1)),
#  'xxoo.xo..': (-inf, 300, (1, 1)),
#  'xxoo.xo.o': (300, 300, (1, 1)),
#  'xxoo.xoo.': (300, 300, (1, 1)),
#  'xxoo.xoox': (300, inf, (1, 1)),
#  'xxoo.xoxo': (300, inf, (1, 1)),
#  'xxoo.xxoo': (0.0, 0.0, (1, 1)),
#  'xxooo....': (300, 300, (2, 0)),
#  'xxooo...x': (300, inf, (2, 0)),
#  'xxooo..ox': (300, inf, (2, 0)),
#  'xxooo..x.': (300, inf, (2, 0)),
#  'xxooo..xo': (300, inf, (2, 0)),
#  'xxooo.x..': (300, 300, (1, 2)),
#  'xxooo.x.o': (-inf, 0.0, (1, 2)),
#  'xxooo.xo.': (-inf, 0.0, (1, 2)),
#  'xxooo.xox': (300, 300, (1, 2)),
#  'xxooo.xxo': (300, 300, (1, 2)),
#  'xxooox...': (300, 300, (2, 0)),
#  'xxooox..o': (-inf, 0.0, (2, 2)),
#  'xxooox.o.': (-inf, 0.0, (2, 0)),
#  'xxooox.ox': (300, 300, (2, 0)),
#  'xxooox.xo': (300, 300, (2, 2)),
#  'xxoooxx.o': (0.0, 0.0, (2, 1)),
#  'xxoooxxo.': (-inf, 0.0, (2, 2)),
#  'xxoox...o': (300, inf, (0, 1)),
#  'xxoox..o.': (300, inf, (0, 2)),
#  'xxoox..oo': (300, inf, (0, 1)),
#  'xxoox.o..': (-inf, -300, (0, 1)),
#  'xxoox.o.o': (-inf, -300, (0, 1)),
#  'xxoox.oo.': (-inf, -300, (0, 2)),
#  'xxoox.xoo': (300, 300, (1, 2)),
#  'xxooxo...': (300, 300, (0, 2)),
#  'xxooxo.o.': (-inf, -300, (0, 2)),
#  'xxooxoo..': (-inf, -300, (0, 2)),
#  'xxooxoxo.': (300, 300, (0, 2)),
#  'xxooxx.oo': (300, 300, (2, 2)),
#  'xxooxxo.o': (300, 300, (2, 1)),
#  'xxooxxoo.': (300, 300, (0, 2)),
#  'xxox.ooox': (300, inf, (1, 1)),
#  'xxoxo...o': (300, inf, (2, 1)),
#  'xxoxo..o.': (300, inf, (2, 0)),
#  'xxoxoo...': (300, 300, (0, 2)),
#  'xxoxoo.o.': (-inf, 300, (0, 2)),
#  'xxoxoo.ox': (300, 300, (2, 2)),
#  'xxoxox.oo': (300, inf, (2, 2)),
#  'xxoxxooo.': (300, 300, (0, 2))}

# %%
from tree import Mbtree_GUI

Mbtree_GUI()
# Out:
# VBox(children=(Output(layout=Layout(display='none')), HBox(children=(Label(value='', layout=Layout(width='50px…

# %%
print(tt[mb.board_to_str()])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(tt[mb.board_to_str()])
#
# KeyError: '.........'

# %%
bestmove = result["bestmove"]
PV = []
while mb.status == Marubatsu.PLAYING:
    PV.append(bestmove)
    print(bestmove)
    x, y = bestmove
    if mb.board[x][y] != Marubatsu.EMPTY:
        print("そのマスには着手済みです")
        break
    mb.move(x, y)
    print(mb)
    boardtxt = mb.board_to_str()
    if boardtxt in tt:
        _, _, bestmove = tt[boardtxt]
    elif mb.status != Marubatsu.PLAYING:
        print("置換表にデータが登録されていません")
        break
print(PV)
# Out:
# (0, 2)
# Turn x
# ...
# ...
# O..
#
# (1, 1)
# Turn o
# ...
# .X.
# o..
#
# (1, 0)
# Turn x
# .O.
# .x.
# o..
#
# (1, 0)
# そのマスには着手済みです
# [(0, 2), (1, 1), (1, 0), (1, 0)]
